# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key

# %%
file = '3.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 country  \
# 0       24196         26088           26088      US
# 1       24197         26089           26089  France
# 2       24198         26090           26090  Greece
# 3       24199         26091           26091  Greece
# 4       24200         26092           26092      US
#
#                                          description  \
# 0  Ripe, flashy raspberry, cherry and red currant...
# 1  This has a minerally, tense structure as well ...
# 2  Fresh and versatile, this Cabernet-Merlot blen...
# 3  A nose of peach, spice and citrus notes leads ...
# 4  Citrusy acidity gives this dry, silky Pinot No...
#
#                       designation  points  price    province  \
# 0              Appellation Series      87   35.0  California
# 1                     Bois Seguin      87   25.0    Burgundy
# 2                             NaN      87   35.0     Pangeon
# 3  Mythic River Sauvignon-Roditis      87   15.0     Corinth
# 4                   Andrea La Rue      87   25.0  California
#
#              region_1       region_2      taster_name taster_twitter_handle  \
# 0  Santa Maria Valley  Central Coast              NaN                   NaN
# 1      Pouilly-Fuissé            NaN       Roger Voss            @vossroger
# 2                 NaN            NaN  Susan Kostrzewa         @suskostrzewa
# 3                 NaN            NaN  Susan Kostrzewa         @suskostrzewa
# 4        Sonoma Coast         Sonoma              NaN                   NaN
#
#                                                title      variety  \
# 0  Cru 2010 Appellation Series Pinot Noir (Santa ...   Pinot Noir
# 1  Domaine Luquet 2011 Bois Seguin  (Pouilly-Fuissé)   Chardonnay
# 2             Estate Biblia Chora 2008 Red (Pangeon)    Red Blend
# 3  Estate Constantin Gofas 2011 Mythic River Sauv...  White Blend
# 4  Flocchini 2009 Andrea La Rue Pinot Noir (Sonom...   Pinot Noir
#
#                     winery
# 0                      Cru
# 1           Domaine Luquet
# 2      Estate Biblia Chora
# 3  Estate Constantin Gofas
# 4                Flocchini

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Cru.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cru
# Retrieving Results for Domaine Luquet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Luquet
# Retrieving Results for Estate Biblia Chora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Estate+Biblia+Chora
# Retrieving Results for Estate Constantin Gofas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Estate+Constantin+Gofas
# Retrieving Results for Flocchini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Flocchini
# Retrieving Results for Villa Spinosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Villa+Spinosa
# Retrieving Results for Vineyard 7&8.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vineyard+7%268
# Retrieving Results for Bressan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bressan
# Retrieving Results for Hess Collection.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hess+Collection
# Retrieving Results for Le Ragose.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Le+Ragose
# Retrieving Results for Va Piano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Va+Piano
# Retrieving Results for Walter Dacon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Walter+Dacon
# Retrieving Results for Louis Roederer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Roederer
# Retrieving Results for Snoqualmie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Snoqualmie
# Retrieving Results for Royal Tokaji.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Royal+Tokaji
# Retrieving Results for Sartori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sartori
# Retrieving Results for Sbragia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sbragia
# Retrieving Results for Three Rivers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Three+Rivers
# Retrieving Results for Whitehall Lane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Whitehall+Lane
# Retrieving Results for Domaine Chandon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Chandon
# Retrieving Results for Brander.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brander
# Retrieving Results for Marimar Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marimar+Estate
# Retrieving Results for Marston Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marston+Family
# Retrieving Results for Merry Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Merry+Cellars
# Retrieving Results for Matthews.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Matthews
# Retrieving Results for Northstar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Northstar
# Retrieving Results for Novelty Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Novelty+Hill
# Retrieving Results for Pascual Toso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pascual+Toso
# Retrieving Results for Rutherford Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Rutherford+Grove
# Retrieving Results for Schubert.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Schubert
# Retrieving Results for Terredora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Terredora
# Retrieving Results for Torii Mor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Torii+Mor
# Retrieving Results for Cantina Dei Monaci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cantina+Dei+Monaci
# Retrieving Results for Cantine del Notaio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cantine+del+Notaio
# Retrieving Results for Domäne Wachau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dom%C3%A4ne+Wachau
# Retrieving Results for Foursight.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Foursight
# Retrieving Results for Fratelli Urciuolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fratelli+Urciuolo
# Retrieving Results for Salexis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Salexis
# Retrieving Results for Shingleback.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Shingleback
# Retrieving Results for Shingleback.
# used region as search
# Retrieving Results for TapaNappa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=TapaNappa
# Retrieving Results for Truchard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Truchard
# Retrieving Results for Lancaster.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lancaster
# Retrieving Results for Legacy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Legacy
# Retrieving Results for Mastroberardino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mastroberardino
# Retrieving Results for Apolloni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Apolloni
# Retrieving Results for Viento.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Viento
# Retrieving Results for El Vinculo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=El+Vinculo
# Retrieving Results for Finca El Encinal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Finca+El+Encinal
# Retrieving Results for Finca El Encinal.
# used region as search
# Retrieving Results for Viento.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Viento
# Retrieving Results for Zull.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zull
# Retrieving Results for Zull.
# used region as search
# Retrieving Results for Zull.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zull
# Retrieving Results for Zull.
# used region as search
# Retrieving Results for I Capitani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=I+Capitani
# Retrieving Results for Lar de Paula.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lar+de+Paula
# Retrieving Results for Lar de Paula.
# used region as search
# Retrieving Results for Peter Lehmann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Peter+Lehmann
# Retrieving Results for Stonier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stonier
# Retrieving Results for Phelps Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Phelps+Creek
# Retrieving Results for Sineann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sineann
# Retrieving Results for Penner-Ash.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Penner-Ash
# Retrieving Results for Antichi Vinai 1877.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Antichi+Vinai+1877
# Retrieving Results for Armand de Brignac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Armand+de+Brignac
# Retrieving Results for Barone Pizzini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Barone+Pizzini
# Retrieving Results for Bischöfliche Weingüter Trier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bisch%C3%B6fliche+Weing%C3%BCter+Trier
# Retrieving Results for Blackbird Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Blackbird+Vineyards
# Retrieving Results for Bodegas Carchelo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bodegas+Carchelo
# Retrieving Results for Bott Frères.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bott+Fr%C3%A8res
# Retrieving Results for Brooks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brooks
# Retrieving Results for Brooks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brooks
# Retrieving Results for Ca' del Bosco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ca%27+del+Bosco
# Retrieving Results for Cedarville.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cedarville
# Retrieving Results for Château Cailleteau Bergeron.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Cailleteau+Bergeron
# Retrieving Results for Château de Lescours.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Lescours
# Retrieving Results for Château de Parenchère.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Parench%C3%A8re
# Retrieving Results for Château La Caussade.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+La+Caussade
# Retrieving Results for Château Noël Les Charmes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+No%C3%ABl+Les+Charmes
# Retrieving Results for Château Tour Bayard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Tour+Bayard
# Retrieving Results for Château Tour Bayard.
# used region as search
# Retrieving Results for Domaine Serene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Serene
# Retrieving Results for Torii Mor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Torii+Mor
# Retrieving Results for Troon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Troon
# Retrieving Results for Vallana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vallana
# Retrieving Results for Vatan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vatan
# Retrieving Results for Vignobles Carreau Selection.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vignobles+Carreau+Selection
# Retrieving Results for Vite Colte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vite+Colte
# Retrieving Results for Winter's Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Winter%27s+Hill
# Retrieving Results for Wise Villa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wise+Villa
# Retrieving Results for Lamborn Family Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lamborn+Family+Vineyards
# Retrieving Results for Oddero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Oddero
# Retrieving Results for Palladino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Palladino
# Retrieving Results for Rizzi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Rizzi
# Retrieving Results for Sineann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sineann
# Retrieving Results for Mount Langi Ghiran.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mount+Langi+Ghiran
# Retrieving Results for Poderi Colla.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Poderi+Colla
# Retrieving Results for Domaine Ehrhart.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Ehrhart
# Retrieving Results for Herdade do Esporão.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Herdade+do+Espor%C3%A3o
# Retrieving Results for Barale Fratelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Barale+Fratelli
# Retrieving Results for Brandborg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brandborg
# Retrieving Results for Trentadue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trentadue
# Retrieving Results for Boffa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Boffa
# Retrieving Results for Casa Nuestra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Casa+Nuestra
# Retrieving Results for Casa Nuestra.
# used region as search
# Retrieving Results for Panther Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Panther+Creek
# Retrieving Results for Siduri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Siduri
# Retrieving Results for Stephen & Walker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stephen+%26+Walker
# Retrieving Results for Tahbilk.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tahbilk
# Retrieving Results for Tenute Cisa Asinari dei Marchesi di Gresy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tenute+Cisa+Asinari+dei+Marchesi+di+Gresy
# Retrieving Results for Inniskillin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Inniskillin
# Retrieving Results for José Maria da Fonseca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jos%C3%A9+Maria+da+Fonseca
# Retrieving Results for Delfino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Delfino
# Retrieving Results for Domaine André Bonhomme.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Andr%C3%A9+Bonhomme
# Retrieving Results for Domaine Ferret.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Ferret
# Retrieving Results for Domaine Méo-Camuzet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+M%C3%A9o-Camuzet
# Retrieving Results for Capichera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Capichera
# Retrieving Results for Casa Santos Lima.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Casa+Santos+Lima
# Retrieving Results for Col dei Venti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Col+dei+Venti
# Retrieving Results for Dão Sul.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=D%C3%A3o+Sul
# Retrieving Results for Dark Earth.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dark+Earth
# Retrieving Results for Dark Earth.
# used region as search
# Retrieving Results for Domaine des Deux Roches.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+des+Deux+Roches
# Retrieving Results for Domaine des Valanges.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+des+Valanges
# Retrieving Results for Domaine Saumaize-Michelin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Saumaize-Michelin
# Retrieving Results for El Enemigo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=El+Enemigo
# Retrieving Results for Pine & Brown.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pine+%26+Brown
# Retrieving Results for Robert Mondavi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Robert+Mondavi
# Retrieving Results for Romililly.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Romililly
# Retrieving Results for Socré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Socr%C3%A9
# Retrieving Results for Socré.
# used region as search
# Retrieving Results for St. Urbans-Hof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=St.+Urbans-Hof
# Retrieving Results for Testarossa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Testarossa
# Retrieving Results for Treos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Treos
# Retrieving Results for Vadio Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vadio+Wines
# Retrieving Results for William Fèvre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=William+F%C3%A8vre
# Retrieving Results for Zaca Mesa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zaca+Mesa
# Retrieving Results for Turasan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Turasan
# Retrieving Results for Herdade da Comporta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Herdade+da+Comporta
# Retrieving Results for Gård.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=G%C3%A5rd
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kendall-Jackson
# Retrieving Results for Mas Belles Eaux.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mas+Belles+Eaux
# Retrieving Results for COS.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=COS
# Retrieving Results for Caterina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Caterina
# Retrieving Results for Dusted Valley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dusted+Valley
# Retrieving Results for Easton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Easton
# Retrieving Results for Patterson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Patterson
# Retrieving Results for San Pedro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=San+Pedro
# Retrieving Results for Simonnet-Febvre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Simonnet-Febvre
# Retrieving Results for Jaffurs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jaffurs
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kendall-Jackson
# Retrieving Results for Coastview.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Coastview
# Retrieving Results for DaMa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=DaMa
# Retrieving Results for Sparkman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sparkman
# Retrieving Results for Sparkman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sparkman
# Retrieving Results for St. Supéry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=St.+Sup%C3%A9ry
# Retrieving Results for Tondré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tondr%C3%A9
# Retrieving Results for Tondré.
# used region as search
# Retrieving Results for Viu Manent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Viu+Manent
# Retrieving Results for Volpe Pasini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Volpe+Pasini
# Retrieving Results for Trentadue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trentadue
# Retrieving Results for Hogue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hogue
# Retrieving Results for Marco Felluga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marco+Felluga
# Retrieving Results for Passalacqua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Passalacqua
# Retrieving Results for Chilcas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chilcas
# Retrieving Results for Hogue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hogue
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kendall-Jackson
# Retrieving Results for Livio Felluga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Livio+Felluga
# Retrieving Results for Matanzas Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Matanzas+Creek
# Retrieving Results for Mirabeau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mirabeau
# Retrieving Results for Monchiero Carbone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Monchiero+Carbone
# Retrieving Results for Moshin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Moshin
# Retrieving Results for Nadler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Nadler
# Retrieving Results for Parducci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Parducci
# Retrieving Results for Ravoire et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ravoire+et+Fils
# Retrieving Results for Ravoire et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ravoire+et+Fils
# Retrieving Results for San Silvestro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=San+Silvestro
# Retrieving Results for Kenwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kenwood
# Retrieving Results for Krupp Brothers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Krupp+Brothers
# Retrieving Results for Lucas & Lewellen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lucas+%26+Lewellen
# Retrieving Results for Luigi Bosca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Luigi+Bosca
# Retrieving Results for Maddalena.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Maddalena
# Retrieving Results for Marco Porello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marco+Porello
# Retrieving Results for Trione.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trione
# Retrieving Results for Vignamato.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vignamato
# Retrieving Results for Whitecliff Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Whitecliff+Vineyard
# Retrieving Results for Winzer Krems.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Winzer+Krems
# Retrieving Results for Zantho.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zantho
# Retrieving Results for Shooting Star.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Shooting+Star
# Retrieving Results for Tertulia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tertulia
# Retrieving Results for Mario Gagliasso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mario+Gagliasso
# Retrieving Results for Mario Gagliasso.
# used region as search
# Retrieving Results for Monte Faustino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Monte+Faustino
# Retrieving Results for Suavia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Suavia
# Retrieving Results for Fabre en Provence.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fabre+en+Provence
# Retrieving Results for Maison Nicolas Perrin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Maison+Nicolas+Perrin
# Retrieving Results for Maison Nicolas Perrin.
# used region as search
# Retrieving Results for Malavasi Daniele.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Malavasi+Daniele
# Retrieving Results for Malavasi Daniele.
# Missing field/result... skipping.
# Retrieving Results for Mar de Frades.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mar+de+Frades
# Retrieving Results for B Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=B+Cellars
# Retrieving Results for Bacio della Luna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bacio+della+Luna
# Retrieving Results for Barlow.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Barlow
# Retrieving Results for Borgo Maragliano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Borgo+Maragliano
# Retrieving Results for Bortolotti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bortolotti
# Retrieving Results for Tilia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tilia
# Retrieving Results for Viña Mayor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1a+Mayor
# Retrieving Results for Viñas de Garza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1as+de+Garza
# Retrieving Results for Volpaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Volpaia
# Retrieving Results for Wente.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wente
# Retrieving Results for Woodenhead.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Woodenhead
# Retrieving Results for Xurus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Xurus
# Retrieving Results for Prà.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pr%C3%A0
# Retrieving Results for Prager.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Prager
# Retrieving Results for Quinta de Chocapalha.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Quinta+de+Chocapalha
# Retrieving Results for Quinta de Chocapalha.
# used region as search
# Retrieving Results for Rappahannock Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Rappahannock+Cellars
# Retrieving Results for Renteria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Renteria
# Retrieving Results for Straight Line.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Straight+Line
# Retrieving Results for Sunset Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sunset+Hills
# Retrieving Results for Tinedo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tinedo
# Retrieving Results for Tinedo.
# Missing field/result... skipping.
# Retrieving Results for Torre Fornello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Torre+Fornello
# Retrieving Results for Tosalet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tosalet
# Retrieving Results for Trinitas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trinitas
# Retrieving Results for Jaffurs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jaffurs
# Retrieving Results for Kenwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kenwood
# Retrieving Results for L de Lyeth.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=L+de+Lyeth
# Retrieving Results for L de Lyeth.
# used region as search
# Retrieving Results for Landmark.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Landmark
# Retrieving Results for Mas de Monistrol.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mas+de+Monistrol
# Retrieving Results for Merotto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Merotto
# Retrieving Results for Tasca d'Almerita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tasca+d%27Almerita
# Retrieving Results for The Grifter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=The+Grifter
# Retrieving Results for Apriori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Apriori
# Retrieving Results for Atwater.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Atwater
# Retrieving Results for Baglio Curatolo Arini 1875.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Baglio+Curatolo+Arini+1875
# Retrieving Results for Baglio di Pianetto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Baglio+di+Pianetto
# Retrieving Results for Byington.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Byington
# Retrieving Results for Cantine Ermes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cantine+Ermes
# Retrieving Results for Castle Rock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Castle+Rock
# Retrieving Results for Château Charmail.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Charmail
# Retrieving Results for Château Latour-Martillac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Latour-Martillac
# Retrieving Results for Château Pomeys.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Pomeys
# Retrieving Results for Chilcas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chilcas
# Retrieving Results for Chilcas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chilcas
# Retrieving Results for Cougar Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cougar+Crest
# Retrieving Results for Domaine du Claouset.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+du+Claouset
# Retrieving Results for Domaine du Claouset.
# Missing field/result... skipping.
# Retrieving Results for Dutton Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dutton+Estate
# Retrieving Results for El Lugar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=El+Lugar
# Retrieving Results for Vigilance.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vigilance
# Retrieving Results for Santa Alba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Santa+Alba
# Retrieving Results for Santa Alba.
# used region as search
# Retrieving Results for Anthony Road.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Anthony+Road
# Retrieving Results for Baglio di Pianetto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Baglio+di+Pianetto
# Retrieving Results for Bernardus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bernardus
# Retrieving Results for Caruso & Minini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Caruso+%26+Minini
# Retrieving Results for Montevina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Montevina
# Retrieving Results for Hosmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hosmer
# Retrieving Results for Purple Star.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Purple+Star
# Retrieving Results for Ramseyer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ramseyer
# Retrieving Results for Rocca di Frassinello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Rocca+di+Frassinello
# Retrieving Results for Roche de Bellene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Roche+de+Bellene
# Retrieving Results for Stolpman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stolpman
# Retrieving Results for Stolpman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stolpman
# Retrieving Results for Swanson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Swanson
# Retrieving Results for Syncline.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Syncline
# Retrieving Results for Carpineto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Carpineto
# Retrieving Results for Channing Daughters.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Channing+Daughters
# Retrieving Results for Chateau Ste. Michelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chateau+Ste.+Michelle
# Retrieving Results for Domaine Charly Nicolle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Charly+Nicolle
# Retrieving Results for Domaine Jessiaume.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Jessiaume
# Retrieving Results for Domaine Sylvain Pataille.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Sylvain+Pataille
# Retrieving Results for Domaine Vrignaud.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Vrignaud
# Retrieving Results for Donna Olimpia 1898.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Donna+Olimpia+1898
# Retrieving Results for Flocchini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Flocchini
# Retrieving Results for Fornacelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fornacelle
# Retrieving Results for Golan Heights Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Golan+Heights+Winery
# Retrieving Results for Craggy Range.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Craggy+Range
# Retrieving Results for Le Grascete.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Le+Grascete
# Retrieving Results for Lost Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lost+Canyon
# Retrieving Results for Merriman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Merriman
# Retrieving Results for Joseph Swan Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Joseph+Swan+Vineyards
# Retrieving Results for Joseph Swan Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Joseph+Swan+Vineyards
# Retrieving Results for Kazmer & Blaise.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kazmer+%26+Blaise
# Retrieving Results for La Selva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=La+Selva
# Retrieving Results for MacRostie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=MacRostie
# Retrieving Results for Man O' War.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Man+O%27+War
# Retrieving Results for Sanguis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sanguis
# Retrieving Results for Thomas Fogarty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Thomas+Fogarty
# Retrieving Results for Vall Llach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vall+Llach
# Retrieving Results for Babcock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Babcock
# Retrieving Results for Bonaccorsi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bonaccorsi
# Retrieving Results for Bonaccorsi.
# used region as search
# Retrieving Results for Castello di Bossi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Castello+di+Bossi
# Retrieving Results for Demetria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Demetria
# Retrieving Results for Jorge Ordóñez & Co..
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jorge+Ord%C3%B3%C3%B1ez+%26+Co.
# Retrieving Results for Jorge Ordóñez & Co..
# used region as search
# Retrieving Results for Poggio Verrano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Poggio+Verrano
# Retrieving Results for Talley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Talley
# Retrieving Results for David Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=David+Hill
# Retrieving Results for Fort Ross.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fort+Ross
# Retrieving Results for Arista.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Arista
# Retrieving Results for Arista.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Arista
# Retrieving Results for Volpaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Volpaia
# Retrieving Results for Zull.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zull
# Retrieving Results for Zull.
# used region as search
# Retrieving Results for Castello Banfi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Castello+Banfi
# Retrieving Results for Clos Figueras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Clos+Figueras
# Retrieving Results for Dominio de Tares.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dominio+de+Tares
# Retrieving Results for Duemani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Duemani
# Retrieving Results for Dürnberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=D%C3%BCrnberg
# Retrieving Results for Fort Ross.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fort+Ross
# Retrieving Results for Foxen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Foxen
# Retrieving Results for Foxen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Foxen
# Retrieving Results for Jacopo Biondi-Santi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jacopo+Biondi-Santi
# Retrieving Results for Kracher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kracher
# Retrieving Results for Laurel Glen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Laurel+Glen
# Retrieving Results for Kellerei Kaltern Caldaro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kellerei+Kaltern+Caldaro
# Retrieving Results for Château Lamothe-Bergeron.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Lamothe-Bergeron
# Retrieving Results for Château Peyredon Lagravette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Peyredon+Lagravette
# Retrieving Results for Château Peyredon Lagravette.
# used region as search
# Retrieving Results for Château Saransot-Dupré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Saransot-Dupr%C3%A9
# Retrieving Results for Errazuriz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Errazuriz
# Retrieving Results for Fattori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fattori
# Retrieving Results for Girlan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Girlan
# Retrieving Results for Pali.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pali
# ...
# Retrieving Results for Château Les Charmes Godard.
# Missing field/result... skipping.
# Retrieving Results for Chehalem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chehalem
# Retrieving Results for Contadi Castaldi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Contadi+Castaldi
# Retrieving Results for Coto de Hayas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Coto+de+Hayas
# Retrieving Results for Coto de Hayas.
# used region as search
# Retrieving Results for Grafen Neipperg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Grafen+Neipperg
# Retrieving Results for Monsieur Touton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Monsieur+Touton
# Retrieving Results for One Leaf.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=One+Leaf
# Retrieving Results for Tenuta Cà du Russ.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tenuta+C%C3%A0+du+Russ
# Retrieving Results for Tenuta Cà du Russ.
# used region as search
# Retrieving Results for Tenuta Mazzolino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tenuta+Mazzolino
# Retrieving Results for Quinta de Porrais.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Quinta+de+Porrais
# Retrieving Results for Quinta de Porrais.
# used region as search
# Retrieving Results for Maison Hebrard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Maison+Hebrard
# Retrieving Results for Maitea.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Maitea
# Retrieving Results for Walnut City WineWorks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Walnut+City+WineWorks
# Retrieving Results for Zerran.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zerran
# Retrieving Results for Zuani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Zuani
# Retrieving Results for Carpe Diem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Carpe+Diem
# Retrieving Results for Colutta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Colutta
# Retrieving Results for Colutta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Colutta
# Retrieving Results for Cormòns.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Corm%C3%B2ns
# Retrieving Results for Cormòns.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Corm%C3%B2ns
# Retrieving Results for DFJ Vinhos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=DFJ+Vinhos
# Retrieving Results for Fortant.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fortant
# Retrieving Results for Fortant.
# used region as search
# Retrieving Results for Glennhawk.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Glennhawk
# Retrieving Results for Hawkins Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hawkins+Cellars
# Retrieving Results for Miguel Torres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Miguel+Torres
# Retrieving Results for Peter Mertes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Peter+Mertes
# Retrieving Results for Red Pony Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Red+Pony+Ranch
# Retrieving Results for Saint Gregory.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Saint+Gregory
# Retrieving Results for Terre Rouge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Terre+Rouge
# Retrieving Results for Urban Legend.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Urban+Legend
# Retrieving Results for Viña Bisquertt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1a+Bisquertt
# Retrieving Results for Viña Requingua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1a+Requingua
# Retrieving Results for Vinum Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vinum+Cellars
# Retrieving Results for Wy'East Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wy%27East+Vineyards
# Retrieving Results for Henrique José de La Puente Sancho Uva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henrique+Jos%C3%A9+de+La+Puente+Sancho+Uva
# Retrieving Results for Henrique José de La Puente Sancho Uva.
# used region as search
# Retrieving Results for Julia Kemper Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Julia+Kemper+Wines
# Retrieving Results for Julia Kemper Wines.
# used region as search
# Retrieving Results for Kenneth Volk.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kenneth+Volk
# Retrieving Results for Holus Bolus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Holus+Bolus
# Retrieving Results for Wakefield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wakefield
# Retrieving Results for Dehlinger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dehlinger
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Gary+Farrell
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Patz & Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Patz+%26+Hall
# Retrieving Results for Shafer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Shafer
# Retrieving Results for Dutton-Goldfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dutton-Goldfield
# Retrieving Results for Jean-Luc and Paul Aegerter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jean-Luc+and+Paul+Aegerter
# Retrieving Results for Massolino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Massolino
# Retrieving Results for Nada Giuseppe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Nada+Giuseppe
# Retrieving Results for Azelia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Azelia
# Retrieving Results for Chappellet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chappellet
# Retrieving Results for Château de Fuissé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Fuiss%C3%A9
# Retrieving Results for Château de Santenay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Santenay
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Monte da Ravasqueira.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Monte+da+Ravasqueira
# Retrieving Results for Reichsgraf von Kesselstatt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Reichsgraf+von+Kesselstatt
# Retrieving Results for Seguin-Manuel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Seguin-Manuel
# Retrieving Results for St. Innocent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=St.+Innocent
# Retrieving Results for Adriano Marco & Vittorio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Adriano+Marco+%26+Vittorio
# Retrieving Results for Bouchard Père & Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bouchard+P%C3%A8re+%26+Fils
# Retrieving Results for Château de Fuissé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Fuiss%C3%A9
# Retrieving Results for Château de Santenay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Santenay
# Retrieving Results for Walt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Walt
# Retrieving Results for Chambers Rosewood Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chambers+Rosewood+Vineyards
# Retrieving Results for Albino Rocca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Albino+Rocca
# Retrieving Results for Vega Sicilia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vega+Sicilia
# Retrieving Results for Wines & Winemakers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wines+%26+Winemakers
# Retrieving Results for Gorman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Gorman
# Retrieving Results for Graveyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Graveyard
# Retrieving Results for Henri Schoenheitz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henri+Schoenheitz
# Retrieving Results for Château de Chaintres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Chaintres
# Retrieving Results for Cloak & Dagger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cloak+%26+Dagger
# Retrieving Results for Dalrymple.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dalrymple
# Retrieving Results for Domaine Gresser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Gresser
# Retrieving Results for Domaine Jean Sipp.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Jean+Sipp
# Retrieving Results for Domaine Ostertag.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Ostertag
# Retrieving Results for Domaines Schlumberger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaines+Schlumberger
# Retrieving Results for Don Tony Perez.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Don+Tony+Perez
# Retrieving Results for Fazeli Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fazeli+Cellars
# Retrieving Results for Foley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Foley
# Retrieving Results for Angove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Angove
# Retrieving Results for Sierra Cantabria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sierra+Cantabria
# Retrieving Results for Undurraga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Undurraga
# Retrieving Results for Vie di Romans.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vie+di+Romans
# Retrieving Results for Vie di Romans.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vie+di+Romans
# Retrieving Results for Wittmann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wittmann
# Retrieving Results for Ancien.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ancien
# Retrieving Results for André Kientzler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Andr%C3%A9+Kientzler
# Retrieving Results for Aver Family Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Aver+Family+Vineyards
# Retrieving Results for Brick & Mortar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brick+%26+Mortar
# Retrieving Results for Viñas del Cenit.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1as+del+Cenit
# Retrieving Results for Casa do Valle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Casa+do+Valle
# Retrieving Results for Cellars 33.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cellars+33
# Retrieving Results for Demetria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Demetria
# Retrieving Results for Bailly-Lapierre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bailly-Lapierre
# Retrieving Results for Bodega Chacra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bodega+Chacra
# Retrieving Results for Bodegas Franco-Españolas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bodegas+Franco-Espa%C3%B1olas
# Retrieving Results for Brokenwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brokenwood
# Retrieving Results for Brokenwood.
# used region as search

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('3coord.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 country  \
# 0       24196         26088           26088      US
# 1       24197         26089           26089  France
# 2       24198         26090           26090  Greece
# 3       24199         26091           26091  Greece
# 4       24200         26092           26092      US
#
#                                          description  \
# 0  Ripe, flashy raspberry, cherry and red currant...
# 1  This has a minerally, tense structure as well ...
# 2  Fresh and versatile, this Cabernet-Merlot blen...
# 3  A nose of peach, spice and citrus notes leads ...
# 4  Citrusy acidity gives this dry, silky Pinot No...
#
#                       designation  points  price    province  \
# 0              Appellation Series      87   35.0  California
# 1                     Bois Seguin      87   25.0    Burgundy
# 2                             NaN      87   35.0     Pangeon
# 3  Mythic River Sauvignon-Roditis      87   15.0     Corinth
# 4                   Andrea La Rue      87   25.0  California
#
#              region_1       region_2      taster_name taster_twitter_handle  \
# 0  Santa Maria Valley  Central Coast              NaN                   NaN
# 1      Pouilly-Fuissé            NaN       Roger Voss            @vossroger
# 2                 NaN            NaN  Susan Kostrzewa         @suskostrzewa
# 3                 NaN            NaN  Susan Kostrzewa         @suskostrzewa
# 4        Sonoma Coast         Sonoma              NaN                   NaN
#
#                                                title      variety  \
# 0  Cru 2010 Appellation Series Pinot Noir (Santa ...   Pinot Noir
# 1  Domaine Luquet 2011 Bois Seguin  (Pouilly-Fuissé)   Chardonnay
# 2             Estate Biblia Chora 2008 Red (Pangeon)    Red Blend
# 3  Estate Constantin Gofas 2011 Mythic River Sauv...  White Blend
# 4  Flocchini 2009 Andrea La Rue Pinot Noir (Sonom...   Pinot Noir
#
#                     winery        Lat         Lng  heat weights
# 0                      Cru  32.730476  -97.338917             7
# 1           Domaine Luquet  46.280191    4.743419             7
# 2      Estate Biblia Chora  40.811805   23.990810             7
# 3  Estate Constantin Gofas  37.856933   22.644690             7
# 4                Flocchini  39.180871 -119.764360             7

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
