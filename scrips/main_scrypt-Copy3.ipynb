# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys_Copy1 import g_key

# %%
file = '10.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 country  \
# 0      108878        117018          117018      US
# 1      108879        117019          117019   Spain
# 2      108880        117020          117020   Spain
# 3      108881        117021          117021   Spain
# 4      108882        117022          117022      US
#
#                                          description          designation  \
# 0        Smells raisiny, feels hot, tastes overripe.      Imagine Reserve
# 1  Powdery and oaky smelling, with not much fruit...                  NaN
# 2  Gritty cherry and plum aromas lead into a shee...  Cantos de Valpiedra
# 3  Stalky smelling, with a minerally streak. Feel...               Serres
# 4  A big, thick, somewhat dull wine, with candied...                  NaN
#
#    points  price        province              region_1       region_2  \
# 0      81   62.0      California  Santa Barbara County  Central Coast
# 1      81   14.0  Northern Spain               Navarra            NaN
# 2      81   21.0  Northern Spain                 Rioja            NaN
# 3      81   10.0  Northern Spain                 Rioja            NaN
# 4      81   19.0      California         Sonoma County         Sonoma
#
#          taster_name taster_twitter_handle  \
# 0                NaN                   NaN
# 1  Michael Schachner           @wineschach
# 2  Michael Schachner           @wineschach
# 3  Michael Schachner           @wineschach
# 4                NaN                   NaN
#
#                                                title             variety  \
# 0  Hunt Cellars 2009 Imagine Reserve Pinot Noir (...          Pinot Noir
# 1              Vega Sindoa 2010 Chardonnay (Navarra)          Chardonnay
# 2  Finca Valpiedra 2008 Cantos de Valpiedra  (Rioja)         Tempranillo
# 3            Carlos Serres 2010 Serres Viura (Rioja)               Viura
# 4  Hideaway Creek 2007 Cabernet Sauvignon (Sonoma...  Cabernet Sauvignon
#
#             winery
# 0     Hunt Cellars
# 1      Vega Sindoa
# 2  Finca Valpiedra
# 3    Carlos Serres
# 4   Hideaway Creek

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Hunt Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hunt+Cellars
# Retrieving Results for Vega Sindoa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vega+Sindoa
# Retrieving Results for Vega Sindoa.
# used region as search
# Retrieving Results for Finca Valpiedra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Valpiedra
# Retrieving Results for Carlos Serres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Carlos+Serres
# Retrieving Results for Hideaway Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hideaway+Creek
# Retrieving Results for Root:1.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Root%3A1
# Retrieving Results for Bodegas Riojanas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Riojanas
# Retrieving Results for Torito Bravo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Torito+Bravo
# Retrieving Results for Caymus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Caymus
# Retrieving Results for Schloss Johannisberger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Schloss+Johannisberger
# Retrieving Results for Robert Weil.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Robert+Weil
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Br%C3%BCndlmayer
# Retrieving Results for Domdechant Werner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domdechant+Werner
# Retrieving Results for Scott Paul.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Scott+Paul
# Retrieving Results for Dr. Heidemanns-Bergweiler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Heidemanns-Bergweiler
# Retrieving Results for Maximin Grünhäuser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Maximin+Gr%C3%BCnh%C3%A4user
# Retrieving Results for Cowhorn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cowhorn
# Retrieving Results for kukkula.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=kukkula
# Retrieving Results for Larner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Larner
# Retrieving Results for Maximin Grünhäuser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Maximin+Gr%C3%BCnh%C3%A4user
# Retrieving Results for Domaine Sigalas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Sigalas
# Retrieving Results for Écluse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=%C3%89cluse
# Retrieving Results for Elk Cove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Elk+Cove
# Retrieving Results for Graci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Graci
# Retrieving Results for Wilde Farm Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wilde+Farm+Wines
# Retrieving Results for Occasio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Occasio
# Retrieving Results for Raventós I Blanc.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ravent%C3%B3s+I+Blanc
# Retrieving Results for Talbott.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Talbott
# Retrieving Results for Tenuta di Fessina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+di+Fessina
# Retrieving Results for Terre Rouge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Terre+Rouge
# Retrieving Results for Hoopes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hoopes
# Retrieving Results for Sella & Mosca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sella+%26+Mosca
# Retrieving Results for Thorn Clarke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Thorn+Clarke
# Retrieving Results for Le Casematte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Casematte
# Retrieving Results for Prime Solum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Prime+Solum
# Retrieving Results for Refugio Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Refugio+Ranch
# Retrieving Results for Sleeping Giant.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sleeping+Giant
# Retrieving Results for Albert Bichot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Albert+Bichot
# Retrieving Results for Ancient Peaks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ancient+Peaks
# Retrieving Results for Antiyal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antiyal
# Retrieving Results for Barone di Villagrande.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barone+di+Villagrande
# Retrieving Results for Beauregard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Beauregard
# Retrieving Results for Black Kite.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Black+Kite
# Retrieving Results for Cobb.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cobb
# Retrieving Results for Cooper-Garrod.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cooper-Garrod
# Retrieving Results for Domaine des Croix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+des+Croix
# Retrieving Results for Sequoia Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sequoia+Grove
# Retrieving Results for Sequoia Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sequoia+Grove
# Retrieving Results for Thomas Fogarty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Thomas+Fogarty
# Retrieving Results for Tolosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tolosa
# Retrieving Results for Trombetta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trombetta
# Retrieving Results for Vik.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vik
# Retrieving Results for Dierberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dierberg
# Retrieving Results for Diora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Diora
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Zind-Humbrecht
# Retrieving Results for Felten Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Felten+Cellars
# Retrieving Results for Felten Cellars.
# used region as search
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gary+Farrell
# Retrieving Results for Goldeneye.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Goldeneye
# Retrieving Results for Cenay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cenay
# Retrieving Results for Poseidon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poseidon
# Retrieving Results for Prodigal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Prodigal
# Retrieving Results for Rexford.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rexford
# Retrieving Results for Roederer Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Roederer+Estate
# Retrieving Results for Tedeschi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tedeschi
# Retrieving Results for Pellet Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pellet+Estate
# Retrieving Results for Lafond.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lafond
# Retrieving Results for Wayfarer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wayfarer
# Retrieving Results for Venturini Massimino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Venturini+Massimino
# Retrieving Results for Pasqua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pasqua
# Retrieving Results for Arista.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Arista
# Retrieving Results for Solminer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Solminer
# Retrieving Results for Acinum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Acinum
# Retrieving Results for Acinum.
# used region as search
# Retrieving Results for Babcock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Babcock
# Retrieving Results for Barbieri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barbieri
# Retrieving Results for Graci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Graci
# Retrieving Results for Luis Cañas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Luis+Ca%C3%B1as
# Retrieving Results for Albert Bichot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Albert+Bichot
# Retrieving Results for Ancient Peaks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ancient+Peaks
# Retrieving Results for Antiyal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antiyal
# Retrieving Results for Barone di Villagrande.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barone+di+Villagrande
# Retrieving Results for Beauregard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Beauregard
# Retrieving Results for Black Kite.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Black+Kite
# Retrieving Results for Refugio Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Refugio+Ranch
# Retrieving Results for Sleeping Giant.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sleeping+Giant
# Retrieving Results for Albert Bichot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Albert+Bichot
# Retrieving Results for Austin Hope.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Austin+Hope
# Retrieving Results for Beckmen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Beckmen
# Retrieving Results for Black Kite.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Black+Kite
# Retrieving Results for Boekenoogen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Boekenoogen
# Retrieving Results for Chanson Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chanson+P%C3%A8re+et+Fils
# Retrieving Results for Chanson Père et Fils.
# used region as search
# Retrieving Results for Chanson Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chanson+P%C3%A8re+et+Fils
# Retrieving Results for Chanson Père et Fils.
# used region as search
# Retrieving Results for Chanson Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chanson+P%C3%A8re+et+Fils
# Retrieving Results for Chanson Père et Fils.
# used region as search
# Retrieving Results for Domaine Faiveley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Faiveley
# Retrieving Results for Domaine Faiveley.
# used region as search
# Retrieving Results for Domaine Jacques Prieur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Jacques+Prieur
# Retrieving Results for Navarro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Navarro
# Retrieving Results for Prime Solum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Prime+Solum
# Retrieving Results for Robert Weil.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Robert+Weil
# Retrieving Results for Santa Cruz Mountain Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Cruz+Mountain+Vineyard
# Retrieving Results for Skinner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Skinner
# Retrieving Results for The Eyrie Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=The+Eyrie+Vineyards
# Retrieving Results for Gunderloch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gunderloch
# Retrieving Results for Halcon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Halcon
# Retrieving Results for Hunnicutt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hunnicutt
# Retrieving Results for Kessler-Haak.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kessler-Haak
# Retrieving Results for Milliaire.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Milliaire
# Retrieving Results for Chateau Morrisette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chateau+Morrisette
# Retrieving Results for El Enemigo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=El+Enemigo
# Retrieving Results for McManis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=McManis
# Retrieving Results for Insatiable.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Insatiable
# Retrieving Results for Insatiable.
# used region as search
# Retrieving Results for Predator.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Predator
# Retrieving Results for Bodega Tintoralba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodega+Tintoralba
# Retrieving Results for VinEcol.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=VinEcol
# Retrieving Results for Zinsane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zinsane
# Retrieving Results for Zinsane.
# used region as search
# Retrieving Results for Villa Toscano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Villa+Toscano
# Retrieving Results for Wise Villa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wise+Villa
# Retrieving Results for Wise Villa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wise+Villa
# Retrieving Results for Twisted.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Twisted
# Retrieving Results for Vindemia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vindemia
# Retrieving Results for Espuela del Gaucho.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Espuela+del+Gaucho
# Retrieving Results for Espuela del Gaucho.
# used region as search
# Retrieving Results for Gramercy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gramercy
# Retrieving Results for Marita's Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marita%27s+Vineyard
# Retrieving Results for Charles Smith.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Charles+Smith
# Retrieving Results for Merry Edwards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Merry+Edwards
# Retrieving Results for Porcupine Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Porcupine+Ridge
# Retrieving Results for Santa Alicia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Alicia
# Retrieving Results for Siegel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Siegel
# Retrieving Results for Brancott.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Brancott
# Retrieving Results for Cantara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cantara
# Retrieving Results for Durbanville Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Durbanville+Hills
# Retrieving Results for Eberle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Eberle
# Retrieving Results for Irony.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Irony
# Retrieving Results for Irony.
# used region as search
# Retrieving Results for Kennedy Point.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kennedy+Point
# Retrieving Results for KWV.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=KWV
# Retrieving Results for KWV.
# used region as search
# Retrieving Results for Lee Family Farm.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lee+Family+Farm
# Retrieving Results for Locati Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Locati+Cellars
# Retrieving Results for Wirra Wirra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wirra+Wirra
# Retrieving Results for Castelvero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Castelvero
# Retrieving Results for Eberle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Eberle
# Retrieving Results for Emiliana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Emiliana
# Retrieving Results for Field Stone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Field+Stone
# Retrieving Results for Gancia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gancia
# Retrieving Results for Gancia.
# used region as search
# Retrieving Results for Prinsi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Prinsi
# Retrieving Results for Prinsi.
# used region as search
# Retrieving Results for Rochioli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rochioli
# Retrieving Results for Jules Taylor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jules+Taylor
# Retrieving Results for Jules Taylor.
# used region as search
# Retrieving Results for Kenwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kenwood
# Retrieving Results for Veramonte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Veramonte
# Retrieving Results for William Cole.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=William+Cole
# Retrieving Results for Le Roi des Pierres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Roi+des+Pierres
# Retrieving Results for Le Roi des Pierres.
# used region as search
# Retrieving Results for Les Vignerons des Coteaux Romanais.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Les+Vignerons+des+Coteaux+Romanais
# Retrieving Results for Albino Armani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Albino+Armani
# Retrieving Results for Bailly-Lapierre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bailly-Lapierre
# Retrieving Results for Bernardus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bernardus
# Retrieving Results for Gordon Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gordon+Estate
# Retrieving Results for Henri Bourgeois.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Henri+Bourgeois
# Retrieving Results for Cantina di Monteforte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cantina+di+Monteforte
# Retrieving Results for Cave de Lugny.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cave+de+Lugny
# Retrieving Results for Cave des Producteurs de Vouvray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cave+des+Producteurs+de+Vouvray
# Retrieving Results for Chateau Ste. Michelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chateau+Ste.+Michelle
# Retrieving Results for Cono Sur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cono+Sur
# Retrieving Results for Domaine du Chalet Pouilly.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+du+Chalet+Pouilly
# Retrieving Results for Domaine Gueguen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Gueguen
# Retrieving Results for Domaines Devillard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaines+Devillard
# Retrieving Results for Domaines Devillard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaines+Devillard
# Retrieving Results for Fournier Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fournier+P%C3%A8re+et+Fils
# Retrieving Results for Aljibes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Aljibes
# Retrieving Results for Amisfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Amisfield
# Retrieving Results for Angel Vine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Angel+Vine
# Retrieving Results for Anglim.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Anglim
# Retrieving Results for Basel Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Basel+Cellars
# Retrieving Results for Bedell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bedell
# Retrieving Results for Bodegas Fabre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Fabre
# Retrieving Results for Bodegas Peñafiel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Pe%C3%B1afiel
# Retrieving Results for Budureasca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Budureasca
# Retrieving Results for Chamonix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chamonix
# Retrieving Results for Charles Krug.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Charles+Krug
# Retrieving Results for Château du Cèdre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+du+C%C3%A8dre
# Retrieving Results for Ponzi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ponzi
# Retrieving Results for Amuse Bouche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Amuse+Bouche
# Retrieving Results for Gérard Bertrand.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=G%C3%A9rard+Bertrand
# Retrieving Results for Gérard Bertrand.
# used region as search
# Retrieving Results for Arkenstone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Arkenstone
# Retrieving Results for Keller Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Keller+Estate
# Retrieving Results for Sinatra Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sinatra+Family
# Retrieving Results for Sinatra Family.
# used region as search
# Retrieving Results for Geh. Rat Dr. von Bassermann-Jordan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Geh.+Rat+Dr.+von+Bassermann-Jordan
# Retrieving Results for Keller Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Keller+Estate
# Retrieving Results for Two Sisters.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Two+Sisters
# Retrieving Results for Fog Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fog+Crest
# Retrieving Results for Freestone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Freestone
# Retrieving Results for Diamond Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Diamond+Creek
# Retrieving Results for Trisaetum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trisaetum
# Retrieving Results for Jean-Luc Baldès.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jean-Luc+Bald%C3%A8s
# Retrieving Results for Jean-Luc Baldès.
# used region as search
# Retrieving Results for Bodega Catena Zapata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodega+Catena+Zapata
# Retrieving Results for Gérard Bertrand.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=G%C3%A9rard+Bertrand
# Retrieving Results for Gérard Bertrand.
# Missing field/result... skipping.
# Retrieving Results for Arkenstone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Arkenstone
# Retrieving Results for Charles Krug.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Charles+Krug
# Retrieving Results for Markus Molitor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Markus+Molitor
# Retrieving Results for Vilafonté.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vilafont%C3%A9
# Retrieving Results for Jean-Luc Baldès.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jean-Luc+Bald%C3%A8s
# Retrieving Results for Jean-Luc Baldès.
# used region as search
# Retrieving Results for Jean-Luc Baldès.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jean-Luc+Bald%C3%A8s
# Retrieving Results for Jean-Luc Baldès.
# used region as search
# Retrieving Results for Patz & Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Patz+%26+Hall
# Retrieving Results for Talisman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Talisman
# Retrieving Results for Dr. Pauly Bergweiler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Pauly+Bergweiler
# Retrieving Results for Trisaetum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trisaetum
# Retrieving Results for Fog Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fog+Crest
# Retrieving Results for Veramar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Veramar
# Retrieving Results for Morandé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Morand%C3%A9
# Retrieving Results for Salentein.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Salentein
# Retrieving Results for Paripaso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paripaso
# Retrieving Results for Paripaso.
# used region as search
# Retrieving Results for Barefoot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barefoot
# Retrieving Results for Finca Las Moras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Las+Moras
# Retrieving Results for Sombras del Sol.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sombras+del+Sol
# Retrieving Results for Sombras del Sol.
# used region as search
# Retrieving Results for Estampa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Estampa
# Retrieving Results for Bota Box.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bota+Box
# Retrieving Results for Cambridge & Sunset.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cambridge+%26+Sunset
# Retrieving Results for Orfila.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Orfila
# Retrieving Results for Santa Rita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Rita
# Retrieving Results for Sartarelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sartarelli
# Retrieving Results for Antucura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antucura
# Retrieving Results for Paripaso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paripaso
# Retrieving Results for Paripaso.
# used region as search
# Retrieving Results for Pessimist.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pessimist
# Retrieving Results for Pessimist.
# used region as search
# Retrieving Results for Maipe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Maipe
# Retrieving Results for Coyote Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Coyote+Creek
# Retrieving Results for Eye Candy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Eye+Candy
# Retrieving Results for Gimenez Riili.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gimenez+Riili
# Retrieving Results for Barefoot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barefoot
# Retrieving Results for Barefoot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barefoot
# Retrieving Results for Castle Rock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Castle+Rock
# Retrieving Results for Wilson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wilson
# Retrieving Results for Familia Schroeder.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Familia+Schroeder
# Retrieving Results for Posh.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Posh
# Retrieving Results for Riaza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Riaza
# Retrieving Results for Señorío de Sarria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Se%C3%B1or%C3%ADo+de+Sarria
# Retrieving Results for Andeluna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Andeluna
# Retrieving Results for Cable Car.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cable+Car
# Retrieving Results for Testarossa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Testarossa
# Retrieving Results for Trerè.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trer%C3%A8
# Retrieving Results for TruthTeller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=TruthTeller
# Retrieving Results for Viña Chocalan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Chocalan
# Retrieving Results for A Blooming Hill Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=A+Blooming+Hill+Vineyard
# Retrieving Results for Bisceglia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bisceglia
# Retrieving Results for Mastroberardino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mastroberardino
# Retrieving Results for Melini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Melini
# Retrieving Results for Palagetto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Palagetto
# Retrieving Results for Plaisance Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Plaisance+Ranch
# Retrieving Results for Poderi Arcangelo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poderi+Arcangelo
# Retrieving Results for Quinta do Casal Branco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+do+Casal+Branco
# Retrieving Results for Sequoia Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sequoia+Grove
# Retrieving Results for St. Christopher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=St.+Christopher
# Retrieving Results for Tenuta La Vigna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+La+Vigna
# Retrieving Results for Tenuta La Viola.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+La+Viola
# Retrieving Results for Terra Silvestre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Terra+Silvestre
# Retrieving Results for Terra Silvestre.
# used region as search
# Retrieving Results for Judd's Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Judd%27s+Hill
# Retrieving Results for La Honda Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Honda+Winery
# Retrieving Results for Maddalena.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Maddalena
# Retrieving Results for Mancura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mancura
# Retrieving Results for Mancura.
# used region as search
# Retrieving Results for 14 Hands.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=14+Hands
# Retrieving Results for Anam Cara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Anam+Cara
# Retrieving Results for Benessere.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Benessere
# Retrieving Results for Quevedo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quevedo
# Retrieving Results for Otazu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Otazu
# Retrieving Results for Otazu.
# used region as search
# Retrieving Results for Louis Tête.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Louis+T%C3%AAte
# Retrieving Results for Louis Tête.
# Missing field/result... skipping.
# Retrieving Results for Luminis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Luminis
# Retrieving Results for Pata Negra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pata+Negra
# Retrieving Results for Trapiche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trapiche
# Retrieving Results for Vega Sindoa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vega+Sindoa
# Retrieving Results for Vega Sindoa.
# used region as search
# Retrieving Results for Cyan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cyan
# Retrieving Results for Coto de Hayas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Coto+de+Hayas
# Retrieving Results for Coto de Hayas.
# used region as search
# Retrieving Results for Garbó.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Garb%C3%B3
# Retrieving Results for Garbó.
# used region as search
# Retrieving Results for Felix Solis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Felix+Solis
# Retrieving Results for Santa Julia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Julia
# Retrieving Results for Damalisco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Damalisco
# Retrieving Results for Damalisco.
# used region as search
# Retrieving Results for Ideology Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ideology+Cellars
# Retrieving Results for Bodega Atamisque.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodega+Atamisque
# Retrieving Results for Godelia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Godelia
# Retrieving Results for Lost Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lost+Canyon
# Retrieving Results for Viña Vilano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Vilano
# Retrieving Results for Gancedo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gancedo
# Retrieving Results for O. Fournier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=O.+Fournier
# Retrieving Results for Zuccardi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zuccardi
# Retrieving Results for Viña Santa Marina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Santa+Marina
# Retrieving Results for Gran Familia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gran+Familia
# Retrieving Results for Cruzat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cruzat
# Retrieving Results for Il Paradiso di Manfredi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Il+Paradiso+di+Manfredi
# Retrieving Results for Mascarello Giuseppe e Figlio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mascarello+Giuseppe+e+Figlio
# Retrieving Results for Sineann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sineann
# Retrieving Results for Mill Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mill+Creek
# Retrieving Results for Steven Kent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Steven+Kent
# Retrieving Results for Zotovich Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zotovich+Cellars
# Retrieving Results for Tantara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tantara
# Retrieving Results for Le Cinciole.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Cinciole
# Retrieving Results for Lujon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lujon
# Retrieving Results for Poças.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Po%C3%A7as
# Retrieving Results for Pomelo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pomelo
# Retrieving Results for Stephen & Walker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stephen+%26+Walker
# Retrieving Results for Valdelainos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Valdelainos
# Retrieving Results for Valdelainos.
# used region as search
# Retrieving Results for Enrique Mendoza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Enrique+Mendoza
# Retrieving Results for Domaine Ehrhart.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Ehrhart
# Retrieving Results for Echo Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Echo+Ridge
# Retrieving Results for ENSO.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=ENSO
# Retrieving Results for Fattoria Poggerino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fattoria+Poggerino
# Retrieving Results for Felsina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Felsina
# Retrieving Results for Fiuza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fiuza
# Retrieving Results for Four Fields.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Four+Fields
# Retrieving Results for A to Z.
# ...
# Retrieving Results for Biltmore Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Biltmore+Estate
# Retrieving Results for Bodegas y Viñedos Tábula.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+y+Vi%C3%B1edos+T%C3%A1bula
# Retrieving Results for Boeckel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Boeckel
# Retrieving Results for Brutocao.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Brutocao
# Retrieving Results for Château Ponzac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Ponzac
# Retrieving Results for Coffee Pot Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Coffee+Pot+Cellars
# Retrieving Results for Domaine des Nugues.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+des+Nugues
# Retrieving Results for Domaine des Terres Dorées.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+des+Terres+Dor%C3%A9es
# Retrieving Results for Domaine Fernand Engel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Fernand+Engel
# Retrieving Results for MacRostie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=MacRostie
# Retrieving Results for Maison Bleue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Maison+Bleue
# Retrieving Results for Martin Ray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Martin+Ray
# Retrieving Results for Martinsancho.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Martinsancho
# Retrieving Results for Martinsancho.
# used region as search
# Retrieving Results for Matthews.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Matthews
# Retrieving Results for Cape Point Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cape+Point+Vineyards
# Retrieving Results for Valserrano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Valserrano
# Retrieving Results for Zaca Mesa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zaca+Mesa
# Retrieving Results for Antigal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antigal
# Retrieving Results for Antigal.
# used region as search
# Retrieving Results for Antigal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antigal
# Retrieving Results for Antigal.
# used region as search
# Retrieving Results for August West.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=August+West
# Retrieving Results for Jean-Luc Colombo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jean-Luc+Colombo
# Retrieving Results for Penedo Borges.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Penedo+Borges
# Retrieving Results for Penedo Borges.
# used region as search
# Retrieving Results for Jax.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jax
# Retrieving Results for La Mannella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Mannella
# Retrieving Results for Lionel Osmin & Cie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lionel+Osmin+%26+Cie
# Retrieving Results for Martin Ray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Martin+Ray
# Retrieving Results for Mazzocco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mazzocco
# Retrieving Results for MCV.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=MCV
# Retrieving Results for Midnight.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Midnight
# Retrieving Results for Paraduxx.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paraduxx
# Retrieving Results for Psagot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Psagot
# Retrieving Results for Quinta de Foz de Arouce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+de+Foz+de+Arouce
# Retrieving Results for Carlos Moro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Carlos+Moro
# Retrieving Results for Cave de Tain.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cave+de+Tain
# Retrieving Results for Chalk Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chalk+Hill
# Retrieving Results for Château Maucoil.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Maucoil
# Retrieving Results for Conn Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Conn+Creek
# Retrieving Results for De Wetshof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=De+Wetshof
# Retrieving Results for DeMorgenzon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=DeMorgenzon
# Retrieving Results for Derby.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Derby
# Retrieving Results for Dr. Loosen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Loosen
# Retrieving Results for Dr. Loosen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Loosen
# Retrieving Results for Dunstan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dunstan
# Retrieving Results for Woodward Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Woodward+Canyon
# Retrieving Results for Fritz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fritz
# Retrieving Results for Balboa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Balboa
# Retrieving Results for Winkler-Hermaden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Winkler-Hermaden
# Retrieving Results for J. & F. Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+%26+F.+Lurton
# Retrieving Results for J. & F. Lurton.
# used region as search
# Retrieving Results for Dr. Loosen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Loosen
# Retrieving Results for Nicholas Cole Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Nicholas+Cole+Cellars
# Retrieving Results for Nicholas Cole Cellars.
# used region as search
# Retrieving Results for Pali.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pali
# Retrieving Results for Ricardo Santos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ricardo+Santos
# Retrieving Results for Sattlerhof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sattlerhof
# Retrieving Results for Stephan Ehlen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stephan+Ehlen
# Retrieving Results for Stephan Ehlen.
# used region as search
# Retrieving Results for Dr. Pauly Bergweiler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Pauly+Bergweiler
# Retrieving Results for O. Fournier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=O.+Fournier
# Retrieving Results for Reininger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Reininger
# Retrieving Results for Tamarack Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tamarack+Cellars
# Retrieving Results for Torres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Torres
# Retrieving Results for Col Vetoraz Spumanti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Col+Vetoraz+Spumanti
# Retrieving Results for Costaval.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Costaval
# Retrieving Results for Costaval.
# used region as search
# Retrieving Results for Henri de Villamont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Henri+de+Villamont
# Retrieving Results for Andeluna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Andeluna
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Br%C3%BCndlmayer
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Br%C3%BCndlmayer
# Retrieving Results for Va Piano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Va+Piano
# Retrieving Results for Bouchard Père & Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bouchard+P%C3%A8re+%26+Fils
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Br%C3%BCndlmayer
# Retrieving Results for Chakana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chakana
# Retrieving Results for Schloss Halbturn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Schloss+Halbturn
# Retrieving Results for Standish.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Standish
# Retrieving Results for Apriori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Apriori
# Retrieving Results for Arrowood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Arrowood
# Retrieving Results for Baglio del Cristo di Campobello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Baglio+del+Cristo+di+Campobello
# Retrieving Results for Barkan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barkan
# Retrieving Results for Birichino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Birichino
# Retrieving Results for Bischöfliche Weingüter Trier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bisch%C3%B6fliche+Weing%C3%BCter+Trier
# Retrieving Results for Feudo Principi di Butera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Feudo+Principi+di+Butera
# Retrieving Results for Finca Las Moras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Las+Moras
# Retrieving Results for Flora Springs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Flora+Springs
# Retrieving Results for Hendry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hendry
# Retrieving Results for Henri Schoenheitz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Henri+Schoenheitz
# Retrieving Results for Houdini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Houdini
# Retrieving Results for Mills Reef.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mills+Reef
# Retrieving Results for Ara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ara
# Retrieving Results for Dog Point.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dog+Point
# Retrieving Results for Esk Valley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Esk+Valley
# Retrieving Results for Viñedos Real Rubio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1edos+Real+Rubio
# Retrieving Results for Babich.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Babich
# Retrieving Results for Cave de Turckheim.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cave+de+Turckheim
# Retrieving Results for Caves Transmontanas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Caves+Transmontanas
# Retrieving Results for Caves Transmontanas.
# used region as search
# Retrieving Results for COS.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=COS
# Retrieving Results for Cusumano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cusumano
# Retrieving Results for Dalton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dalton
# Retrieving Results for Domaine Rieflé-Landmann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Riefl%C3%A9-Landmann
# Retrieving Results for Dr. H. Thanisch (Erben Müller-Burggraef).
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+H.+Thanisch+%28Erben+M%C3%BCller-Burggraef%29
# Retrieving Results for Citation.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Citation
# Retrieving Results for Domaine Gresser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Gresser
# Retrieving Results for Domaine Marcel Deiss.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Marcel+Deiss
# Retrieving Results for Domaine Schoffit.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Schoffit

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('10coord.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 country  \
# 0      108878        117018          117018      US
# 1      108879        117019          117019   Spain
# 2      108880        117020          117020   Spain
# 3      108881        117021          117021   Spain
# 4      108882        117022          117022      US
#
#                                          description          designation  \
# 0        Smells raisiny, feels hot, tastes overripe.      Imagine Reserve
# 1  Powdery and oaky smelling, with not much fruit...                  NaN
# 2  Gritty cherry and plum aromas lead into a shee...  Cantos de Valpiedra
# 3  Stalky smelling, with a minerally streak. Feel...               Serres
# 4  A big, thick, somewhat dull wine, with candied...                  NaN
#
#    points  price        province              region_1       region_2  \
# 0      81   62.0      California  Santa Barbara County  Central Coast
# 1      81   14.0  Northern Spain               Navarra            NaN
# 2      81   21.0  Northern Spain                 Rioja            NaN
# 3      81   10.0  Northern Spain                 Rioja            NaN
# 4      81   19.0      California         Sonoma County         Sonoma
#
#          taster_name taster_twitter_handle  \
# 0                NaN                   NaN
# 1  Michael Schachner           @wineschach
# 2  Michael Schachner           @wineschach
# 3  Michael Schachner           @wineschach
# 4                NaN                   NaN
#
#                                                title             variety  \
# 0  Hunt Cellars 2009 Imagine Reserve Pinot Noir (...          Pinot Noir
# 1              Vega Sindoa 2010 Chardonnay (Navarra)          Chardonnay
# 2  Finca Valpiedra 2008 Cantos de Valpiedra  (Rioja)         Tempranillo
# 3            Carlos Serres 2010 Serres Viura (Rioja)               Viura
# 4  Hideaway Creek 2007 Cabernet Sauvignon (Sonoma...  Cabernet Sauvignon
#
#             winery        Lat         Lng  heat weights
# 0     Hunt Cellars  35.566526 -120.745808             1
# 1      Vega Sindoa  42.695391   -1.676069             1
# 2  Finca Valpiedra  42.495639   -2.608177             1
# 3    Carlos Serres  42.568149   -2.861762             1
# 4   Hideaway Creek  29.516886  -98.733364             1

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
