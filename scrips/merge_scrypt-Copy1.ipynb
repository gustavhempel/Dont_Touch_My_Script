# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key

# %%
file = 'res/1_2.csv'
df = pd.read_csv(file)

file1 = 'res/3coord.csv'
df1 = pd.read_csv(file1)

file2 = 'res/4coord.csv'
df2 = pd.read_csv(file2)

file4 = 'res/5coord.csv'
df4 = pd.read_csv(file4)

file5 = 'res/6coord.csv'
df5 = pd.read_csv(file5)

file6 = 'res/7coord.csv'
df6 = pd.read_csv(file6)

file7 = 'res/8coord.csv'
df7 = pd.read_csv(file7)

file8 = 'res/9coord.csv'
df8 = pd.read_csv(file8)

file9 = 'res/10coord.csv'
df9 = pd.read_csv(file9)

# %%
new_df = pd.concat([df,df1,df2,df4,df5,df6,df7,df8,df9], join='outer')
new_df.head()
new_df = new_df.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1','Unnamed: 0.1.1.1','region_2'])
new_df['year'] = new_df['title']


new_df.head()
# Out:
#     country                                        description  \
# 0  Portugal  This is ripe and fruity, a wine that is smooth...
# 1        US  Tart and snappy, the flavors of lime flesh and...
# 2        US  Pineapple rind, lemon pith and orange blossom ...
# 3        US  Much like the regular bottling from 2012, this...
# 4     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1         taster_name taster_twitter_handle  \
# 0                  NaN          Roger Voss            @vossroger
# 1    Willamette Valley        Paul Gregutt           @paulgwine
# 2  Lake Michigan Shore  Alexander Peartree                   NaN
# 3    Willamette Valley        Paul Gregutt           @paulgwine
# 4              Navarra   Michael Schachner           @wineschach
#
#                                                title             variety  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 2  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 4  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
#
#                 winery        Lat         Lng  heat weights  \
# 0  Quinta dos Avidagos  41.387933   -7.276971             7
# 1            Rainstorm  40.089829  -88.248177             7
# 2           St. Julian  42.212252  -85.891725             7
# 3         Sweet Cheeks  42.343889  -71.101111             7
# 4               Tandem  32.905753 -117.230246             7
#
#                                                 year
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...

# %%
new_df['year'] = new_df['year'].str.extract('(\d+)')

# %%
new_df.to_csv('winedf2')

# %%
group_df = new_df.groupby(new_df['variety'])
group_mean = group_df.mean()
group_mean_price = group_mean.sort_values(by='price')
group_mean_points = group_mean.sort_values(by='points')
group_mean_price
# Out:
#                           points       price        Lat         Lng  \
# variety
# Trajadura              86.000000    7.000000  41.207587   -8.308216
# Malagouzia-Chardonnay  86.000000    8.000000  37.225606  -95.716202
# Macabeo-Moscatel       85.000000    8.000000  39.929755   -3.012023
# Shiraz-Tempranillo     82.000000    8.500000  35.779821  -58.875590
# Johannisberg Riesling  86.250000    8.875000  42.743756 -108.887464
# ...                          ...         ...        ...         ...
# Malbec-Cabernet        91.666667  113.333333  16.631590  -77.746702
# Rosenmuskateller       92.000000  150.000000  45.784283 -108.520048
# Francisa               91.000000  160.000000  21.538743   82.168644
# Terrantez              95.000000  236.000000  39.063792  -78.065266
# Ramisco                93.000000  495.000000  38.795634   -9.470396
#
#                        heat weights
# variety
# Trajadura                  6.000000
# Malagouzia-Chardonnay      6.000000
# Macabeo-Moscatel           5.000000
# Shiraz-Tempranillo         2.000000
# Johannisberg Riesling      6.250000
# ...                             ...
# Malbec-Cabernet           11.666667
# Rosenmuskateller          12.000000
# Francisa                  11.000000
# Terrantez                 15.000000
# Ramisco                   13.000000
#
# [694 rows x 5 columns]

# %%
group_mean_points
# Out:
#                         points  price        Lat         Lng  heat weights
# variety
# Chancellor           80.500000   16.0  40.394104  -81.916138      0.500000
# Airen                81.666667    9.0  41.538212   -2.911664      1.666667
# Picapoll             82.000000   21.0  41.864185    1.972414      2.000000
# Shiraz-Tempranillo   82.000000    8.5  35.779821  -58.875590      2.000000
# Aidani               82.000000   27.0  43.679592 -114.362361      2.000000
# ...                        ...    ...        ...         ...           ...
# Riesling-Chardonnay  94.000000   40.0  40.945028  -72.277470     14.000000
# Bual                 94.333333  100.0  38.144699  -86.890734     14.333333
# Tinta del Pais       95.000000   47.5  42.029839  -37.711981     15.000000
# Terrantez            95.000000  236.0  39.063792  -78.065266     15.000000
# Gelber Traminer      95.000000   35.0  48.406135   15.589728     15.000000
#
# [694 rows x 5 columns]

# %%
group_pnt_df = new_df.groupby(new_df['points'])

# %%
group_pnt = group_pnt_df.count()
group_pnt.plot(kind='bar',legend=False)

# %%
group_prc_df = new_df.groupby(new_df['price'])
group_price = group_prc_df.count()
group_price.plot()

# %%
#base_url =f'http://climateapi.scottpinkelman.com/api/v1/location/{latitude}/{logintitude}'
    
#response = requests.get(base_url)
#print(response.url)
#places_data = response.json()
#places_data
for index, row in new_df.iterrows():
    latitute = row['Lat']
    logintitude = row['Lng']
    print(f"Retrieving Results for {row['winery']}.")
    base_url =f'http://climateapi.scottpinkelman.com/api/v1/location/{latitute}/{logintitude}'
    response = requests.get(base_url)
    print(response.url)
    
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['return_values'][0]
        #print(results)
        zone = results['koppen_geiger_zone']
        zone_desc = results['zone_description']
        print(zone)
        df.loc[index, 'Climate Zone'] = zone
        df.loc[index, 'Climate Zone Desc.'] = zone_desc
        
        
        
    except:
        print("Could not identify the Climate Zone.")
# Out:
# Retrieving Results for Quinta dos Avidagos.
# http://climateapi.scottpinkelman.com/api/v1/location/41.3879331/-7.276971400000001
# Csb
# Retrieving Results for Rainstorm.
# http://climateapi.scottpinkelman.com/api/v1/location/40.08982879999999/-88.2481766
# Dfa
# Retrieving Results for St. Julian.
# http://climateapi.scottpinkelman.com/api/v1/location/42.21225219999999/-85.89172479999998
# Dfa
# Retrieving Results for Sweet Cheeks.
# http://climateapi.scottpinkelman.com/api/v1/location/42.343888899999996/-71.1011111
# Dfa
# Retrieving Results for Tandem.
# http://climateapi.scottpinkelman.com/api/v1/location/32.9057531/-117.2302457
# BSk
# Retrieving Results for Terre di Giurfo.
# http://climateapi.scottpinkelman.com/api/v1/location/37.1112433/14.632728699999998
# Csa
# Retrieving Results for Trimbach.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1949046/7.3260159
# Cfb
# Retrieving Results for Heinz Eifel.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Jean-Baptiste Adam.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1265682/7.283714199999999
# Cfb
# Retrieving Results for Kirkland Signature.
# http://climateapi.scottpinkelman.com/api/v1/location/38.502468900000004/-122.26538870000002
# Csb
# Retrieving Results for Leon Beyer.
# http://climateapi.scottpinkelman.com/api/v1/location/48.0425465/7.306561599999998
# Cfb
# Retrieving Results for Louis M. Martini.
# http://climateapi.scottpinkelman.com/api/v1/location/38.491074/-122.452179
# Csb
# Retrieving Results for Mirassou.
# http://climateapi.scottpinkelman.com/api/v1/location/25.9432844/-80.296723
# Am
# Retrieving Results for Richard Böcking.
# http://climateapi.scottpinkelman.com/api/v1/location/49.947177200000006/7.1121360000000005
# Cfb
# Retrieving Results for Felix Lavaque.
# http://climateapi.scottpinkelman.com/api/v1/location/-26.073079800000002/-65.976052
# Cwb
# Retrieving Results for Gaucho Andino.
# http://climateapi.scottpinkelman.com/api/v1/location/-32.8894587/-68.8458386
# BWk
# Retrieving Results for Pradorey.
# http://climateapi.scottpinkelman.com/api/v1/location/41.7007585/-3.7948873999999995
# Csb
# Retrieving Results for Quiévremont.
# http://climateapi.scottpinkelman.com/api/v1/location/38.689546299999996/-78.2116796
# Cfa
# Retrieving Results for Quiévremont.
# http://climateapi.scottpinkelman.com/api/v1/location/38.689546299999996/-78.2116796
# Cfa
# Retrieving Results for Acrobat.
# http://climateapi.scottpinkelman.com/api/v1/location/30.217050699999998/-97.7432426
# Cfa
# Retrieving Results for Baglio di Pianetto.
# http://climateapi.scottpinkelman.com/api/v1/location/37.9881256/13.349254
# Csa
# Retrieving Results for Bianchi.
# http://climateapi.scottpinkelman.com/api/v1/location/33.9030556/-118.16305559999999
# BSk
# Retrieving Results for Canicattì.
# http://climateapi.scottpinkelman.com/api/v1/location/37.358178499999994/13.8506902
# Csa
# Retrieving Results for Castello di Amorosa.
# http://climateapi.scottpinkelman.com/api/v1/location/38.5584735/-122.542594
# Csb
# Retrieving Results for Stemmari.
# http://climateapi.scottpinkelman.com/api/v1/location/37.5999938/14.0153557
# Csa
# Retrieving Results for Stemmari.
# http://climateapi.scottpinkelman.com/api/v1/location/37.5999938/14.0153557
# Csa
# Retrieving Results for Terre di Giurfo.
# http://climateapi.scottpinkelman.com/api/v1/location/37.1112433/14.632728699999998
# Csa
# Retrieving Results for Clarksburg Wine Company.
# http://climateapi.scottpinkelman.com/api/v1/location/38.422495/-121.53245690000001
# Csa
# Retrieving Results for Envolve.
# http://climateapi.scottpinkelman.com/api/v1/location/35.959079200000005/-77.80227690000001
# Cfa
# Retrieving Results for Envolve.
# http://climateapi.scottpinkelman.com/api/v1/location/35.959079200000005/-77.80227690000001
# Cfa
# Retrieving Results for Erath.
# http://climateapi.scottpinkelman.com/api/v1/location/29.958261100000005/-92.0359562
# Cfa
# Retrieving Results for Estampa.
# http://climateapi.scottpinkelman.com/api/v1/location/34.2385842/-118.5715405
# Csb
# Retrieving Results for Feudi del Pisciotto.
# http://climateapi.scottpinkelman.com/api/v1/location/37.11545/14.41194
# Csa
# Retrieving Results for Feudi di San Marzano.
# http://climateapi.scottpinkelman.com/api/v1/location/34.013273600000005/-118.494651
# Csb
# Retrieving Results for Feudo di Santa Tresa.
# http://climateapi.scottpinkelman.com/api/v1/location/37.00781/14.522807
# Csa
# Retrieving Results for Feudo Montoni.
# http://climateapi.scottpinkelman.com/api/v1/location/38.1484333/13.336050199999997
# Csa
# Retrieving Results for Hawkins Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/45.275971999999996/-123.01341699999999
# Csb
# Retrieving Results for Henry Fessy.
# http://climateapi.scottpinkelman.com/api/v1/location/46.121562/4.6996097
# Cfb
# Retrieving Results for Robert Hall.
# http://climateapi.scottpinkelman.com/api/v1/location/35.6438088/-120.63351709999999
# Csb
# Retrieving Results for Sundance.
# http://climateapi.scottpinkelman.com/api/v1/location/37.9650132/-122.50886259999999
# Csb
# Retrieving Results for Tarara.
# http://climateapi.scottpinkelman.com/api/v1/location/39.23371289999999/-77.48196
# Cfa
# Retrieving Results for Tasca d'Almerita.
# http://climateapi.scottpinkelman.com/api/v1/location/37.7182588/13.828726699999999
# Csa
# Retrieving Results for The White Knight.
# http://climateapi.scottpinkelman.com/api/v1/location/38.631572600000005/-90.205776
# Cfa
# Retrieving Results for Trump.
# http://climateapi.scottpinkelman.com/api/v1/location/41.888868/-87.62639399999999
# Dfa
# Retrieving Results for Vignerons de Bel Air.
# http://climateapi.scottpinkelman.com/api/v1/location/46.1156149/4.7100956
# Cfb
# Retrieving Results for Casa Silva.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.538579/-70.966841
# Csb
# Retrieving Results for Cantine di Dolianova.
# http://climateapi.scottpinkelman.com/api/v1/location/39.358059000000004/9.1637732
# Csa
# Retrieving Results for Château de Sours.
# http://climateapi.scottpinkelman.com/api/v1/location/48.417398999999996/1.595292
# Cfb
# Retrieving Results for RustRidge.
# http://climateapi.scottpinkelman.com/api/v1/location/38.52847/-122.31807690000001
# Csb
# Retrieving Results for Souverain.
# http://climateapi.scottpinkelman.com/api/v1/location/38.76285/-122.9740338
# Csb
# Retrieving Results for Tasca d'Almerita.
# http://climateapi.scottpinkelman.com/api/v1/location/38.1016773/13.328935699999999
# Csa
# Retrieving Results for Tres Palacios.
# http://climateapi.scottpinkelman.com/api/v1/location/28.687790000000003/-96.2216678
# Cfa
# Retrieving Results for Mellisoni.
# http://climateapi.scottpinkelman.com/api/v1/location/47.8352538/-120.0690355
# Dsb
# Retrieving Results for Okapi.
# http://climateapi.scottpinkelman.com/api/v1/location/40.758303600000005/-73.98118620000001
# Cfa
# Retrieving Results for Podere dal Nespoli.
# http://climateapi.scottpinkelman.com/api/v1/location/44.0377762/11.994815199999998
# Cfb
# Retrieving Results for Ram.
# http://climateapi.scottpinkelman.com/api/v1/location/32.764449400000004/-97.0962301
# Cfa
# Retrieving Results for Roland Champion.
# http://climateapi.scottpinkelman.com/api/v1/location/49.025356/4.0132132999999985
# Cfb
# Retrieving Results for Sevtap.
# http://climateapi.scottpinkelman.com/api/v1/location/34.595350399999994/-120.14143020000002
# Csb
# Retrieving Results for Simonnet-Febvre.
# http://climateapi.scottpinkelman.com/api/v1/location/47.7600133/3.6906189
# Cfb
# Retrieving Results for Vignerons des Terres Secrètes.
# http://climateapi.scottpinkelman.com/api/v1/location/46.3219516/4.7533477999999985
# Cfb
# Retrieving Results for Basel Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/46.0176661/-118.39593300000001
# Csa
# Retrieving Results for Cocobon.
# http://climateapi.scottpinkelman.com/api/v1/location/34.504006/-82.650689
# Cfa
# Retrieving Results for Collet.
# http://climateapi.scottpinkelman.com/api/v1/location/34.0702435/-84.29317459999999
# Cfa
# Retrieving Results for Drumheller.
# http://climateapi.scottpinkelman.com/api/v1/location/51.4619484/-112.7107576
# Dfb
# Retrieving Results for Eco Terreno.
# http://climateapi.scottpinkelman.com/api/v1/location/38.2820218/-122.4598824
# Csb
# Retrieving Results for Grifalco.
# http://climateapi.scottpinkelman.com/api/v1/location/40.968593/15.8508855
# Csb
# Retrieving Results for Hindsight.
# http://climateapi.scottpinkelman.com/api/v1/location/28.8634581/-82.01574670000001
# Cfa
# Retrieving Results for Hindsight.
# http://climateapi.scottpinkelman.com/api/v1/location/28.8634581/-82.01574670000001
# Cfa
# Retrieving Results for Mulvane Wine Co..
# http://climateapi.scottpinkelman.com/api/v1/location/37.475493/-97.3241166
# Cfa
# Retrieving Results for Schmitt Söhne.
# http://climateapi.scottpinkelman.com/api/v1/location/39.093810600000005/-76.63212209999998
# Cfa
# Retrieving Results for Yalumba.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.5131355/139.0565116
# BSk
# Retrieving Results for Z'IVO.
# http://climateapi.scottpinkelman.com/api/v1/location/45.127568100000005/-123.1187881
# Csb
# Retrieving Results for Aresti.
# http://climateapi.scottpinkelman.com/api/v1/location/32.470674/-97.559511
# Cfa
# Retrieving Results for Spyro.
# http://climateapi.scottpinkelman.com/api/v1/location/41.0541667/-85.2261111
# Dfa
# Retrieving Results for Lionel Osmin & Cie.
# http://climateapi.scottpinkelman.com/api/v1/location/43.326190000000004/-0.3296535
# Cfb
# Retrieving Results for Mitolo.
# http://climateapi.scottpinkelman.com/api/v1/location/41.024063899999994/-80.61693100000001
# Dfb
# Retrieving Results for Napa Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/38.4212828/-122.3900237
# Csb
# Retrieving Results for P.J. Valckenberg.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Palencia.
# http://climateapi.scottpinkelman.com/api/v1/location/42.0096857/-4.5288015999999995
# Csb
# Retrieving Results for Passaggio.
# http://climateapi.scottpinkelman.com/api/v1/location/38.2916223/-122.4572729
# Csb
# Retrieving Results for Poggio Alloro.
# http://climateapi.scottpinkelman.com/api/v1/location/43.4880136/11.0651513
# Cfa
# Retrieving Results for Fattoria Sardi.
# http://climateapi.scottpinkelman.com/api/v1/location/43.8763845/10.5035337
# Cfb
# Retrieving Results for Ferrari-Carano.
# http://climateapi.scottpinkelman.com/api/v1/location/38.7113931/-122.97829660000001
# Csb
# Retrieving Results for Folie à Deux.
# http://climateapi.scottpinkelman.com/api/v1/location/38.42112720000001/-122.39027709999999
# Csb
# Retrieving Results for Franciscan.
# http://climateapi.scottpinkelman.com/api/v1/location/39.967727000000004/-86.15883699999998
# Cfa
# Retrieving Results for Fuchs.
# http://climateapi.scottpinkelman.com/api/v1/location/39.0615138/-94.78402890000001
# Cfa
# Retrieving Results for Gård.
# http://climateapi.scottpinkelman.com/api/v1/location/43.94469960000001/4.151376399999999
# Csa
# Retrieving Results for Henry Fessy.
# http://climateapi.scottpinkelman.com/api/v1/location/46.121562/4.6996097
# Cfb
# Retrieving Results for Henry Fessy.
# http://climateapi.scottpinkelman.com/api/v1/location/46.121562/4.6996097
# Cfb
# Retrieving Results for Heron Hill.
# http://climateapi.scottpinkelman.com/api/v1/location/42.4498966/-77.201624
# Dfb
# Retrieving Results for Serpaia di Endrizzi.
# http://climateapi.scottpinkelman.com/api/v1/location/42.6877372/11.3327819
# Csa
# Retrieving Results for Soquel Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/37.0295161/-121.93386670000001
# Csb
# Retrieving Results for Ventosa.
# http://climateapi.scottpinkelman.com/api/v1/location/42.857164000000004/-76.936131
# Dfb
# Retrieving Results for Lamoreaux Landing.
# http://climateapi.scottpinkelman.com/api/v1/location/42.57663180000001/-76.8584529
# Dfb
# Retrieving Results for Lamoreaux Landing.
# http://climateapi.scottpinkelman.com/api/v1/location/42.57663180000001/-76.8584529
# Dfb
# Retrieving Results for Leyda.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.61315740000001/-71.4501843
# Csb
# Retrieving Results for Madonna Alta.
# http://climateapi.scottpinkelman.com/api/v1/location/43.1026405/12.369592599999999
# Cfb
# Retrieving Results for Marchesi Antinori.
# http://climateapi.scottpinkelman.com/api/v1/location/43.6153804/11.1919579
# Cfb
# Retrieving Results for Marchesi de' Frescobaldi.
# http://climateapi.scottpinkelman.com/api/v1/location/43.770511/11.470005
# Cfb
# Retrieving Results for Marchesi de' Frescobaldi.
# http://climateapi.scottpinkelman.com/api/v1/location/43.770511/11.470005
# Cfb
# Retrieving Results for Martin Ranch.
# http://climateapi.scottpinkelman.com/api/v1/location/37.040317200000004/-121.7114895
# Csb
# Retrieving Results for Ornellaia.
# http://climateapi.scottpinkelman.com/api/v1/location/40.76295/-73.96930499999998
# Cfa
# Retrieving Results for Pardon et Fils.
# http://climateapi.scottpinkelman.com/api/v1/location/46.147718/4.597989099999999
# Cfb
# Retrieving Results for Piña.
# http://climateapi.scottpinkelman.com/api/v1/location/38.467065500000004/-122.3780446
# Csb
# Retrieving Results for Podere Ciona.
# http://climateapi.scottpinkelman.com/api/v1/location/43.476413/11.456984
# Cfa
# Retrieving Results for Poggioventoso.
# http://climateapi.scottpinkelman.com/api/v1/location/42.906521600000005/10.968290300000001
# Csa
# Retrieving Results for Pull.
# http://climateapi.scottpinkelman.com/api/v1/location/30.337263399999998/-81.7696935
# Cfa
# Retrieving Results for Pull.
# http://climateapi.scottpinkelman.com/api/v1/location/30.337263399999998/-81.7696935
# Cfa
# Retrieving Results for R2.
# http://climateapi.scottpinkelman.com/api/v1/location/41.90397120000001/-87.65638570000002
# Dfa
# Retrieving Results for Rideau.
# http://climateapi.scottpinkelman.com/api/v1/location/34.628281/-120.114814
# Csb
# Retrieving Results for Tenuta Forconi.
# http://climateapi.scottpinkelman.com/api/v1/location/43.696166/10.989761
# Cfb
# Retrieving Results for Dopff & Irion.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1662821/7.299018599999999
# Cfb
# Retrieving Results for Ceretto.
# http://climateapi.scottpinkelman.com/api/v1/location/44.6722222/7.996388900000001
# Cfa
# Retrieving Results for Matrix.
# http://climateapi.scottpinkelman.com/api/v1/location/36.2335662/-95.7463989
# Cfa
# Retrieving Results for Mauritson.
# http://climateapi.scottpinkelman.com/api/v1/location/38.650488/-122.912031
# Csb
# Retrieving Results for Henry's Drive Vignerons.
# http://climateapi.scottpinkelman.com/api/v1/location/47.463691/3.76951
# Cfb
# Retrieving Results for Silverado.
# http://climateapi.scottpinkelman.com/api/v1/location/29.552111800000002/-98.6716162
# Cfa
# Retrieving Results for Le Riche.
# http://climateapi.scottpinkelman.com/api/v1/location/39.085029399999996/-94.5810042
# Cfa
# Retrieving Results for Pierre Sparr.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1589834/7.326862200000001
# Cfb
# Retrieving Results for Pierre Sparr.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1589834/7.326862200000001
# Cfb
# Retrieving Results for Kuentz-Bas.
# http://climateapi.scottpinkelman.com/api/v1/location/48.0349643/7.280920699999998
# Cfb
# Retrieving Results for Camberley.
# http://climateapi.scottpinkelman.com/api/v1/location/51.335389899999996/-0.7428560000000001
# Cfb
# Retrieving Results for Ceretto.
# http://climateapi.scottpinkelman.com/api/v1/location/44.6722222/7.996388900000001
# Cfa
# Retrieving Results for Dopff & Irion.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1662821/7.299018599999999
# Cfb
# Retrieving Results for Delheim.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.870379/18.885578
# Csa
# Retrieving Results for Poderi Luigi Einaudi.
# http://climateapi.scottpinkelman.com/api/v1/location/44.5182621/7.9516738999999985
# Cfa
# Retrieving Results for Clark-Clauden.
# http://climateapi.scottpinkelman.com/api/v1/location/38.502468900000004/-122.26538870000002
# Csb
# Retrieving Results for Giacomo Ascheri.
# http://climateapi.scottpinkelman.com/api/v1/location/44.692088/7.8478
# Cfa
# Retrieving Results for Lassègue.
# http://climateapi.scottpinkelman.com/api/v1/location/26.1346672/-80.1414839
# Am
# Retrieving Results for Dopff & Irion.
# http://climateapi.scottpinkelman.com/api/v1/location/48.1662821/7.299018599999999
# Cfb
# Retrieving Results for Kuentz-Bas.
# http://climateapi.scottpinkelman.com/api/v1/location/48.0349643/7.280920699999998
# Cfb
# Retrieving Results for Poderi Colla.
# http://climateapi.scottpinkelman.com/api/v1/location/44.671898/8.07356
# Cfb
# Retrieving Results for Giacomo Ascheri.
# http://climateapi.scottpinkelman.com/api/v1/location/44.692088/7.8478
# Cfa
# Retrieving Results for Banyan.
# http://climateapi.scottpinkelman.com/api/v1/location/26.1929849/-80.17024040000001
# Am
# Retrieving Results for Domaine Zind-Humbrecht.
# http://climateapi.scottpinkelman.com/api/v1/location/48.083828600000004/7.295686999999999
# Cfb
# Retrieving Results for Terra Valentine.
# http://climateapi.scottpinkelman.com/api/v1/location/38.5229576/-122.54896389999999
# Csb
# Retrieving Results for Testarossa.
# http://climateapi.scottpinkelman.com/api/v1/location/37.21347799999999/-121.981544
# Csb
# Retrieving Results for Vincent Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/34.652697499999995/-120.0948277
# Csb
# Retrieving Results for Vincent Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/34.652697499999995/-120.0948277
# Csb
# Retrieving Results for Weingut Liebfrauenstift.
# http://climateapi.scottpinkelman.com/api/v1/location/49.638290000000005/8.36892
# Cfb
# Retrieving Results for Wrath.
# http://climateapi.scottpinkelman.com/api/v1/location/36.40920699999999/-121.38520700000001
# Csb
# Retrieving Results for Yardstick.
# http://climateapi.scottpinkelman.com/api/v1/location/37.371094/-121.925574
# Csb
# Retrieving Results for Herdade Grande.
# http://climateapi.scottpinkelman.com/api/v1/location/38.1874922/-7.8383587000000015
# Csa
# Retrieving Results for Albatross Ridge.
# http://climateapi.scottpinkelman.com/api/v1/location/36.4777986/-121.72905279999999
# Csb
# Retrieving Results for Alta Colina.
# http://climateapi.scottpinkelman.com/api/v1/location/35.650182/-120.7449239
# Csb
# Retrieving Results for Big Basin.
# http://climateapi.scottpinkelman.com/api/v1/location/37.171628399999996/-122.2227571
# Csb
# Retrieving Results for Carl Graff.
# http://climateapi.scottpinkelman.com/api/v1/location/42.035688799999996/-87.77794990000001
# Dfa
# Retrieving Results for Casa Santa Vitória.
# http://climateapi.scottpinkelman.com/api/v1/location/37.891133700000005/-8.020334700000001
# Csa
# Retrieving Results for Castello di Gabbiano.
# http://climateapi.scottpinkelman.com/api/v1/location/45.15922929999999/8.1930017
# Cfa
# Retrieving Results for Château Vincens.
# http://climateapi.scottpinkelman.com/api/v1/location/44.4559157/1.2803746
# Cfb
# Retrieving Results for Chronic Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/35.6743698/-120.7302499
# Csb
# Retrieving Results for Claiborne & Churchill.
# http://climateapi.scottpinkelman.com/api/v1/location/35.1981121/-120.6051883
# Csb
# Retrieving Results for Conde de Velázquez.
# http://climateapi.scottpinkelman.com/api/v1/location/31.4812327/-100.4243572
# Cfa
# Retrieving Results for Cono Sur.
# http://climateapi.scottpinkelman.com/api/v1/location/35.3884238/-82.5663345
# Cfb
# Retrieving Results for Domaine Berthoumieu.
# http://climateapi.scottpinkelman.com/api/v1/location/43.611784/-0.123643
# Cfb
# Retrieving Results for Dracaena.
# http://climateapi.scottpinkelman.com/api/v1/location/35.6368759/-120.65450220000001
# Csb
# Retrieving Results for Duckhorn.
# http://climateapi.scottpinkelman.com/api/v1/location/38.5294533/-122.4908152
# Csb
# Retrieving Results for Dutton-Goldfield.
# http://climateapi.scottpinkelman.com/api/v1/location/38.43728979999999/-122.85833329999998
# Csb
# Retrieving Results for Fritz Haag.
# http://climateapi.scottpinkelman.com/api/v1/location/49.9075335/6.9857475
# Cfb
# Retrieving Results for Fritz Haag.
# http://climateapi.scottpinkelman.com/api/v1/location/49.9075335/6.9857475
# Cfb
# Retrieving Results for G7.
# http://climateapi.scottpinkelman.com/api/v1/location/36.7270234/-96.20558390000001
# Cfa
# Retrieving Results for Le Cadeau.
# http://climateapi.scottpinkelman.com/api/v1/location/45.272490000000005/-123.01619109999999
# Csb
# Retrieving Results for Stoneleigh.
# http://climateapi.scottpinkelman.com/api/v1/location/39.3021196/-94.9360666
# Cfa
# Retrieving Results for Tenuta Peter Sölva & Söhne.
# http://climateapi.scottpinkelman.com/api/v1/location/46.4118499/11.2435894
# Dfb
# Retrieving Results for TerraMater.
# http://climateapi.scottpinkelman.com/api/v1/location/33.775785/-84.293741
# Cfa
# Retrieving Results for Isole e Olena.
# http://climateapi.scottpinkelman.com/api/v1/location/43.5044444/11.2372222
# Cfb
# Retrieving Results for Kenwood.
# http://climateapi.scottpinkelman.com/api/v1/location/38.832514/-97.600814
# Cfa
# Retrieving Results for La Chablisienne.
# http://climateapi.scottpinkelman.com/api/v1/location/47.812268100000004/3.7950068
# Cfb
# Retrieving Results for Manzoni.
# http://climateapi.scottpinkelman.com/api/v1/location/36.4722855/-121.4676372
# Csb
# Retrieving Results for McIntyre Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/36.537164000000004/-121.908697
# Csb
# Retrieving Results for Alamos.
# http://climateapi.scottpinkelman.com/api/v1/location/27.0254869/-108.941309
# Csa
# Retrieving Results for Anaba.
# http://climateapi.scottpinkelman.com/api/v1/location/35.864261/-84.06413900000003
# Cfa
# Retrieving Results for Apaltagua.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.622309200000004/-71.26564690000001
# Csb
# Retrieving Results for Harrington.
# http://climateapi.scottpinkelman.com/api/v1/location/42.653580600000005/-83.25589690000001
# Dfb
# Retrieving Results for Abbazia Santa Anastasia.
# http://climateapi.scottpinkelman.com/api/v1/location/37.9724968/14.0849294
# Csa
# Retrieving Results for Viña Bisquertt.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.3929354/-70.6169695
# Csb
# Retrieving Results for Emiliana.
# http://climateapi.scottpinkelman.com/api/v1/location/32.0889663/-116.6406622
# BSk
# Retrieving Results for Fattoria Alois.
# http://climateapi.scottpinkelman.com/api/v1/location/40.542787/-74.16409
# Cfa
# Retrieving Results for Henry's Drive Vignerons.
# http://climateapi.scottpinkelman.com/api/v1/location/47.463691/3.76951
# Cfb
# Retrieving Results for Aldegheri.
# http://climateapi.scottpinkelman.com/api/v1/location/45.5153297/10.8347666
# Cfb
# Retrieving Results for Bertrand Ambroise.
# http://climateapi.scottpinkelman.com/api/v1/location/46.99825800000001/4.708748
# Cfb
# Retrieving Results for Carpineto.
# http://climateapi.scottpinkelman.com/api/v1/location/43.595557/11.3860055
# Cfb
# Retrieving Results for Cesani.
# http://climateapi.scottpinkelman.com/api/v1/location/43.505696/11.002787
# Cfb
# Retrieving Results for Spier.
# http://climateapi.scottpinkelman.com/api/v1/location/31.835041999999998/-106.562424
# BWk
# Retrieving Results for Sequum.
# http://climateapi.scottpinkelman.com/api/v1/location/38.4985372/-122.45626329999999
# Csb
# Retrieving Results for Sierra Starr.
# http://climateapi.scottpinkelman.com/api/v1/location/39.21921270000001/-121.06289050000001
# Csa
# Retrieving Results for Terlan.
# http://climateapi.scottpinkelman.com/api/v1/location/46.5293309/11.2484293
# Dfc
# Retrieving Results for Yatir.
# http://climateapi.scottpinkelman.com/api/v1/location/31.347454/35.035536
# BSh
# Retrieving Results for Adega Cooperativa de Borba.
# http://climateapi.scottpinkelman.com/api/v1/location/38.8070655/-7.4629375
# Csa
# Retrieving Results for J. Lohr.
# http://climateapi.scottpinkelman.com/api/v1/location/35.69088199999999/-120.641421
# Csb
# Retrieving Results for J. Lohr.
# http://climateapi.scottpinkelman.com/api/v1/location/35.69088199999999/-120.641421
# Csb
# Retrieving Results for Courtney Benham.
# http://climateapi.scottpinkelman.com/api/v1/location/38.502468900000004/-122.26538870000002
# Csb
# Retrieving Results for Del Carlo Winery.
# http://climateapi.scottpinkelman.com/api/v1/location/38.6737658/-122.9366162
# Csb
# Retrieving Results for Delaire Graff.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.9219198/18.9228276
# Csa
# Retrieving Results for Domaine St Pierre.
# http://climateapi.scottpinkelman.com/api/v1/location/46.2210348/-72.9233728
# Dfb
# Retrieving Results for Eikendal.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.018882700000006/18.835113600000003
# Csb
# Retrieving Results for Famille Perrin.
# http://climateapi.scottpinkelman.com/api/v1/location/44.0557386/4.831910400000001
# Csa
# Retrieving Results for Matarromera.
# http://climateapi.scottpinkelman.com/api/v1/location/41.643012/-4.317947999999999
# Csb
# Retrieving Results for MCV.
# http://climateapi.scottpinkelman.com/api/v1/location/37.5430237/-77.4296035
# Cfa
# Retrieving Results for Mounts.
# http://climateapi.scottpinkelman.com/api/v1/location/36.06674599999999/-94.14603699999999
# Cfa
# Retrieving Results for Or Haganuz.
# http://climateapi.scottpinkelman.com/api/v1/location/33.005183/35.446736
# Csa
# Retrieving Results for Podere Scopetone.
# http://climateapi.scottpinkelman.com/api/v1/location/44.4235555/9.8901195
# Csb
# Retrieving Results for Quinta de Foz de Arouce.
# http://climateapi.scottpinkelman.com/api/v1/location/40.156514/-8.274113999999999
# Csb
# Retrieving Results for Robert Mondavi.
# http://climateapi.scottpinkelman.com/api/v1/location/38.4412684/-122.40980230000001
# Csb
# Retrieving Results for Samuel Tinon.
# http://climateapi.scottpinkelman.com/api/v1/location/48.243419700000004/21.432648899999997
# Cfb
# Retrieving Results for Sixteen by Twenty.
# http://climateapi.scottpinkelman.com/api/v1/location/41.9625914/-70.6693879
# Cfa
# Retrieving Results for St. Pauls.
# http://climateapi.scottpinkelman.com/api/v1/location/37.518034899999996/-95.1730355
# Cfa
# Retrieving Results for Mendel.
# http://climateapi.scottpinkelman.com/api/v1/location/41.920648/-88.33438100000001
# Dfa
# Retrieving Results for Oldenburg.
# http://climateapi.scottpinkelman.com/api/v1/location/53.1434501/8.214552099999999
# Cfb
# Retrieving Results for Oldenburg.
# http://climateapi.scottpinkelman.com/api/v1/location/53.1434501/8.214552099999999
# Cfb
# Retrieving Results for Wagner.
# http://climateapi.scottpinkelman.com/api/v1/location/40.6149557/-74.09438229999998
# Cfa
# Retrieving Results for Treleaven.
# http://climateapi.scottpinkelman.com/api/v1/location/42.65034199999999/-76.634433
# Dfb
# Retrieving Results for Benessere.
# http://climateapi.scottpinkelman.com/api/v1/location/40.725963899999996/-74.37335829999998
# Cfa
# Retrieving Results for Bloomer Creek.
# http://climateapi.scottpinkelman.com/api/v1/location/42.489662700000004/-76.8702328
# Dfb
# Retrieving Results for Andean Sky.
# http://climateapi.scottpinkelman.com/api/v1/location/-21.1607667/-66.7752481
# BSk
# Retrieving Results for Angove's.
# http://climateapi.scottpinkelman.com/api/v1/location/41.9747799/-79.12871679999998
# Dfb
# Retrieving Results for Silvan Ridge.
# http://climateapi.scottpinkelman.com/api/v1/location/43.9569919/-123.26447979999999
# Csb
# Retrieving Results for Talamonti.
# http://climateapi.scottpinkelman.com/api/v1/location/42.065576899999996/-87.68487009999998
# Dfa
# Retrieving Results for Testarossa.
# http://climateapi.scottpinkelman.com/api/v1/location/37.21347799999999/-121.981544
# Csb
# Retrieving Results for Meeker.
# http://climateapi.scottpinkelman.com/api/v1/location/40.03747329999999/-107.91312990000002
# Dfb
# Retrieving Results for Consorzio Vini Tipici di San Marino.
# http://climateapi.scottpinkelman.com/api/v1/location/43.9408465/12.4582462
# Cfb
# Retrieving Results for D'Arenberg.
# http://climateapi.scottpinkelman.com/api/v1/location/-35.19721639999999/138.5511368
# Csb
# Retrieving Results for Dogwood.
# http://climateapi.scottpinkelman.com/api/v1/location/29.749411/-95.378162
# Cfa
# Retrieving Results for Domaine du Tariquet.
# http://climateapi.scottpinkelman.com/api/v1/location/43.8533307/0.1686208
# Cfb
# Retrieving Results for Falcor.
# http://climateapi.scottpinkelman.com/api/v1/location/38.2560001/-122.27626799999999
# Csb
# Retrieving Results for Hayman & Hill.
# http://climateapi.scottpinkelman.com/api/v1/location/45.253181/-67.32514979999999
# Dfb
# Retrieving Results for Hermann J. Wiemer.
# http://climateapi.scottpinkelman.com/api/v1/location/42.5720217/-76.92809849999998
# Dfb
# Retrieving Results for Finca Las Moras.
# http://climateapi.scottpinkelman.com/api/v1/location/31.7215363/-106.45416409999999
# BWk
# Retrieving Results for Long Flat.
# http://climateapi.scottpinkelman.com/api/v1/location/-31.433333/152.48333300000002
# Cfb
# Retrieving Results for Work.
# http://climateapi.scottpinkelman.com/api/v1/location/38.8861111/-94.79138890000002
# Cfa
# Retrieving Results for Amity.
# http://climateapi.scottpinkelman.com/api/v1/location/45.1156724/-123.2073257
# Csb
# Retrieving Results for Autumn Hill.
# http://climateapi.scottpinkelman.com/api/v1/location/36.360540500000006/-93.5521894
# Cfa
# Retrieving Results for Blue Rock.
# http://climateapi.scottpinkelman.com/api/v1/location/39.8000697/-81.8915241
# Cfa
# Retrieving Results for Cherry Hill.
# http://climateapi.scottpinkelman.com/api/v1/location/39.926813/-75.0246312
# Cfa
# Retrieving Results for Cloud 9.
# http://climateapi.scottpinkelman.com/api/v1/location/36.655406/-92.143331
# Cfa
# Retrieving Results for Cueva de las Manos.
# http://climateapi.scottpinkelman.com/api/v1/location/-47.15222139999999/-70.66270349999998
# Csb
# Retrieving Results for David Fulton.
# http://climateapi.scottpinkelman.com/api/v1/location/34.0110131/-81.1524135
# Cfa
# Retrieving Results for Esterlina.
# http://climateapi.scottpinkelman.com/api/v1/location/35.9733/-119.035202
# BSk
# Retrieving Results for Goats do Roam Wine Co..
# http://climateapi.scottpinkelman.com/api/v1/location/29.743232/-95.461971
# Cfa
# Retrieving Results for Graham Beck.
# http://climateapi.scottpinkelman.com/api/v1/location/29.743232/-95.461971
# Cfa
# Retrieving Results for Hartenberg.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.89833/18.791539999999998
# Csa
# Retrieving Results for Vignobles 46N118.
# http://climateapi.scottpinkelman.com/api/v1/location/44.4475229/1.441989
# Cfb
# Retrieving Results for Willamette Valley Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/44.8279071/-123.012622
# Csb
# Retrieving Results for Algodon.
# http://climateapi.scottpinkelman.com/api/v1/location/32.713411300000004/-114.7365544
# BWh
# Retrieving Results for Beaver Creek.
# http://climateapi.scottpinkelman.com/api/v1/location/39.6042863/-106.51671090000002
# Dfc
# Retrieving Results for Byron.
# http://climateapi.scottpinkelman.com/api/v1/location/36.9019722/-98.2939595
# Cfa
# Retrieving Results for Jardin.
# http://climateapi.scottpinkelman.com/api/v1/location/37.09024/-95.712891
# Cfa
# Retrieving Results for Jardin.
# http://climateapi.scottpinkelman.com/api/v1/location/37.09024/-95.712891
# Cfa
# Retrieving Results for Kaiken.
# http://climateapi.scottpinkelman.com/api/v1/location/-32.8894587/-68.8458386
# BWk
# Retrieving Results for Lungarotti.
# http://climateapi.scottpinkelman.com/api/v1/location/43.0298886/12.4289901
# Cfb
# Retrieving Results for Marchesi Fumanelli.
# http://climateapi.scottpinkelman.com/api/v1/location/45.513143/10.9012257
# Cfb
# Retrieving Results for Mariell.
# http://climateapi.scottpinkelman.com/api/v1/location/40.8885583/-74.72424219999998
# Cfa
# Retrieving Results for Livio Felluga.
# http://climateapi.scottpinkelman.com/api/v1/location/40.5791993/-73.9846613
# Cfa
# Retrieving Results for My Big Fat Greek Wine.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Nals Margreid.
# http://climateapi.scottpinkelman.com/api/v1/location/46.538855600000005/11.2039243
# Dfc
# Retrieving Results for O. Fournier.
# http://climateapi.scottpinkelman.com/api/v1/location/42.2776728/-71.7616372
# Dfb
# Retrieving Results for Pico Maccario.
# http://climateapi.scottpinkelman.com/api/v1/location/44.817558700000006/8.7046627
# Csb
# Retrieving Results for Sottano.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.0950929/-68.92443109999999
# BWk
# Retrieving Results for St. Francis.
# http://climateapi.scottpinkelman.com/api/v1/location/36.072651/-95.919195
# Cfa
# Retrieving Results for Trailhead.
# http://climateapi.scottpinkelman.com/api/v1/location/37.281586499999996/-95.7997013
# Cfa
# Retrieving Results for Erath.
# http://climateapi.scottpinkelman.com/api/v1/location/29.958261100000005/-92.0359562
# Cfa
# Retrieving Results for Franz Haas.
# http://climateapi.scottpinkelman.com/api/v1/location/37.4932499/-77.34024939999998
# Cfa
# Retrieving Results for Forstreiter.
# http://climateapi.scottpinkelman.com/api/v1/location/48.3791445/15.691594
# Cfb
# Retrieving Results for Cambria.
# http://climateapi.scottpinkelman.com/api/v1/location/32.9444961/-96.995613
# Cfa
# Retrieving Results for I Giusti e Zanza.
# http://climateapi.scottpinkelman.com/api/v1/location/43.5821411/10.5195897
# Cfb
# Retrieving Results for J. Christopher.
# http://climateapi.scottpinkelman.com/api/v1/location/36.1315995/-86.801121
# Cfa
# Retrieving Results for Viña Cobos.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.0972849/-68.92445479999999
# BWk
# Retrieving Results for Talley.
# http://climateapi.scottpinkelman.com/api/v1/location/33.0668227/-96.8751434
# Cfa
# Retrieving Results for Acústic.
# http://climateapi.scottpinkelman.com/api/v1/location/41.292953000000004/0.7978029999999999
# Csa
# Retrieving Results for Parallel.
# http://climateapi.scottpinkelman.com/api/v1/location/43.6694451/-79.4385803
# Dfb
# Retrieving Results for Domaine Daniel Dugois.
# http://climateapi.scottpinkelman.com/api/v1/location/46.949161100000005/5.7903144
# Cfb
# Retrieving Results for Kilikanoon.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.9201684/138.623133
# BSk
# Retrieving Results for Finca Sophenia.
# http://climateapi.scottpinkelman.com/api/v1/location/34.0930548/-118.37803799999999
# Csb
# Retrieving Results for Treana.
# http://climateapi.scottpinkelman.com/api/v1/location/35.5879453/-120.72135549999999
# Csb
# Retrieving Results for Ventisquero.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.6170546/-71.2511025
# Csb
# Retrieving Results for Aquinas.
# http://climateapi.scottpinkelman.com/api/v1/location/36.132115/-86.84404599999998
# Cfa
# Retrieving Results for Arboleda.
# http://climateapi.scottpinkelman.com/api/v1/location/30.521901500000002/-97.818869
# Cfa
# Retrieving Results for Benessere.
# http://climateapi.scottpinkelman.com/api/v1/location/40.725963899999996/-74.37335829999998
# Cfa
# Retrieving Results for Buried Cane.
# http://climateapi.scottpinkelman.com/api/v1/location/48.9220655/-122.1390398
# Cfb
# Retrieving Results for Cascina Adelaide.
# http://climateapi.scottpinkelman.com/api/v1/location/44.6126534/7.9458787
# Cfa
# Retrieving Results for Claudia Springs.
# http://climateapi.scottpinkelman.com/api/v1/location/39.131896999999995/-123.53260149999998
# Csb
# Retrieving Results for Cramele Recas.
# http://climateapi.scottpinkelman.com/api/v1/location/45.7991938/21.505781600000002
# Cfb
# Retrieving Results for Domaine Bertagna.
# http://climateapi.scottpinkelman.com/api/v1/location/47.175934399999996/4.963435899999999
# Cfb
# Retrieving Results for Domaine Sigalas.
# http://climateapi.scottpinkelman.com/api/v1/location/36.471427/25.394178
# Csa
# Retrieving Results for Socré.
# http://climateapi.scottpinkelman.com/api/v1/location/41.9176306/-87.6982833
# Dfa
# Retrieving Results for Boffa.
# http://climateapi.scottpinkelman.com/api/v1/location/10.1808254/-14.039161499999999
# Am
# Retrieving Results for Otto's Constant Dream.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Mount Veeder.
# http://climateapi.scottpinkelman.com/api/v1/location/38.3793566/-122.4477575
# Csb
# Retrieving Results for Robert Mondavi.
# http://climateapi.scottpinkelman.com/api/v1/location/38.4412684/-122.40980230000001
# Csb
# Retrieving Results for Bellussi.
# http://climateapi.scottpinkelman.com/api/v1/location/45.8792585/12.003568099999999
# Cfb
# Retrieving Results for Aresti.
# http://climateapi.scottpinkelman.com/api/v1/location/32.470674/-97.559511
# Cfa
# Retrieving Results for Paladin.
# http://climateapi.scottpinkelman.com/api/v1/location/39.446469/-105.08105400000001
# Dfb
# Retrieving Results for Perlage.
# http://climateapi.scottpinkelman.com/api/v1/location/47.2941948/-122.3200423
# Csb
# Retrieving Results for Sant Eurosia.
# http://climateapi.scottpinkelman.com/api/v1/location/45.61019879999999/8.0267523
# Cfb
# Retrieving Results for Sant Eurosia.
# http://climateapi.scottpinkelman.com/api/v1/location/45.61019879999999/8.0267523
# Cfb
# Retrieving Results for J. & F. Lurton.
# http://climateapi.scottpinkelman.com/api/v1/location/29.743232/-95.461971
# Cfa
# Retrieving Results for L'Antica Quercia.
# http://climateapi.scottpinkelman.com/api/v1/location/45.94487300000001/12.297694
# Cfb
# Retrieving Results for Lucas Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/42.62787/-76.71015400000002
# Dfb
# Retrieving Results for Marsuret.
# http://climateapi.scottpinkelman.com/api/v1/location/45.906068/12.063322
# Cfb
# Retrieving Results for De Martino.
# http://climateapi.scottpinkelman.com/api/v1/location/39.958604799999996/-74.2125623
# Cfa
# Retrieving Results for Beringer.
# http://climateapi.scottpinkelman.com/api/v1/location/38.510162/-122.47988799999999
# Csb
# Retrieving Results for Brutocao.
# http://climateapi.scottpinkelman.com/api/v1/location/38.97166/-123.079154
# Csb
# Retrieving Results for Clos La Chance.
# http://climateapi.scottpinkelman.com/api/v1/location/37.072889399999994/-121.6432703
# Csb
# Retrieving Results for Cono Sur.
# http://climateapi.scottpinkelman.com/api/v1/location/35.3884238/-82.5663345
# Cfb
# Retrieving Results for Sommariva.
# http://climateapi.scottpinkelman.com/api/v1/location/-26.415753100000003/146.60018290000002
# BSh
# Retrieving Results for Spagnol.
# http://climateapi.scottpinkelman.com/api/v1/location/40.4256355/-79.68949649999998
# Cfa
# Retrieving Results for Jacquart.
# http://climateapi.scottpinkelman.com/api/v1/location/46.461518700000006/-90.1439877
# Dfb
# Retrieving Results for L'Antica Quercia.
# http://climateapi.scottpinkelman.com/api/v1/location/45.94487300000001/12.297694
# Cfb
# Retrieving Results for Koyle.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.5357571/-70.9792445
# Csb
# Retrieving Results for Château Notre Dame du Quatourze.
# http://climateapi.scottpinkelman.com/api/v1/location/43.15952/2.999774
# Csb
# Retrieving Results for Mémoires.
# http://climateapi.scottpinkelman.com/api/v1/location/30.492994/-92.351793
# Cfa
# Retrieving Results for Cavas Hill.
# http://climateapi.scottpinkelman.com/api/v1/location/41.3227451/1.6901876
# Csa
# Retrieving Results for Antoine Moltès & Fils.
# http://climateapi.scottpinkelman.com/api/v1/location/47.983338/7.2891720000000015
# Cfb
# Retrieving Results for Pezzi King.
# http://climateapi.scottpinkelman.com/api/v1/location/38.6060807/-122.86229809999999
# Csb
# Retrieving Results for Bellisco.
# http://climateapi.scottpinkelman.com/api/v1/location/40.4029249/-3.7536039
# Csa
# Retrieving Results for Pura 8.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Viña Tarapacá.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Chambers Rosewood Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/-36.044717999999996/146.45081000000002
# Cfa
# Retrieving Results for Chambers Rosewood Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/-36.044717999999996/146.45081000000002
# Cfa
# Retrieving Results for Robert Weil.
# http://climateapi.scottpinkelman.com/api/v1/location/41.75255429999999/-88.21054720000001
# Dfa
# Retrieving Results for Chambers Rosewood Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/-36.044717999999996/146.45081000000002
# Cfa
# Retrieving Results for Torbreck.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.476955/138.950515
# BSk
# Retrieving Results for Cavallotto.
# http://climateapi.scottpinkelman.com/api/v1/location/44.628496000000005/7.977163000000001
# Cfa
# Retrieving Results for Oremus.
# http://climateapi.scottpinkelman.com/api/v1/location/32.4033137/-111.1715696
# BSh
# Retrieving Results for Rochioli.
# http://climateapi.scottpinkelman.com/api/v1/location/38.5335045/-122.86723020000001
# Csb
# Retrieving Results for Louis Latour.
# http://climateapi.scottpinkelman.com/api/v1/location/38.017382299999994/-122.5393571
# Csb
# Retrieving Results for Robert Weil.
# http://climateapi.scottpinkelman.com/api/v1/location/41.75255429999999/-88.21054720000001
# Dfa
# Retrieving Results for Rochioli.
# http://climateapi.scottpinkelman.com/api/v1/location/38.5335045/-122.86723020000001
# Csb
# Retrieving Results for Jasper Hill.
# http://climateapi.scottpinkelman.com/api/v1/location/44.586738700000005/-72.26941540000001
# Dfb
# Retrieving Results for Château de la Tour.
# http://climateapi.scottpinkelman.com/api/v1/location/49.1939223/2.4253063999999998
# Cfb
# Retrieving Results for Weingut Hans Bausch.
# http://climateapi.scottpinkelman.com/api/v1/location/50.021179100000005/8.0511643
# Cfb
# Retrieving Results for Philippe Colin.
# http://climateapi.scottpinkelman.com/api/v1/location/46.9277443/4.7401848
# Cfb
# Retrieving Results for Torbreck.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.476955/138.950515
# BSk
# Retrieving Results for Bel Colle.
# http://climateapi.scottpinkelman.com/api/v1/location/44.6585859/7.926916599999998
# Cfa
# Retrieving Results for J. Davies.
# http://climateapi.scottpinkelman.com/api/v1/location/38.4983541/-122.46224240000001
# Csb
# Retrieving Results for Louis Latour.
# http://climateapi.scottpinkelman.com/api/v1/location/38.017382299999994/-122.5393571
# Csb
# Retrieving Results for Winderlea.
# http://climateapi.scottpinkelman.com/api/v1/location/45.2790245/-123.04307539999999
# Csb
# Retrieving Results for Wakefield.
# http://climateapi.scottpinkelman.com/api/v1/location/42.5039395/-71.0723391
# Dfb
# Retrieving Results for Cantina Terlano.
# http://climateapi.scottpinkelman.com/api/v1/location/46.5306691/11.2519441
# Dfc
# Retrieving Results for De Martino.
# http://climateapi.scottpinkelman.com/api/v1/location/39.958604799999996/-74.2125623
# Cfa
# Retrieving Results for Montresor.
# http://climateapi.scottpinkelman.com/api/v1/location/26.472646/-80.11214
# Am
# Retrieving Results for Ronco del Gelso.
# http://climateapi.scottpinkelman.com/api/v1/location/45.949304/13.4774169
# Cfa
# Retrieving Results for Sebastiani.
# http://climateapi.scottpinkelman.com/api/v1/location/38.29323189999999/-122.44941709999999
# Csb
# Retrieving Results for Elena Walch.
# http://climateapi.scottpinkelman.com/api/v1/location/46.3385258/11.2385953
# Dfb
# Retrieving Results for Gini.
# http://climateapi.scottpinkelman.com/api/v1/location/42.345921600000004/-83.0141955
# Dfa
# Retrieving Results for Borgo Conventi.
# http://climateapi.scottpinkelman.com/api/v1/location/45.9135304/13.528000099999998
# Cfb
# Retrieving Results for Ceago Vinegarden.
# http://climateapi.scottpinkelman.com/api/v1/location/39.1085498/-122.816065
# Csb
# Retrieving Results for Valiano.
# http://climateapi.scottpinkelman.com/api/v1/location/43.1479125/11.9021177
# Cfb
# Retrieving Results for Volpe Pasini.
# http://climateapi.scottpinkelman.com/api/v1/location/46.11364289999999/13.3973476
# Cfb
# Retrieving Results for L.A. Cetto.
# http://climateapi.scottpinkelman.com/api/v1/location/32.52413/-117.037761
# BSk
# Retrieving Results for La Vis.
# http://climateapi.scottpinkelman.com/api/v1/location/46.1377955/11.107530800000001
# Dfb
# Retrieving Results for Lapostolle.
# http://climateapi.scottpinkelman.com/api/v1/location/29.743232/-95.461971
# Cfa
# Retrieving Results for Carmen.
# http://climateapi.scottpinkelman.com/api/v1/location/37.09024/-95.712891
# Cfa
# Retrieving Results for Tommasi.
# http://climateapi.scottpinkelman.com/api/v1/location/30.162265/-93.18051190000001
# Cfa
# Retrieving Results for San Michele Eppan.
# http://climateapi.scottpinkelman.com/api/v1/location/46.456076700000004/11.2623877
# Dfb
# Retrieving Results for Vinoce.
# http://climateapi.scottpinkelman.com/api/v1/location/38.2859369/-122.2863383
# Csb
# Retrieving Results for Merriam.
# http://climateapi.scottpinkelman.com/api/v1/location/39.023616499999996/-94.69357009999999
# Cfa
# Retrieving Results for Murphy-Goode.
# http://climateapi.scottpinkelman.com/api/v1/location/38.612964700000006/-122.7694345
# Csb
# Retrieving Results for Kynsi.
# http://climateapi.scottpinkelman.com/api/v1/location/35.189788799999995/-120.5815658
# Csb
# Retrieving Results for Cantina Terlano.
# http://climateapi.scottpinkelman.com/api/v1/location/46.5306691/11.2519441
# Dfc
# Retrieving Results for Casa Julia.
# http://climateapi.scottpinkelman.com/api/v1/location/27.46775/-109.951305
# BSh
# Retrieving Results for Valdivieso.
# http://climateapi.scottpinkelman.com/api/v1/location/42.3522105/-83.05719619999998
# Dfa
# Retrieving Results for Bridlewood.
# http://climateapi.scottpinkelman.com/api/v1/location/33.049859999999995/-97.0907588
# Cfa
# Retrieving Results for San Pedro.
# http://climateapi.scottpinkelman.com/api/v1/location/33.7360619/-118.29224609999999
# BSk
# Retrieving Results for Undurraga.
# http://climateapi.scottpinkelman.com/api/v1/location/43.0790686/-2.7379706
# Cfb
# Retrieving Results for Cline.
# http://climateapi.scottpinkelman.com/api/v1/location/38.2141294/-122.458146
# Csb
# Retrieving Results for Cono Sur.
# http://climateapi.scottpinkelman.com/api/v1/location/35.3884238/-82.5663345
# Cfb
# Retrieving Results for Aresti.
# http://climateapi.scottpinkelman.com/api/v1/location/32.470674/-97.559511
# Cfa
# Retrieving Results for Astoria.
# http://climateapi.scottpinkelman.com/api/v1/location/46.1878841/-123.8312534
# Csb
# Retrieving Results for Cantine Maschio.
# http://climateapi.scottpinkelman.com/api/v1/location/45.847890899999996/12.428617
# Cfb
# Retrieving Results for Val d'Oca.
# http://climateapi.scottpinkelman.com/api/v1/location/45.87277/12.026615
# Cfb
# Retrieving Results for Viña Bisquertt.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.3929354/-70.6169695
# Csb
# Retrieving Results for Vinavanti.
# http://climateapi.scottpinkelman.com/api/v1/location/32.7481994/-117.1494656
# BSk
# Retrieving Results for Vino V.
# http://climateapi.scottpinkelman.com/api/v1/location/34.4208305/-119.69819009999999
# Csb
# Retrieving Results for Viticoltori Ponte.
# http://climateapi.scottpinkelman.com/api/v1/location/45.720355600000005/12.465574900000002
# Cfb
# Retrieving Results for Jacquart.
# http://climateapi.scottpinkelman.com/api/v1/location/46.461518700000006/-90.1439877
# Dfb
# Retrieving Results for Lapostolle.
# http://climateapi.scottpinkelman.com/api/v1/location/29.743232/-95.461971
# Cfa
# Retrieving Results for Le Vigne di Alice.
# http://climateapi.scottpinkelman.com/api/v1/location/45.952909999999996/12.290298
# Cfb
# Retrieving Results for McGregor.
# http://climateapi.scottpinkelman.com/api/v1/location/31.444055699999996/-97.4091792
# Cfa
# Retrieving Results for Miles.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2441411/-96.9485502
# Cfa
# Retrieving Results for Morro Bay.
# http://climateapi.scottpinkelman.com/api/v1/location/35.3659445/-120.8499924
# Csb
# Retrieving Results for Perlage.
# http://climateapi.scottpinkelman.com/api/v1/location/47.2941948/-122.3200423
# Csb
# Retrieving Results for Pizzolato.
# http://climateapi.scottpinkelman.com/api/v1/location/45.979681899999996/12.294208300000001
# Cfb
# Retrieving Results for Pizzolato.
# http://climateapi.scottpinkelman.com/api/v1/location/45.979681899999996/12.294208300000001
# Cfb
# Retrieving Results for Red Newt Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/42.501911/-76.867181
# Dfb
# Retrieving Results for Ca'Tullio.
# http://climateapi.scottpinkelman.com/api/v1/location/45.75951939999999/13.372674499999999
# Cfa
# Retrieving Results for Château de Callac.
# http://climateapi.scottpinkelman.com/api/v1/location/47.814276/-2.567409
# Cfb
# Retrieving Results for Guardian.
# http://climateapi.scottpinkelman.com/api/v1/location/37.09024/-95.712891
# Cfa
# Retrieving Results for Kerloo.
# http://climateapi.scottpinkelman.com/api/v1/location/47.5676354/-122.33546809999999
# Csb
# Retrieving Results for Kohl.
# http://climateapi.scottpinkelman.com/api/v1/location/36.295194200000005/-95.8345596
# Cfa
# Retrieving Results for Las Positas.
# http://climateapi.scottpinkelman.com/api/v1/location/37.711689/-121.7997617
# Csb
# Retrieving Results for Lieb.
# http://climateapi.scottpinkelman.com/api/v1/location/41.0361386/-72.50435259999998
# Cfa
# Retrieving Results for Luberri.
# http://climateapi.scottpinkelman.com/api/v1/location/42.518652100000004/-2.6265921000000003
# Cfb
# Retrieving Results for Macari.
# http://climateapi.scottpinkelman.com/api/v1/location/40.986564/-72.56800600000001
# Cfa
# Retrieving Results for Malat.
# http://climateapi.scottpinkelman.com/api/v1/location/37.163654/50.158798
# Csa
# Retrieving Results for Milbrandt.
# http://climateapi.scottpinkelman.com/api/v1/location/46.2195744/-119.77816740000002
# Csa
# Retrieving Results for Ojai.
# ...
# Csa
# Retrieving Results for First & Local.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2236985/-95.7062569
# Cfa
# Retrieving Results for Amalaya.
# http://climateapi.scottpinkelman.com/api/v1/location/-24.782126899999998/-65.42319760000001
# Cwa
# Retrieving Results for Half Mile Creek.
# http://climateapi.scottpinkelman.com/api/v1/location/-27.6728168/148.3716902
# BSh
# Retrieving Results for California Republic.
# http://climateapi.scottpinkelman.com/api/v1/location/34.0361721/-118.44431399999999
# Csb
# Retrieving Results for Cantina Valle Tritana.
# http://climateapi.scottpinkelman.com/api/v1/location/42.05779889999999/13.4762135
# Cfb
# Retrieving Results for Château Doms.
# http://climateapi.scottpinkelman.com/api/v1/location/44.6796539/-0.4144893
# Cfb
# Retrieving Results for Château Pindefleurs.
# http://climateapi.scottpinkelman.com/api/v1/location/44.8869809/-0.18157379999999998
# Cfb
# Retrieving Results for Cliff Creek.
# http://climateapi.scottpinkelman.com/api/v1/location/42.501915999999994/-122.976914
# Csb
# Retrieving Results for Quady North.
# http://climateapi.scottpinkelman.com/api/v1/location/42.313854/-122.96598600000002
# Csb
# Retrieving Results for Qupé.
# http://climateapi.scottpinkelman.com/api/v1/location/34.9188571/-120.29823970000001
# Csb
# Retrieving Results for Réserve des Oliviers.
# http://climateapi.scottpinkelman.com/api/v1/location/44.056556/4.8312810000000015
# Csa
# Retrieving Results for Tardieu-Laurent.
# http://climateapi.scottpinkelman.com/api/v1/location/43.76414399999999/5.369288
# Csa
# Retrieving Results for Bonaccorsi.
# http://climateapi.scottpinkelman.com/api/v1/location/34.9358377/-120.4646111
# Csb
# Retrieving Results for Chanin.
# http://climateapi.scottpinkelman.com/api/v1/location/34.8619064/-87.65740319999998
# Cfa
# Retrieving Results for Cuda Ridge Wines.
# http://climateapi.scottpinkelman.com/api/v1/location/37.6547921/-121.7668362
# Csb
# Retrieving Results for Doña Silvina.
# http://climateapi.scottpinkelman.com/api/v1/location/-32.8894587/-68.8458386
# BWk
# Retrieving Results for Dürnberg.
# http://climateapi.scottpinkelman.com/api/v1/location/47.66486/13.09168
# Cfb
# Retrieving Results for Lange.
# http://climateapi.scottpinkelman.com/api/v1/location/44.942554/-122.9337615
# Csb
# Retrieving Results for Markus Huber.
# http://climateapi.scottpinkelman.com/api/v1/location/48.337472/15.697273999999998
# Cfb
# Retrieving Results for Melrose.
# http://climateapi.scottpinkelman.com/api/v1/location/37.0309011/-94.95828990000001
# Cfa
# Retrieving Results for Piña.
# http://climateapi.scottpinkelman.com/api/v1/location/29.706493100000003/-95.4173782
# Cfa
# Retrieving Results for Qupé.
# http://climateapi.scottpinkelman.com/api/v1/location/34.9188571/-120.29823970000001
# Csb
# Retrieving Results for Qupé.
# http://climateapi.scottpinkelman.com/api/v1/location/34.9188571/-120.29823970000001
# Csb
# Retrieving Results for Tardieu-Laurent.
# http://climateapi.scottpinkelman.com/api/v1/location/43.76414399999999/5.369288
# Csa
# Retrieving Results for Tessa Marie.
# http://climateapi.scottpinkelman.com/api/v1/location/40.007497799999996/-75.1858203
# Cfa
# Retrieving Results for Türk.
# http://climateapi.scottpinkelman.com/api/v1/location/36.171795/-120.22183999999999
# BSk
# Retrieving Results for Ugly Duckling.
# http://climateapi.scottpinkelman.com/api/v1/location/40.738256400000004/-74.22389299999998
# Cfa
# Retrieving Results for Finca Vides.
# http://climateapi.scottpinkelman.com/api/v1/location/-32.8894587/-68.8458386
# BWk
# Retrieving Results for Petra.
# http://climateapi.scottpinkelman.com/api/v1/location/30.3284544/35.4443622
# BWh
# Retrieving Results for Recanati.
# http://climateapi.scottpinkelman.com/api/v1/location/43.3946856/13.5321234
# Cfa
# Retrieving Results for Terralsole.
# http://climateapi.scottpinkelman.com/api/v1/location/43.018783/11.536556
# Cfb
# Retrieving Results for Tommasi.
# http://climateapi.scottpinkelman.com/api/v1/location/30.162265/-93.18051190000001
# Cfa
# Retrieving Results for Caves Aliança.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Bodegas Cerrosol.
# http://climateapi.scottpinkelman.com/api/v1/location/41.1629055/-4.574646599999999
# Csb
# Retrieving Results for Dry Creek Vineyard.
# http://climateapi.scottpinkelman.com/api/v1/location/38.65291/-122.924876
# Csb
# Retrieving Results for Prejean.
# http://climateapi.scottpinkelman.com/api/v1/location/30.3061906/-92.02772850000001
# Cfa
# Retrieving Results for Kadesh Barnea.
# http://climateapi.scottpinkelman.com/api/v1/location/30.903428/34.396679
# BWh
# Retrieving Results for Antonino Tringali-Casanuova.
# http://climateapi.scottpinkelman.com/api/v1/location/32.3703722/-110.9669111
# BSh
# Retrieving Results for Tyrrell's.
# http://climateapi.scottpinkelman.com/api/v1/location/40.99135379999999/-74.03214179999998
# Cfa
# Retrieving Results for Vasse River.
# http://climateapi.scottpinkelman.com/api/v1/location/-33.9610465/115.0767388
# Csb
# Retrieving Results for Vega de la Reina.
# http://climateapi.scottpinkelman.com/api/v1/location/41.410874299999996/-4.9597660999999995
# Csb
# Retrieving Results for Villa Vignamaggio.
# http://climateapi.scottpinkelman.com/api/v1/location/32.3703722/-110.9669111
# BSh
# Retrieving Results for Vinum Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/38.222947/-122.26304820000001
# Csb
# Retrieving Results for Analivia.
# http://climateapi.scottpinkelman.com/api/v1/location/41.410874299999996/-4.9597660999999995
# Csb
# Retrieving Results for Battle of Bosworth.
# http://climateapi.scottpinkelman.com/api/v1/location/52.59691600000001/-1.405901
# Cfb
# Retrieving Results for La Gerla.
# http://climateapi.scottpinkelman.com/api/v1/location/43.0653778/11.4972677
# Cfa
# Retrieving Results for Quinta do Grifo.
# http://climateapi.scottpinkelman.com/api/v1/location/41.1323483/-8.611127
# Csb
# Retrieving Results for Recanati.
# http://climateapi.scottpinkelman.com/api/v1/location/43.3946856/13.5321234
# Cfa
# Retrieving Results for St. Clement.
# http://climateapi.scottpinkelman.com/api/v1/location/41.9280626/-87.6461313
# Dfa
# Retrieving Results for Quinta da Alorna.
# http://climateapi.scottpinkelman.com/api/v1/location/39.1998069/-8.6391689
# Csa
# Retrieving Results for Torres.
# http://climateapi.scottpinkelman.com/api/v1/location/36.1483826/-95.8920805
# Cfa
# Retrieving Results for Renwood.
# http://climateapi.scottpinkelman.com/api/v1/location/38.541752100000004/-120.7950854
# Csa
# Retrieving Results for Marqués de Cáceres.
# http://climateapi.scottpinkelman.com/api/v1/location/42.480132299999994/-2.6363289
# Cfb
# Retrieving Results for Bodegas Campante.
# http://climateapi.scottpinkelman.com/api/v1/location/42.3226/-8.0150199
# Csb
# Retrieving Results for Brick Road.
# http://climateapi.scottpinkelman.com/api/v1/location/42.9557228/-85.64364619999998
# Dfb
# Retrieving Results for Chaddsford.
# http://climateapi.scottpinkelman.com/api/v1/location/39.865348100000006/-75.56842540000001
# Cfa
# Retrieving Results for Ventosa.
# http://climateapi.scottpinkelman.com/api/v1/location/42.857164000000004/-76.936131
# Dfb
# Retrieving Results for Bodegas Riojanas.
# http://climateapi.scottpinkelman.com/api/v1/location/42.481075/-2.6403123
# Cfb
# Retrieving Results for Presqu'ile.
# http://climateapi.scottpinkelman.com/api/v1/location/34.8538029/-120.3710817
# Csb
# Retrieving Results for Sante Arcangeli.
# http://climateapi.scottpinkelman.com/api/v1/location/36.977943200000006/-121.9007088
# Csb
# Retrieving Results for Sixto.
# http://climateapi.scottpinkelman.com/api/v1/location/40.737296/-73.986729
# Cfa
# Retrieving Results for Syncline.
# http://climateapi.scottpinkelman.com/api/v1/location/45.718115000000004/-121.3319
# Csb
# Retrieving Results for Lambardi.
# http://climateapi.scottpinkelman.com/api/v1/location/40.9151924/-73.7846686
# Cfa
# Retrieving Results for Le Carré.
# http://climateapi.scottpinkelman.com/api/v1/location/45.530245/-73.56287329999998
# Dfb
# Retrieving Results for Two Vintners.
# http://climateapi.scottpinkelman.com/api/v1/location/47.762225/-122.14970339999999
# Csb
# Retrieving Results for Va Piano.
# http://climateapi.scottpinkelman.com/api/v1/location/41.880967999999996/-87.62639300000001
# Dfa
# Retrieving Results for Tenuta San Giorgio.
# http://climateapi.scottpinkelman.com/api/v1/location/45.7725133/12.335317800000002
# Cfb
# Retrieving Results for Le P'tit Paysan.
# http://climateapi.scottpinkelman.com/api/v1/location/36.3136201/-121.35416310000001
# Csb
# Retrieving Results for Lisini.
# http://climateapi.scottpinkelman.com/api/v1/location/42.998793/11.473352
# Csa
# Retrieving Results for Mesa Del Sol.
# http://climateapi.scottpinkelman.com/api/v1/location/34.986709600000005/-106.6133638
# BSk
# Retrieving Results for Ornellaia.
# http://climateapi.scottpinkelman.com/api/v1/location/40.76295/-73.96930499999998
# Cfa
# Retrieving Results for Analemma.
# http://climateapi.scottpinkelman.com/api/v1/location/45.682534000000004/-121.37191399999999
# Csb
# Retrieving Results for Bella.
# http://climateapi.scottpinkelman.com/api/v1/location/41.7029569/-73.92731409999998
# Dfa
# Retrieving Results for Centolani.
# http://climateapi.scottpinkelman.com/api/v1/location/40.768489200000005/-73.95890490000001
# Cfa
# Retrieving Results for Château Gaudin.
# http://climateapi.scottpinkelman.com/api/v1/location/45.1848534/-0.7521097999999999
# Cfb
# Retrieving Results for Darcie Kent Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/37.6659675/-121.70612179999999
# Csb
# Retrieving Results for Univitis.
# http://climateapi.scottpinkelman.com/api/v1/location/44.794395/0.17704720000000002
# Cfb
# Retrieving Results for Volver.
# http://climateapi.scottpinkelman.com/api/v1/location/39.9469808/-75.165686
# Cfa
# Retrieving Results for Washington Hills.
# http://climateapi.scottpinkelman.com/api/v1/location/35.084762299999994/-85.1764843
# Cfa
# Retrieving Results for Finca La Pica.
# http://climateapi.scottpinkelman.com/api/v1/location/42.287073299999996/-2.539603
# Cfb
# Retrieving Results for Château Saint-Urban.
# http://climateapi.scottpinkelman.com/api/v1/location/48.4001756/-4.1855985
# Cfb
# Retrieving Results for Conde de Subirats.
# http://climateapi.scottpinkelman.com/api/v1/location/41.3904082/1.7696778999999998
# Csa
# Retrieving Results for Crayelle Cellars.
# http://climateapi.scottpinkelman.com/api/v1/location/47.4269072/-120.31221740000001
# Csb
# Retrieving Results for Domaine Beausejour.
# http://climateapi.scottpinkelman.com/api/v1/location/47.1530078/0.3787495
# Cfb
# Retrieving Results for Les Rocailles.
# http://climateapi.scottpinkelman.com/api/v1/location/45.491553499999995/5.977958
# Cfb
# Retrieving Results for Niel Santofimia.
# http://climateapi.scottpinkelman.com/api/v1/location/38.8702789/-1.0993366000000002
# BSk
# Retrieving Results for Producta Vignobles.
# http://climateapi.scottpinkelman.com/api/v1/location/44.87857899999999/-0.5178153
# Cfb
# Retrieving Results for Silver Thread.
# http://climateapi.scottpinkelman.com/api/v1/location/42.56327329999999/-76.8746431
# Dfb
# Retrieving Results for V. Sattui.
# http://climateapi.scottpinkelman.com/api/v1/location/38.488982/-122.44813400000001
# Csb
# Retrieving Results for Ventosa.
# http://climateapi.scottpinkelman.com/api/v1/location/42.857164000000004/-76.936131
# Dfb
# Retrieving Results for Biutiful.
# http://climateapi.scottpinkelman.com/api/v1/location/34.06111509999999/-118.44628770000001
# Csb
# Retrieving Results for Cave B.
# http://climateapi.scottpinkelman.com/api/v1/location/47.0964885/-119.9948491
# BSk
# Retrieving Results for Château Barreyre.
# http://climateapi.scottpinkelman.com/api/v1/location/45.0854928/-0.7016455
# Cfb
# Retrieving Results for Château Laronde Désormes.
# http://climateapi.scottpinkelman.com/api/v1/location/53.53901219999999/-113.4942241
# Dfb
# Retrieving Results for Château Los Boldos.
# http://climateapi.scottpinkelman.com/api/v1/location/-34.3000093/-70.8185298
# Csb
# Retrieving Results for Cocobon.
# http://climateapi.scottpinkelman.com/api/v1/location/34.504006/-82.650689
# Cfa
# Retrieving Results for Domaine de la Sanglière.
# http://climateapi.scottpinkelman.com/api/v1/location/43.127860999999996/6.277277
# Csa
# Retrieving Results for Doña Isadora.
# http://climateapi.scottpinkelman.com/api/v1/location/37.2256055/-95.7162018
# Cfa
# Retrieving Results for Ehret.
# http://climateapi.scottpinkelman.com/api/v1/location/38.5011133/-89.94254649999998
# Cfa
# Retrieving Results for Château des Tourtes.
# http://climateapi.scottpinkelman.com/api/v1/location/45.2847705/-0.5611843000000001
# Cfb
# Retrieving Results for Château Donjon de Bruignac.
# http://climateapi.scottpinkelman.com/api/v1/location/44.7905767/-0.06144819999999999
# Cfb
# Retrieving Results for Helix by Reininger.
# http://climateapi.scottpinkelman.com/api/v1/location/46.052245899999996/-118.46027250000002
# Csa
# Retrieving Results for Capanna.
# http://climateapi.scottpinkelman.com/api/v1/location/41.7536534/-91.6051693
# Dfa
# Retrieving Results for Cellers Unió.
# http://climateapi.scottpinkelman.com/api/v1/location/41.211424/1.1987658
# Csa
# Retrieving Results for Château Haut Bertinerie.
# http://climateapi.scottpinkelman.com/api/v1/location/45.0756231/-0.41297429999999996
# Cfb
# Retrieving Results for Château Preuillac.
# http://climateapi.scottpinkelman.com/api/v1/location/45.306074100000004/-0.8918997000000001
# Cfb
# Retrieving Results for Koenig Vineyards.
# http://climateapi.scottpinkelman.com/api/v1/location/43.60491/-116.82175
# BSk
# Retrieving Results for Krutz.
# http://climateapi.scottpinkelman.com/api/v1/location/39.032432/-94.69511990000001
# Cfa
# Retrieving Results for Loring Wine Company.
# http://climateapi.scottpinkelman.com/api/v1/location/34.6144876/-120.19940829999999
# Csb
# Retrieving Results for Loring Wine Company.
# http://climateapi.scottpinkelman.com/api/v1/location/34.6144876/-120.19940829999999
# Csb
# Retrieving Results for Manzoni.
# http://climateapi.scottpinkelman.com/api/v1/location/36.4722855/-121.4676372
# Csb
# Retrieving Results for Amavi.
# http://climateapi.scottpinkelman.com/api/v1/location/46.01615049999999/-118.38378490000002
# Csa
# Retrieving Results for Bouchaine.
# http://climateapi.scottpinkelman.com/api/v1/location/38.2264234/-122.3313172
# Csb
# Retrieving Results for Bucher.
# http://climateapi.scottpinkelman.com/api/v1/location/38.895438/-94.7799375
# Cfa
# Retrieving Results for Syncline.
# http://climateapi.scottpinkelman.com/api/v1/location/45.718115000000004/-121.3319
# Csb
# Retrieving Results for Villadoria.
# http://climateapi.scottpinkelman.com/api/v1/location/44.6253925/7.9861908999999995
# Cfa
# Retrieving Results for Château de Roquebrune.
# http://climateapi.scottpinkelman.com/api/v1/location/44.951586999999996/-0.227622
# Cfb
# Retrieving Results for Quinta do Casal Branco.
# http://climateapi.scottpinkelman.com/api/v1/location/39.1701846/-8.659847000000001
# Csa
# Retrieving Results for Real Companhia Velha.
# http://climateapi.scottpinkelman.com/api/v1/location/41.1329742/-8.600936299999999
# Csb
# Retrieving Results for Jean-Marc Burgaud.
# http://climateapi.scottpinkelman.com/api/v1/location/46.1471236/4.6825737
# Cfb
# Retrieving Results for Jewelry Box.
# http://climateapi.scottpinkelman.com/api/v1/location/37.09024/-95.712891
# Cfa
# Retrieving Results for Juvé y Camps.
# http://climateapi.scottpinkelman.com/api/v1/location/40.7397902/-73.9861696
# Cfa
# Retrieving Results for Lanson.
# http://climateapi.scottpinkelman.com/api/v1/location/30.2034756/-92.0168981
# Cfa
# Retrieving Results for Magnolia Court.
# http://climateapi.scottpinkelman.com/api/v1/location/33.4653635/-81.94895890000001
# Cfa
# Retrieving Results for Mamarracho.
# http://climateapi.scottpinkelman.com/api/v1/location/28.521792200000004/-81.46357669999998
# Cfa
# Retrieving Results for Mantel Blanco.
# http://climateapi.scottpinkelman.com/api/v1/location/41.410874299999996/-4.9597660999999995
# Csb
# Retrieving Results for Red Rock.
# http://climateapi.scottpinkelman.com/api/v1/location/39.6655381/-105.2052116
# Dfb
# Retrieving Results for Quinta da Lapa.
# http://climateapi.scottpinkelman.com/api/v1/location/39.23621869999999/-8.8813774
# Csa
# Retrieving Results for Real Companhia Velha.
# http://climateapi.scottpinkelman.com/api/v1/location/41.1329742/-8.600936299999999
# Csb
# Retrieving Results for Castillo de Liria.
# http://climateapi.scottpinkelman.com/api/v1/location/28.521792200000004/-81.46357669999998
# Cfa
# Retrieving Results for San Felipe.

# %%
new_df.to_csv('winedf_loc_cz2.csv')
