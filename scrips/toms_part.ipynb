# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')

# %%
file = 'thefile.csv'
df = pd.read_csv(file)
df.nunique()
# Out:
# Unnamed: 0            113402
# country                   42
# description           104675
# points                    21
# price                    384
# region_1                1186
# taster_name               20
# title                 104360
# variety                  677
# winery                 15005
# Lat                    12892
# Lng                    12888
# heat weights              21
# year                      50
# Climate Zone              23
# Climate Zone Desc.        22
# raiting                   21
# dtype: int64

# %%
wineyards = df.groupby(['country'])
wineyards = wineyards['winery'].nunique()
wineyards = wineyards.sort_values(ascending=False).head(10)

# %%
wineyards.head()
# Out:
# country
# US           5160
# France       3089
# Italy        2514
# Spain        1304
# Argentina     506
# Name: winery, dtype: int64

# %%
wineyards.plot(kind='bar')
plt.ylabel('Count of wineries')
plt.title("Wineries by Country")


for x in range(wineyards.shape[0]):
    
    plt.annotate(xy=(x-0.3, wineyards[x] + 100),
                s=wineyards[x])
plt.ylim(0,5700)    
plt.legend()
plt.tight_layout()

plt.savefig("../pics/winery_country.png");

# %%
cz = df.groupby(['Climate Zone'])

czc = cz['winery'].count().sort_values(ascending=False).head(10)
czc
# Out:
# Climate Zone
# Csb    32471
# Cfa    25701
# Cfb    23148
# Csa    12030
# Dfb     6946
# BSk     4143
# Dfa     4081
# BWk     1705
# BSh      758
# Dfc      584
# Name: winery, dtype: int64

# %%
czc.plot(kind='bar')
plt.ylabel('Reviews by Climate Zone')
plt.title("Reviews based on Climate zones")


for x in range(czc.shape[0]):
    
    plt.annotate(xy=(x-0.3, czc[x] +1000),
                s=czc[x])
plt.ylim(0,35000)    
plt.legend()
plt.tight_layout()

plt.savefig("../pics/climatezone.png");

# %%
#points = cz['points'].mean()

# %%
#points

# %%
#price = cz['price'].mean()

# %%
#price
#rating = cz['raiting'].mean()

# %%
#new = pd.DataFrame({'Price':price,'Score':points,'Rating':rating})

# %%
#new

# %%
# Out:
#          cz       p
# 0       Cfa   550.0
# 1       Csb   450.0
# 2       Csb  1500.0
# 3       Cfa   359.0
# 4       Csb   210.0
# ...     ...     ...
# 113397  Csb    15.0
# 113398  Csa    13.0
# 113399  BSk    17.0
# 113400  Csa    17.0
# 113401  Csb    12.0
#
# [113402 rows x 2 columns]

# %%
# Out:
# array(['Cfa', 'Csb', 'Csa', 'Cfb', 'Dfb', 'Dfa', 'BWk', 'BSk', 'BSh',
#        'ET', 'Dfc', 'Af', 'Cwb', 'Aw', 'BWh', 'Dsb', 'Am', 'Cwa', 'As',
#        'Cwc', 'Cfc', 'Dsc', 'not avail'], dtype=object)

# %%
# Out:
# F_onewayResult(statistic=4.810849497540905, pvalue=1.9063368236739745e-06)
