# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key

# %%
file = '4.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 country  \
# 0       36294         39122           39122  Canada
# 1       36295         39123           39123   Italy
# 2       36296         39124           39124      US
# 3       36297         39125           39125   Italy
# 4       36298         39126           39126      US
#
#                                          description  \
# 0  Oaky and full bodied, this features minty and ...
# 1  Made solely with Pinot Nero, this offers aroma...
# 2  A dense nose of leathery violets and heavy bla...
# 3  Pressed white flowers and white peach aromas c...
# 4  A 100% varietal wine, this features big oak an...
#
#                             designation  points  price          province  \
# 0                                   NaN      89   35.0  British Columbia
# 1  Oltre Nature Metodo Classico Riserva      89   40.0       Italy Other
# 2                                   NaN      89   45.0        California
# 3                                  Brut      89   17.0            Veneto
# 4                       Keeper Vineyard      89   34.0        California
#
#                            region_1       region_2     taster_name  \
# 0                   Okanagan Valley            NaN    Paul Gregutt
# 1                     Vino Spumante            NaN   Kerin O’Keefe
# 2              Santa Cruz Mountains  Central Coast   Matt Kettmann
# 3  Valdobbiadene Prosecco Superiore            NaN   Kerin O’Keefe
# 4                  Alexander Valley         Sonoma  Virginie Boone
#
#   taster_twitter_handle                                              title  \
# 0           @paulgwine         Burrowing Owl 2011 Merlot (Okanagan Valley)
# 1          @kerinokeefe  Cà di Frara 2004 Oltre Nature Metodo Classico ...
# 2         @mattkettmann    Comartin 2013 Pinot Noir (Santa Cruz Mountains)
# 3          @kerinokeefe  Conte Collalto NV Brut  (Valdobbiadene Prosecc...
# 4               @vboone  DeLorimier 2012 Keeper Vineyard Sangiovese (Al...
#
#            variety          winery
# 0           Merlot   Burrowing Owl
# 1  Sparkling Blend     Cà di Frara
# 2       Pinot Noir        Comartin
# 3            Glera  Conte Collalto
# 4       Sangiovese      DeLorimier

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Burrowing Owl.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Burrowing+Owl
# Retrieving Results for Cà di Frara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=C%C3%A0+di+Frara
# Retrieving Results for Comartin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Comartin
# Retrieving Results for Comartin.
# used region as search
# Retrieving Results for Conte Collalto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Conte+Collalto
# Retrieving Results for DeLorimier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=DeLorimier
# Retrieving Results for Domaine Dubost.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Dubost
# Retrieving Results for Dutton Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dutton+Estate
# Retrieving Results for Joseph Perrier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Joseph+Perrier
# Retrieving Results for Marchiori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Marchiori
# Retrieving Results for Montaudon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Montaudon
# Retrieving Results for Château de Bligny.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+de+Bligny
# Retrieving Results for Cowhorn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cowhorn
# Retrieving Results for Masottina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Masottina
# Retrieving Results for McFadden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=McFadden
# Retrieving Results for Morgadío.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Morgad%C3%ADo
# Retrieving Results for Morgadío.
# used region as search
# Retrieving Results for Nunum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Nunum
# Retrieving Results for Nunum.
# Missing field/result... skipping.
# Retrieving Results for Silvano Follador.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Silvano+Follador
# Retrieving Results for Sommariva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Sommariva
# Retrieving Results for Vignerons de Bel Air.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vignerons+de+Bel+Air
# Retrieving Results for Wolfberger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Wolfberger
# Retrieving Results for Rafael Cambra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Rafael+Cambra
# Retrieving Results for Jacquart.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Jacquart
# Retrieving Results for Vignerons de Bel Air.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vignerons+de+Bel+Air
# Retrieving Results for Montaubret.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Montaubret
# Retrieving Results for Montaubret.
# used region as search
# Retrieving Results for Peter Paul Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Peter+Paul+Wines
# Retrieving Results for Peter Paul Wines.
# used region as search
# Retrieving Results for Quinta Cruz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Quinta+Cruz
# Retrieving Results for Quivira.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Quivira
# Retrieving Results for Raats Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Raats+Family
# Retrieving Results for Rancho Sisquoc.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Rancho+Sisquoc
# Retrieving Results for Raphael Dal Bo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Raphael+Dal+Bo
# Retrieving Results for Raphael Dal Bo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Raphael+Dal+Bo
# Retrieving Results for Signorello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Signorello
# Retrieving Results for Stolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stolo
# Retrieving Results for Tenuta Cà Bolani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+C%C3%A0+Bolani
# Retrieving Results for Tenuta degli Ultimi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+degli+Ultimi
# Retrieving Results for Soutiran.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Soutiran
# Retrieving Results for Troon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Troon
# Retrieving Results for V. Sattui.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=V.+Sattui
# Retrieving Results for Vincent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vincent
# Retrieving Results for Comtes de Dampierre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Comtes+de+Dampierre
# Retrieving Results for Comtes de Dampierre.
# used region as search
# Retrieving Results for Fiuza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Fiuza
# Retrieving Results for CARM.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=CARM
# Retrieving Results for Bailly-Lapierre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bailly-Lapierre
# Retrieving Results for Bellussi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bellussi
# Retrieving Results for Black Stallion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Black+Stallion
# Retrieving Results for Bodegas Bilbainas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bodegas+Bilbainas
# Retrieving Results for Bonny Doon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bonny+Doon
# Retrieving Results for Borgoluce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Borgoluce
# Retrieving Results for Brandlin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brandlin
# Retrieving Results for Fess Parker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Fess+Parker
# Retrieving Results for Trerose.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Trerose
# Retrieving Results for Jezebel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Jezebel
# Retrieving Results for Jezebel.
# used region as search
# Retrieving Results for Jim Palmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Jim+Palmer
# Retrieving Results for La Collina dei Lecci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=La+Collina+dei+Lecci
# Retrieving Results for Le Nardian.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Le+Nardian
# Retrieving Results for Le Nardian.
# Missing field/result... skipping.
# Retrieving Results for Marchesi Gondi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Marchesi+Gondi
# Retrieving Results for Wolff.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Wolff
# Retrieving Results for Joseph Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Joseph+Cellars
# Retrieving Results for La Legua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=La+Legua
# Retrieving Results for 2Hawk.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=2Hawk
# Retrieving Results for 2Hawk.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=2Hawk
# Retrieving Results for A Blooming Hill Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=A+Blooming+Hill+Vineyard
# Retrieving Results for André Kientzler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Andr%C3%A9+Kientzler
# Retrieving Results for Baccinetti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Baccinetti
# Retrieving Results for Badia di Morrona.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Badia+di+Morrona
# Retrieving Results for Belpoggio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Belpoggio
# Retrieving Results for Brooks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brooks
# Retrieving Results for Wirra Wirra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Wirra+Wirra
# Retrieving Results for ZD.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=ZD
# Retrieving Results for Ideology.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ideology
# Retrieving Results for Gracciano della Seta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Gracciano+della+Seta
# Retrieving Results for 3 Horse Ranch Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=3+Horse+Ranch+Vineyards
# Retrieving Results for Ancient Oak Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ancient+Oak+Cellars
# Retrieving Results for Antico Colle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Antico+Colle
# Retrieving Results for Argentiera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Argentiera
# Retrieving Results for Baker & Brain.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Baker+%26+Brain
# Retrieving Results for Bodegas Yuste.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bodegas+Yuste
# Retrieving Results for Château Bibian.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Bibian
# Retrieving Results for Château d'Arcins.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+d%27Arcins
# Retrieving Results for Stevens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stevens
# Retrieving Results for Stevens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stevens
# Retrieving Results for Tamarack Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tamarack+Cellars
# Retrieving Results for Tangent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tangent
# Retrieving Results for Tenshen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenshen
# Retrieving Results for Tenshen.
# used region as search
# Retrieving Results for Terras Gauda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Terras+Gauda
# Retrieving Results for The Walls.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=The+Walls
# Retrieving Results for Viberti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Viberti
# Retrieving Results for Virna Borgogno.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Virna+Borgogno
# Retrieving Results for Weszeli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Weszeli
# Retrieving Results for Wölffer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=W%C3%B6lffer
# Retrieving Results for Y Rousseau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Y+Rousseau
# Retrieving Results for Bargetto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bargetto
# Retrieving Results for Batasiolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Batasiolo
# Retrieving Results for Vignobles Guy Mousset et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vignobles+Guy+Mousset+et+Fils
# Retrieving Results for Vignobles Guy Mousset et Fils.
# used region as search
# Retrieving Results for Savage Grace.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Savage+Grace
# Retrieving Results for Cantina Terre del Barolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cantina+Terre+del+Barolo
# Retrieving Results for Cap Royal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cap+Royal
# Retrieving Results for Cap Royal.
# Missing field/result... skipping.
# Retrieving Results for Cascina Chicco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cascina+Chicco
# Retrieving Results for Catman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Catman
# Retrieving Results for Cave de Tain.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cave+de+Tain
# Retrieving Results for Château la Roque de By.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+la+Roque+de+By
# Retrieving Results for Château Léon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+L%C3%A9on
# Retrieving Results for Château Léon.
# used region as search
# Retrieving Results for Château Quinsac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Quinsac
# Retrieving Results for Château Val Joanis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Val+Joanis
# Retrieving Results for Concannon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Concannon
# Retrieving Results for Erwin Sabathi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Erwin+Sabathi
# Retrieving Results for Fontanafredda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Fontanafredda
# Retrieving Results for Wagner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Wagner
# Retrieving Results for Iago's Wine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Iago%27s+Wine
# Retrieving Results for Kopriva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kopriva
# Retrieving Results for Mahoney.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mahoney
# Retrieving Results for Mocali.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mocali
# Retrieving Results for Morovino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Morovino
# Retrieving Results for Morovino.
# used region as search
# Retrieving Results for Motta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Motta
# Retrieving Results for Arbor Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Arbor+Crest
# Retrieving Results for Benessere.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Benessere
# Retrieving Results for Boneshaker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Boneshaker
# Retrieving Results for Wellington.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Wellington
# Retrieving Results for White Oak.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=White+Oak
# Retrieving Results for White Oak.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=White+Oak
# Retrieving Results for Melini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Melini
# Retrieving Results for Mission Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mission+Estate
# Retrieving Results for Rampa di Fugnano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Rampa+di+Fugnano
# Retrieving Results for Saint Clair.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Saint+Clair
# Retrieving Results for Brancott.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brancott
# Retrieving Results for Château Musar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Musar
# Retrieving Results for Donna Olimpia 1898.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Donna+Olimpia+1898
# Retrieving Results for Flocchini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Flocchini
# Retrieving Results for Gualdo del Re.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Gualdo+del+Re
# Retrieving Results for Pieve Vecchia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Pieve+Vecchia
# Retrieving Results for Tenuta del Buonamico.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+del+Buonamico
# Retrieving Results for Tenuta del Buonamico.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+del+Buonamico
# Retrieving Results for Antonin Rodet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Antonin+Rodet
# Retrieving Results for Matetic.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Matetic
# Retrieving Results for Mercer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mercer
# Retrieving Results for Merryvale.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Merryvale
# Retrieving Results for Alta Alella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Alta+Alella
# Retrieving Results for Barrage Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Barrage+Cellars
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Br%C3%BCndlmayer
# Retrieving Results for Charles B. Mitchell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Charles+B.+Mitchell
# Retrieving Results for Château Bouissel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Bouissel
# Retrieving Results for Château d'Or et de Gueules.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+d%27Or+et+de+Gueules
# Retrieving Results for Black Stallion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Black+Stallion
# Retrieving Results for Château de Lacarelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+de+Lacarelle
# Retrieving Results for Château de Nages.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+de+Nages
# Retrieving Results for Château Laur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Laur
# Retrieving Results for Château Laur.
# used region as search
# Retrieving Results for Cliff Lede.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cliff+Lede
# Retrieving Results for Domaine de Gensac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+de+Gensac
# Retrieving Results for Efeste.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Efeste
# Retrieving Results for Greywacke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Greywacke
# Retrieving Results for Mills Reef.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mills+Reef
# Retrieving Results for Staphyle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Staphyle
# Retrieving Results for Staphyle.
# used region as search
# Retrieving Results for Cinco Sentidos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cinco+Sentidos
# Retrieving Results for Tenuta dell'Ornellaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+dell%27Ornellaia
# Retrieving Results for Tenuta dell'Ornellaia.
# used region as search
# Retrieving Results for Le Macchiole.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Le+Macchiole
# Retrieving Results for Château Haut-Brion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Haut-Brion
# Retrieving Results for Vine Cliff.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vine+Cliff
# Retrieving Results for Vine Cliff.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vine+Cliff
# Retrieving Results for Tenuta dell'Ornellaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+dell%27Ornellaia
# Retrieving Results for Tenuta dell'Ornellaia.
# used region as search
# Retrieving Results for Castello di Ama.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Castello+di+Ama
# Retrieving Results for Le Macchiole.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Le+Macchiole
# Retrieving Results for Tenuta Sette Ponti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+Sette+Ponti
# Retrieving Results for Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Hall
# Retrieving Results for Brogan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brogan
# Retrieving Results for Dutton-Goldfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dutton-Goldfield
# Retrieving Results for Mazzei.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mazzei
# Retrieving Results for Gloria Ferrer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Gloria+Ferrer
# Retrieving Results for Tenuta Argentiera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+Argentiera
# Retrieving Results for Tenuta dell'Ornellaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenuta+dell%27Ornellaia
# Retrieving Results for Tenuta dell'Ornellaia.
# used region as search
# Retrieving Results for Clos Troteligotte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Clos+Troteligotte
# Retrieving Results for Château du Cèdre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+du+C%C3%A8dre
# Retrieving Results for Kracher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kracher
# Retrieving Results for Produttori del Barbaresco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Produttori+del+Barbaresco
# Retrieving Results for Sineann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Sineann
# Retrieving Results for Sol Rouge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Sol+Rouge
# Retrieving Results for Château du Cèdre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+du+C%C3%A8dre
# Retrieving Results for Dutton-Goldfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dutton-Goldfield
# Retrieving Results for Kevin White.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kevin+White
# Retrieving Results for Lorenzi Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Lorenzi+Estate
# Retrieving Results for Pianetta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Pianetta
# Retrieving Results for Andrew Will.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Andrew+Will
# Retrieving Results for Château de Gaudou.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+de+Gaudou
# Retrieving Results for Domaine Rolet Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Rolet+P%C3%A8re+et+Fils
# Retrieving Results for Esterházy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Esterh%C3%A1zy
# Retrieving Results for Domaine Cauhapé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Cauhap%C3%A9
# Retrieving Results for Dutton-Goldfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dutton-Goldfield
# Retrieving Results for Gorman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Gorman
# Retrieving Results for Hager Matthias.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Hager+Matthias
# Retrieving Results for Hager Matthias.
# used region as search
# Retrieving Results for Kevin White.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kevin+White
# Retrieving Results for Nittnaus Anita und Hans.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Nittnaus+Anita+und+Hans
# Retrieving Results for Produttori del Barbaresco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Produttori+del+Barbaresco
# Retrieving Results for Marques de Griñon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Marques+de+Gri%C3%B1on
# Retrieving Results for Marques de Griñon.
# Missing field/result... skipping.
# Retrieving Results for Paul Hobbs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Paul+Hobbs
# Retrieving Results for Presqu'ile.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Presqu%27ile
# Retrieving Results for Produttori del Barbaresco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Produttori+del+Barbaresco
# Retrieving Results for Spy Valley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Spy+Valley
# Retrieving Results for Concha y Toro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Concha+y+Toro
# Retrieving Results for Corte Sermana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Corte+Sermana
# Retrieving Results for Domaine du Petit Clocher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+du+Petit+Clocher
# Retrieving Results for Domaine Sauvat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Sauvat
# Retrieving Results for Dopff & Irion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dopff+%26+Irion
# Retrieving Results for Doqi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Doqi
# Retrieving Results for Doqi.
# used region as search
# Retrieving Results for Drumheller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Drumheller
# Retrieving Results for Fullerton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Fullerton
# Retrieving Results for Bodegas Luzón.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bodegas+Luz%C3%B3n
# Retrieving Results for Mollydooker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mollydooker
# Retrieving Results for Jardín de Lúculo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Jard%C3%ADn+de+L%C3%BAculo
# Retrieving Results for Jardín de Lúculo.
# used region as search
# Retrieving Results for Finca Villacreces.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Finca+Villacreces
# Retrieving Results for 14 Hands.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=14+Hands
# Retrieving Results for Acquiesce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Acquiesce
# Retrieving Results for AuburnJames.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=AuburnJames
# Retrieving Results for Beronia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Beronia
# Retrieving Results for Boeger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Boeger
# Retrieving Results for Bridlewood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bridlewood
# Retrieving Results for Torres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Torres
# Retrieving Results for Cellars 33.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cellars+33
# Retrieving Results for Chacewater.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Chacewater
# Retrieving Results for Château Haut-Rian.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Haut-Rian
# Retrieving Results for Château Sainte Marie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Sainte+Marie
# Retrieving Results for Chateau Ste. Michelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Chateau+Ste.+Michelle
# Retrieving Results for Clos La Soleya.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Clos+La+Soleya
# Retrieving Results for Clos La Soleya.
# used region as search
# Retrieving Results for Domaine du Claouset.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+du+Claouset
# Retrieving Results for Domaine du Claouset.
# Missing field/result... skipping.
# Retrieving Results for Domaine Mersiol.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Mersiol
# Retrieving Results for Domaine Sauvat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Sauvat
# Retrieving Results for Ms. Behave.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ms.+Behave
# Retrieving Results for Narbona.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Narbona
# Retrieving Results for Nelson Neves.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Nelson+Neves
# Retrieving Results for Nelson Neves.
# used region as search
# Retrieving Results for Oak Farm.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Oak+Farm
# Retrieving Results for Prima Materia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Prima+Materia
# Retrieving Results for Stella Bella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stella+Bella
# Retrieving Results for Tantara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tantara
# Retrieving Results for Viña Bisquertt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vi%C3%B1a+Bisquertt
# Retrieving Results for Zaca Mesa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Zaca+Mesa
# Retrieving Results for Zaca Mesa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Zaca+Mesa
# Retrieving Results for 5OS Project.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=5OS+Project
# Retrieving Results for 5OS Project.
# used region as search
# Retrieving Results for Barton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Barton
# Retrieving Results for Barton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Barton
# Retrieving Results for Bouza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bouza
# Retrieving Results for Brassfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brassfield
# Retrieving Results for Capitoni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Capitoni
# Retrieving Results for Château Chantemerle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Chantemerle
# Retrieving Results for Château Climens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Climens
# Retrieving Results for Château du Cros.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+du+Cros
# Retrieving Results for Château Gauthier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Gauthier
# Retrieving Results for Château Haut-Bernat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Haut-Bernat
# Retrieving Results for Château Jolys.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Jolys
# Retrieving Results for Château Laroque.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Laroque
# Retrieving Results for Château Saint-André Corbin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Saint-Andr%C3%A9+Corbin
# Retrieving Results for Château Tour des Gendres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Tour+des+Gendres
# Retrieving Results for Domaine Dugois.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Dugois
# Retrieving Results for Domaine Terlato & Chapoutier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Terlato+%26+Chapoutier
# Retrieving Results for Duckhorn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Duckhorn
# Retrieving Results for Eleven Eleven.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Eleven+Eleven
# Retrieving Results for Trisaetum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Trisaetum
# Retrieving Results for Veuve Clicquot Ponsardin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Veuve+Clicquot+Ponsardin
# Retrieving Results for Veuve Clicquot Ponsardin.
# used region as search
# Retrieving Results for Yao Family Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Yao+Family+Wines
# Retrieving Results for Murgo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Murgo
# Retrieving Results for Adega Mãe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Adega+M%C3%A3e
# Retrieving Results for Mailly Grand Cru.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mailly+Grand+Cru
# Retrieving Results for John Duval Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=John+Duval+Wines
# Retrieving Results for Trisaetum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Trisaetum
# Retrieving Results for Trisaetum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Trisaetum
# Retrieving Results for Henri Abele.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Henri+Abele
# Retrieving Results for 29 & Oak Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=29+%26+Oak+Wines
# Retrieving Results for Abadia Retuerta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Abadia+Retuerta
# Retrieving Results for Real Companhia Velha.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Real+Companhia+Velha
# Retrieving Results for Brian Benson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brian+Benson
# Retrieving Results for Cedarville.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cedarville
# Retrieving Results for Château Barbé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Barb%C3%A9
# Retrieving Results for Domaine de l'A.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+de+l%27A
# Retrieving Results for Dr. Heidemanns-Bergweiler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dr.+Heidemanns-Bergweiler
# Retrieving Results for Elk Cove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Elk+Cove
# Retrieving Results for Lombard et Cie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Lombard+et+Cie
# Retrieving Results for Lombard et Cie.
# used region as search
# Retrieving Results for Louis Roederer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Louis+Roederer
# Retrieving Results for Marco Abella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Marco+Abella
# Retrieving Results for Penner-Ash.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Penner-Ash
# Retrieving Results for Penner-Ash.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Penner-Ash
# Retrieving Results for Robert Biale.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Robert+Biale
# Retrieving Results for Talbott.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Talbott
# Retrieving Results for Terrazze dell'Etna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Terrazze+dell%27Etna
# Retrieving Results for Testarossa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Testarossa
# Retrieving Results for Murgo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Murgo
# Retrieving Results for Quinta das Carvalhas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Quinta+das+Carvalhas
# Retrieving Results for Tarara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tarara
# Retrieving Results for Valle dell'Acate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Valle+dell%27Acate
# Retrieving Results for Illahe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Illahe
# Retrieving Results for J. Scott Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=J.+Scott+Cellars
# Retrieving Results for J. Scott Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=J.+Scott+Cellars
# Retrieving Results for Jean-Luc Baldès.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Jean-Luc+Bald%C3%A8s
# Retrieving Results for Jean-Luc Baldès.
# used region as search
# Retrieving Results for Kalaris.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kalaris
# Retrieving Results for Westrey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Westrey
# Retrieving Results for Westrey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Westrey
# Retrieving Results for Argiolas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Argiolas
# Retrieving Results for Argiolas.
# Missing field/result... skipping.
# Retrieving Results for Château du Port.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+du+Port
# Retrieving Results for Château Lanbersac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Lanbersac
# Retrieving Results for Château Tour Seran.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Tour+Seran
# Retrieving Results for Château Tour Seran.
# used region as search
# Retrieving Results for Cusumano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cusumano
# Retrieving Results for Damian Rae.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Damian+Rae
# Retrieving Results for Domaine Bru-Baché.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Bru-Bach%C3%A9
# Retrieving Results for Eight Bells.
# ...
# Retrieving Results for Santa Rita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Santa+Rita
# Retrieving Results for Schloss Gobelsburg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Schloss+Gobelsburg
# Retrieving Results for Simonsig.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Simonsig
# Retrieving Results for Fairview.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Fairview
# Retrieving Results for Chateau de Pibarnon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Chateau+de+Pibarnon
# Retrieving Results for Jax.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Jax
# Retrieving Results for La Chablisienne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=La+Chablisienne
# Retrieving Results for La Chablisienne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=La+Chablisienne
# Retrieving Results for Law.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Law
# Retrieving Results for Piña.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Pi%C3%B1a
# Retrieving Results for Betz Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Betz+Family
# Retrieving Results for Black Kite.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Black+Kite
# Retrieving Results for Davis Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Davis+Family
# Retrieving Results for DeLille.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=DeLille
# Retrieving Results for Deutz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Deutz
# Retrieving Results for Dominio IV.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dominio+IV
# Retrieving Results for Dragonette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dragonette
# Retrieving Results for Gosset.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Gosset
# Retrieving Results for Gosset.
# used region as search
# Retrieving Results for Guastaferro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Guastaferro
# Retrieving Results for Guastaferro.
# used region as search
# Retrieving Results for Huré Frères.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Hur%C3%A9+Fr%C3%A8res
# Retrieving Results for Kenefick Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kenefick+Ranch
# Retrieving Results for Casa Santos Lima.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Casa+Santos+Lima
# Retrieving Results for Chamisal Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Chamisal+Vineyards
# Retrieving Results for Domaine Divio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Divio
# Retrieving Results for Dragonette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dragonette
# Retrieving Results for Dragonette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dragonette
# Retrieving Results for Gramercy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Gramercy
# Retrieving Results for Law.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Law
# Retrieving Results for Le Cadeau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Le+Cadeau
# Retrieving Results for Maximin Grünhäuser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Maximin+Gr%C3%BCnh%C3%A4user
# Retrieving Results for Morandé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Morand%C3%A9
# Retrieving Results for Paraduxx.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Paraduxx
# Retrieving Results for Patel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Patel
# Retrieving Results for Paul O'Brien.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Paul+O%27Brien
# Retrieving Results for Polkura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Polkura
# Retrieving Results for Polkura.
# used region as search
# Retrieving Results for Beaulieu Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Beaulieu+Vineyard
# Retrieving Results for Laleure-Piot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Laleure-Piot
# Retrieving Results for Clark-Claudon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Clark-Claudon
# Retrieving Results for Clark-Claudon.
# used region as search
# Retrieving Results for St. Supéry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=St.+Sup%C3%A9ry
# Retrieving Results for Signorello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Signorello
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Louis+Latour
# Retrieving Results for Robert Craig.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Robert+Craig
# Retrieving Results for Lancaster.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Lancaster
# Retrieving Results for Liparita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Liparita
# Retrieving Results for St. Clement.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=St.+Clement
# Retrieving Results for Staglin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Staglin
# Retrieving Results for Nickel & Nickel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Nickel+%26+Nickel
# Retrieving Results for Seavey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Seavey
# Retrieving Results for Spring Mountain Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Spring+Mountain+Vineyard
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Kendall-Jackson
# Retrieving Results for Frog's Leap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Frog%27s+Leap
# Retrieving Results for V Norte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=V+Norte
# Retrieving Results for Valle dell'Acate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Valle+dell%27Acate
# Retrieving Results for Villa Raiano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Villa+Raiano
# Retrieving Results for Antica Enotria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Antica+Enotria
# Retrieving Results for Aura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Aura
# Retrieving Results for Bianchi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Bianchi
# Retrieving Results for Breaux.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Breaux
# Retrieving Results for Cantina Sociale di Dolianova.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cantina+Sociale+di+Dolianova
# Retrieving Results for Caruso & Minini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Caruso+%26+Minini
# Retrieving Results for Château de Pizay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+de+Pizay
# Retrieving Results for Château Tour des Gendres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ch%C3%A2teau+Tour+des+Gendres
# Retrieving Results for Colosi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Colosi
# Retrieving Results for Courtney Benham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Courtney+Benham
# Retrieving Results for Cusumano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cusumano
# Retrieving Results for Planeta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Planeta
# Retrieving Results for Principi di Spadafora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Principi+di+Spadafora
# Retrieving Results for Rancho Zabaco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Rancho+Zabaco
# Retrieving Results for Robert Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Robert+Hall
# Retrieving Results for Santa Helena.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Santa+Helena
# Retrieving Results for Smoking Loon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Smoking+Loon
# Retrieving Results for Spindrift Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Spindrift+Cellars
# Retrieving Results for Stemmari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stemmari
# Retrieving Results for Stemmari.
# used region as search
# Retrieving Results for Stemmari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stemmari
# Retrieving Results for Stemmari.
# used region as search
# Retrieving Results for Stemmari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Stemmari
# Retrieving Results for Stemmari.
# used region as search
# Retrieving Results for Tasca d'Almerita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tasca+d%27Almerita
# Retrieving Results for Tortoise Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tortoise+Creek
# Retrieving Results for Tortoise Creek.
# Missing field/result... skipping.
# Retrieving Results for Tres Palacios.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tres+Palacios
# Retrieving Results for Tres Palacios.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tres+Palacios
# Retrieving Results for Root:1.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Root%3A1
# Retrieving Results for Sandhi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Sandhi
# Retrieving Results for Teanum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Teanum
# Retrieving Results for Tinhorn Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tinhorn+Creek
# Retrieving Results for Tommasi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tommasi
# Retrieving Results for Baron Philippe de Rothschild.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Baron+Philippe+de+Rothschild
# Retrieving Results for De Bortoli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=De+Bortoli
# Retrieving Results for Imagery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Imagery
# Retrieving Results for Mocavero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Mocavero
# Retrieving Results for Mocavero.
# used region as search
# Retrieving Results for Naggiar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Naggiar
# Retrieving Results for Naggiar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Naggiar
# Retrieving Results for Oakwild Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Oakwild+Ranch
# Retrieving Results for Brander.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Brander
# Retrieving Results for Cantele.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Cantele
# Retrieving Results for Ryan Patrick.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Ryan+Patrick
# Retrieving Results for Santa Ema.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Santa+Ema
# Retrieving Results for Tenute Girolamo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tenute+Girolamo
# Retrieving Results for Tommasi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Tommasi
# Retrieving Results for Torrevento.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Torrevento
# Retrieving Results for Domaine du Moulin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+du+Moulin
# Retrieving Results for Domaine Joël Delaunay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Domaine+Jo%C3%ABl+Delaunay
# Retrieving Results for Dominican Oaks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Dominican+Oaks
# Retrieving Results for Vortex.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyAXcDUUkwTzZFWYcjLTrpWUeHhrapM1vqo&address=Vortex

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('4coord.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 country  \
# 0       36294         39122           39122  Canada
# 1       36295         39123           39123   Italy
# 2       36296         39124           39124      US
# 3       36297         39125           39125   Italy
# 4       36298         39126           39126      US
#
#                                          description  \
# 0  Oaky and full bodied, this features minty and ...
# 1  Made solely with Pinot Nero, this offers aroma...
# 2  A dense nose of leathery violets and heavy bla...
# 3  Pressed white flowers and white peach aromas c...
# 4  A 100% varietal wine, this features big oak an...
#
#                             designation  points  price          province  \
# 0                                   NaN      89   35.0  British Columbia
# 1  Oltre Nature Metodo Classico Riserva      89   40.0       Italy Other
# 2                                   NaN      89   45.0        California
# 3                                  Brut      89   17.0            Veneto
# 4                       Keeper Vineyard      89   34.0        California
#
#                            region_1       region_2     taster_name  \
# 0                   Okanagan Valley            NaN    Paul Gregutt
# 1                     Vino Spumante            NaN   Kerin O’Keefe
# 2              Santa Cruz Mountains  Central Coast   Matt Kettmann
# 3  Valdobbiadene Prosecco Superiore            NaN   Kerin O’Keefe
# 4                  Alexander Valley         Sonoma  Virginie Boone
#
#   taster_twitter_handle                                              title  \
# 0           @paulgwine         Burrowing Owl 2011 Merlot (Okanagan Valley)
# 1          @kerinokeefe  Cà di Frara 2004 Oltre Nature Metodo Classico ...
# 2         @mattkettmann    Comartin 2013 Pinot Noir (Santa Cruz Mountains)
# 3          @kerinokeefe  Conte Collalto NV Brut  (Valdobbiadene Prosecc...
# 4               @vboone  DeLorimier 2012 Keeper Vineyard Sangiovese (Al...
#
#            variety          winery        Lat         Lng  heat weights
# 0           Merlot   Burrowing Owl  49.101389 -119.533056             9
# 1  Sparkling Blend     Cà di Frara  45.010123    9.184226             9
# 2       Pinot Noir        Comartin  37.110892 -121.844891             9
# 3            Glera  Conte Collalto  45.849588   12.247459             9
# 4       Sangiovese      DeLorimier  38.715539 -122.892581             9

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
