# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys_Copy1 import g_key

# %%
file = '5.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       country  \
# 0       48392         52055           52055  South Africa
# 1       48393         52056           52056            US
# 2       48394         52057           52057            US
# 3       48395         52058           52058            US
# 4       48396         52059           52059            US
#
#                                          description           designation  \
# 0  Notes of caramel sauce and balsamic reduction ...            Mocha Java
# 1  It's big and brawny, with a very deep color, s...  Estate Grown Reserve
# 2  Dried peach and apple flavors peek out timidly...          Late Harvest
# 3  Broad and easy in texture, this is tempting to...                   NaN
# 4  The color of this wine has a touch of brown at...   Upper Russian River
#
#    points  price        province      region_1          region_2  \
# 0      85   13.0  Coastal Region           NaN               NaN
# 1      85   24.0      California     Fair Play  Sierra Foothills
# 2      85   15.0        New York  Finger Lakes      Finger Lakes
# 3      85    9.0      California    California  California Other
# 4      85   30.0      California     Mendocino               NaN
#
#           taster_name taster_twitter_handle  \
# 0       Lauren Buzzeo             @laurbuzz
# 1          Jim Gordon      @gordone_cellars
# 2  Anna Lee C. Iijima                   NaN
# 3          Jim Gordon      @gordone_cellars
# 4          Jim Gordon      @gordone_cellars
#
#                                                title     variety  \
# 0  Bellingham 2013 Mocha Java Merlot (Coastal Reg...      Merlot
# 1  Charles B. Mitchell 2012 Estate Grown Reserve ...      Merlot
# 2  Chateau Lafayette Reneau 2012 Late Harvest Rie...    Riesling
# 3              Happy Camper 2012 Merlot (California)      Merlot
# 4  Jeriko 2012 Upper Russian River Pinot Noir (Me...  Pinot Noir
#
#                      winery
# 0                Bellingham
# 1       Charles B. Mitchell
# 2  Chateau Lafayette Reneau
# 3              Happy Camper
# 4                    Jeriko

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Bellingham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bellingham
# Retrieving Results for Charles B. Mitchell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Charles+B.+Mitchell
# Retrieving Results for Chateau Lafayette Reneau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chateau+Lafayette+Reneau
# Retrieving Results for Happy Camper.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Happy+Camper
# Retrieving Results for Jeriko.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jeriko
# Retrieving Results for Lionel Osmin & Cie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lionel+Osmin+%26+Cie
# Retrieving Results for MacMurray Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=MacMurray+Ranch
# Retrieving Results for Begali.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Begali
# Retrieving Results for Viña el Aromo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+el+Aromo
# Retrieving Results for Ervideira.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ervideira
# Retrieving Results for Angeline.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Angeline
# Retrieving Results for Morandé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Morand%C3%A9
# Retrieving Results for North Gate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=North+Gate
# Retrieving Results for Meli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Meli
# Retrieving Results for Villa Spinosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Villa+Spinosa
# Retrieving Results for Andrieux & Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Andrieux+%26+Fils
# Retrieving Results for Andrieux & Fils.
# used region as search
# Retrieving Results for Cherokee Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cherokee+Vineyards
# Retrieving Results for Conde de Jauregui.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Conde+de+Jauregui
# Retrieving Results for Conde de Jauregui.
# used region as search
# Retrieving Results for Tres Ojos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tres+Ojos
# Retrieving Results for Castle Rock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Castle+Rock
# Retrieving Results for Divine Llama.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Divine+Llama
# Retrieving Results for Fiddlehead.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fiddlehead
# Retrieving Results for Pepperwood Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pepperwood+Grove
# Retrieving Results for Quasar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quasar
# Retrieving Results for Rock Hollow.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rock+Hollow
# Retrieving Results for Tamaya.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tamaya
# Retrieving Results for Père Anselme.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=P%C3%A8re+Anselme
# Retrieving Results for Père Anselme.
# Missing field/result... skipping.
# Retrieving Results for Santa Ema.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Ema
# Retrieving Results for Heaven's Cave.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Heaven%27s+Cave
# Retrieving Results for Brigaldara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Brigaldara
# Retrieving Results for Concrete.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Concrete
# Retrieving Results for Contini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Contini
# Retrieving Results for Corley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Corley
# Retrieving Results for Domaine Dampt Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Dampt+P%C3%A8re+et+Fils
# Retrieving Results for Domingo Molina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domingo+Molina
# Retrieving Results for Elk Cove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Elk+Cove
# Retrieving Results for Erzetič.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Erzeti%C4%8D
# Retrieving Results for Erzetič.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Erzeti%C4%8D
# Retrieving Results for Watermill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Watermill
# Retrieving Results for Willamette Valley Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Willamette+Valley+Vineyards
# Retrieving Results for ZinPhomaniac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=ZinPhomaniac
# Retrieving Results for ZinPhomaniac.
# used region as search
# Retrieving Results for Hawk Watch Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hawk+Watch+Winery
# Retrieving Results for Jean-Claude Debeaune.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jean-Claude+Debeaune
# Retrieving Results for Jean-Claude Debeaune.
# Missing field/result... skipping.
# Retrieving Results for Left Coast Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Left+Coast+Cellars
# Retrieving Results for Lovingston.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lovingston
# Retrieving Results for Mesa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mesa
# Retrieving Results for Michel Torino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Michel+Torino
# Retrieving Results for Michel Torino.
# used region as search
# Retrieving Results for Moccagatta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Moccagatta
# Retrieving Results for Mt. Monster.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mt.+Monster
# Retrieving Results for Paradise Springs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paradise+Springs
# Retrieving Results for Poderi Elia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poderi+Elia
# Retrieving Results for Poderi Elia.
# used region as search
# Retrieving Results for Quady North.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quady+North
# Retrieving Results for Quinta de la Rosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+de+la+Rosa
# Retrieving Results for Quinta do Vallado.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+do+Vallado
# Retrieving Results for San Biagio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=San+Biagio
# Retrieving Results for San Biagio.
# used region as search
# Retrieving Results for Soléna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sol%C3%A9na
# Retrieving Results for Alma Rosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alma+Rosa
# Retrieving Results for Aurielle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Aurielle
# Retrieving Results for Aurielle.
# used region as search
# Retrieving Results for Bardessono.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bardessono
# Retrieving Results for Breggo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Breggo
# Retrieving Results for Breggo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Breggo
# Retrieving Results for Bruno Paillard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bruno+Paillard
# Retrieving Results for Calera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Calera
# Retrieving Results for Cockerell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cockerell
# Retrieving Results for Frank Cornelissen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Frank+Cornelissen
# Retrieving Results for Gloria Ferrer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gloria+Ferrer
# Retrieving Results for Trivento.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trivento
# Retrieving Results for Von Strasser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Von+Strasser
# Retrieving Results for Von Strasser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Von+Strasser
# Retrieving Results for Paradise Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paradise+Ridge
# Retrieving Results for Passopisciaro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Passopisciaro
# Retrieving Results for Pol Roger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pol+Roger
# Retrieving Results for Pol Roger.
# used region as search
# Retrieving Results for Sartori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sartori
# Retrieving Results for Corte Sant' Alda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Corte+Sant%27+Alda
# Retrieving Results for Colin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Colin
# Retrieving Results for Forefathers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Forefathers
# Retrieving Results for Bodega Catena Zapata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodega+Catena+Zapata
# Retrieving Results for Cornaleto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cornaleto
# Retrieving Results for Derby.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Derby
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gary+Farrell
# Retrieving Results for Horse & Plow.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Horse+%26+Plow
# Retrieving Results for Barone Pizzini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barone+Pizzini
# Retrieving Results for Zorzal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zorzal
# Retrieving Results for Zorzal.
# used region as search
# Retrieving Results for Jeriko.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jeriko
# Retrieving Results for Lakewood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lakewood
# Retrieving Results for Lamoreaux Landing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lamoreaux+Landing
# Retrieving Results for Olivier Leflaive.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Olivier+Leflaive
# Retrieving Results for Paul Buisse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paul+Buisse
# Retrieving Results for Pavillion Crossing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pavillion+Crossing
# Retrieving Results for Pierre André.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pierre+Andr%C3%A9
# Retrieving Results for Villa Sandi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Villa+Sandi
# Retrieving Results for Wiese & Krohn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wiese+%26+Krohn
# Retrieving Results for Wiese & Krohn.
# used region as search
# Retrieving Results for François Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fran%C3%A7ois+Lurton
# Retrieving Results for Glenora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Glenora
# Retrieving Results for Mayacamas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mayacamas
# Retrieving Results for L'Ecole No. 41.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=L%27Ecole+No.+41
# Retrieving Results for Alto Los Romeros.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alto+Los+Romeros
# Retrieving Results for Aurelio Settimo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Aurelio+Settimo
# Retrieving Results for Aurelio Settimo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Aurelio+Settimo
# Retrieving Results for B Side.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=B+Side
# Retrieving Results for Barnard Griffin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barnard+Griffin
# Retrieving Results for Calicaro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Calicaro
# Retrieving Results for Calicaro.
# used region as search
# Retrieving Results for Vasse Felix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vasse+Felix
# Retrieving Results for William Church.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=William+Church
# Retrieving Results for William Church.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=William+Church
# Retrieving Results for Château Barreyre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Barreyre
# Retrieving Results for Côte Bonneville.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=C%C3%B4te+Bonneville
# Retrieving Results for Giacomo Fenocchio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Giacomo+Fenocchio
# Retrieving Results for Rocche Costamagna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rocche+Costamagna
# Retrieving Results for San Biagio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=San+Biagio
# Retrieving Results for San Biagio.
# used region as search
# Retrieving Results for Gebeshuber.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gebeshuber
# Retrieving Results for Gebeshuber.
# used region as search
# Retrieving Results for Moss Wood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Moss+Wood
# Retrieving Results for Mount Veeder.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mount+Veeder
# Retrieving Results for Patz & Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Patz+%26+Hall
# Retrieving Results for Domaine D'en Ségur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+D%27en+S%C3%A9gur
# Retrieving Results for Emiliana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Emiliana
# Retrieving Results for Estampa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Estampa
# Retrieving Results for Fess Parker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fess+Parker
# Retrieving Results for Foley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Foley
# Retrieving Results for Franciscan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Franciscan
# Retrieving Results for Joseph Carr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Joseph+Carr
# Retrieving Results for Kilikanoon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kilikanoon
# Retrieving Results for Kontos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kontos
# Retrieving Results for Luis Felipe Edwards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Luis+Felipe+Edwards
# Retrieving Results for I Veroni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=I+Veroni
# Retrieving Results for Il Bosco di Grazia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Il+Bosco+di+Grazia
# Retrieving Results for Vega Montán.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vega+Mont%C3%A1n
# Retrieving Results for Vega Montán.
# used region as search
# Retrieving Results for ZD.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=ZD
# Retrieving Results for La Ciarliana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Ciarliana
# Retrieving Results for Loring Wine Company.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Loring+Wine+Company
# Retrieving Results for Love & Squalor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Love+%26+Squalor
# Retrieving Results for Michael Sullberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Michael+Sullberg
# Retrieving Results for Miner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Miner
# Retrieving Results for Morgadío.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Morgad%C3%ADo
# Retrieving Results for Morgadío.
# used region as search
# Retrieving Results for Pieve de' Pitti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pieve+de%27+Pitti
# Retrieving Results for PoderNuovo a Palazzone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=PoderNuovo+a+Palazzone
# Retrieving Results for Poggio Nardone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poggio+Nardone
# Retrieving Results for Poggio Nardone.
# used region as search
# Retrieving Results for Poggio Nardone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poggio+Nardone
# Retrieving Results for Poggio Nardone.
# used region as search
# Retrieving Results for Pratesi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pratesi
# Retrieving Results for Provenance Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Provenance+Vineyards
# Retrieving Results for Rascioni e Cecconello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rascioni+e+Cecconello
# Retrieving Results for Sbragia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sbragia
# Retrieving Results for Sokol Blosser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sokol+Blosser
# Retrieving Results for Soléna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sol%C3%A9na
# Retrieving Results for Soléna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sol%C3%A9na
# Retrieving Results for Tenuta Forconi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+Forconi
# Retrieving Results for Trerose.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trerose
# Retrieving Results for Uccelliera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Uccelliera
# Retrieving Results for Viña Bujanda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Bujanda
# Retrieving Results for Viña Bujanda.
# used region as search
# Retrieving Results for Viña Somoza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Somoza
# Retrieving Results for Bernardus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bernardus
# Retrieving Results for Boscarelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Boscarelli
# Retrieving Results for Caccia al Piano 1868.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Caccia+al+Piano+1868
# Retrieving Results for Canneto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Canneto
# Retrieving Results for Elena Walch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Elena+Walch
# Retrieving Results for Emidio Pepe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Emidio+Pepe
# Retrieving Results for Emiliana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Emiliana
# Retrieving Results for Gordon Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gordon+Estate
# Retrieving Results for Gordon Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gordon+Estate
# Retrieving Results for Gustafson Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gustafson+Family
# Retrieving Results for Hawks View.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hawks+View
# Retrieving Results for Healdsburg Ranches.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Healdsburg+Ranches
# Retrieving Results for Loriñon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lori%C3%B1on
# Retrieving Results for Loriñon.
# used region as search
# Retrieving Results for Manzoni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Manzoni
# Retrieving Results for Marqués de Cáceres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marqu%C3%A9s+de+C%C3%A1ceres
# Retrieving Results for Materra Cunat Family Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Materra+Cunat+Family+Vineyards
# Retrieving Results for McCrea Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=McCrea+Cellars
# Retrieving Results for McCrea Cellars.
# used region as search
# Retrieving Results for Peju.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Peju
# Retrieving Results for Revelry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Revelry
# Retrieving Results for San Lorenzo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=San+Lorenzo
# Retrieving Results for Santa Alicia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Alicia
# Retrieving Results for Silverado.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Silverado
# Retrieving Results for Stevens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stevens
# Retrieving Results for Torii Mor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Torii+Mor
# Retrieving Results for Villa Gianna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Villa+Gianna
# Retrieving Results for Voss.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Voss
# Retrieving Results for J. Lohr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+Lohr
# Retrieving Results for King Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=King+Estate
# Retrieving Results for Wente.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wente
# Retrieving Results for Odfjell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Odfjell
# Retrieving Results for Landshut.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Landshut
# Retrieving Results for Maddalena.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Maddalena
# Retrieving Results for Picket Fence.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Picket+Fence
# Retrieving Results for Post House.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Post+House
# Retrieving Results for Red Pony Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Red+Pony+Ranch
# Retrieving Results for Rock Wall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rock+Wall
# Retrieving Results for Skouras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Skouras
# Retrieving Results for Cinnabar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cinnabar
# Retrieving Results for Clos du Val.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Clos+du+Val
# Retrieving Results for Haras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Haras
# Retrieving Results for Headbanger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Headbanger
# Retrieving Results for A. Parparoussis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=A.+Parparoussis
# Retrieving Results for Las Lomas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Las+Lomas
# Retrieving Results for Stellenbosch Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stellenbosch+Hills
# Retrieving Results for Vino dei Fratelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vino+dei+Fratelli
# Retrieving Results for Vino dei Fratelli.
# used region as search
# Retrieving Results for Rooiberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rooiberg
# Retrieving Results for Purple Hands.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Purple+Hands
# Retrieving Results for Robert Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Robert+Hall
# Retrieving Results for Rock Wall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rock+Wall
# Retrieving Results for Scott Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Scott+Cellars
# Retrieving Results for Scott Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Scott+Cellars
# Retrieving Results for Terra Valentine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Terra+Valentine
# Retrieving Results for Beyerskloof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Beyerskloof
# Retrieving Results for Easton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Easton
# Retrieving Results for Margrain.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Margrain
# Retrieving Results for Petrucco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Petrucco
# Retrieving Results for Pighin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pighin
# Retrieving Results for Progettidivini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Progettidivini
# Retrieving Results for Progettidivini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Progettidivini
# Retrieving Results for Ricardo Santos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ricardo+Santos
# Retrieving Results for Smythe & Renfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Smythe+%26+Renfield
# Retrieving Results for Smythe & Renfield.
# used region as search
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kendall-Jackson
# Retrieving Results for Kenefick Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kenefick+Ranch
# Retrieving Results for La Farra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Farra
# Retrieving Results for Laetitia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Laetitia
# Retrieving Results for Le Manzane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Manzane
# Retrieving Results for Le Manzane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Manzane
# Retrieving Results for Masottina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Masottina
# Retrieving Results for Morgan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Morgan
# Retrieving Results for Ojai.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ojai
# Retrieving Results for Piera Martellozzo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Piera+Martellozzo
# Retrieving Results for Gaierhof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gaierhof
# Retrieving Results for Shannon Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Shannon+Ridge
# Retrieving Results for Solar de Pinheiro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Solar+de+Pinheiro
# Retrieving Results for Solar de Pinheiro.
# used region as search
# Retrieving Results for Starmont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Starmont
# Retrieving Results for Valdo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Valdo
# Retrieving Results for Alta Vista.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alta+Vista
# Retrieving Results for Bodega Norton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodega+Norton
# Retrieving Results for Borgo Magredo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Borgo+Magredo
# Retrieving Results for Borgo Magredo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Borgo+Magredo
# Retrieving Results for J Vineyards & Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J+Vineyards+%26+Winery
# Retrieving Results for JR Wine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=JR+Wine
# Retrieving Results for Lamoreaux Landing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lamoreaux+Landing
# Retrieving Results for Malibu Rocky Oaks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Malibu+Rocky+Oaks
# Retrieving Results for Morgante.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Morgante
# Retrieving Results for Nicosia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Nicosia
# Retrieving Results for Nicosia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Nicosia
# Retrieving Results for Palari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Palari
# Retrieving Results for Planeta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Planeta
# Retrieving Results for Rozes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rozes
# Retrieving Results for Rozes.
# used region as search
# Retrieving Results for Stevens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stevens
# Retrieving Results for Stevens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stevens
# Retrieving Results for Valle dell'Acate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Valle+dell%27Acate
# Retrieving Results for Vellum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vellum
# Retrieving Results for Ventisquero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ventisquero
# Retrieving Results for Feudi del Pisciotto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Feudi+del+Pisciotto
# Retrieving Results for Feudo Arancio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Feudo+Arancio
# Retrieving Results for Feudo Arancio.
# used region as search
# Retrieving Results for Garnier et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Garnier+et+Fils
# Retrieving Results for Glenora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Glenora
# Retrieving Results for HandCraft.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=HandCraft
# Retrieving Results for HandCraft.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=HandCraft
# Retrieving Results for Hightower.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hightower
# Retrieving Results for Villa Maria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Villa+Maria
# Retrieving Results for Viña Bujanda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Bujanda
# Retrieving Results for Viña Bujanda.
# used region as search
# Retrieving Results for Yorkville Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Yorkville+Cellars
# Retrieving Results for Cantine Rallo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cantine+Rallo
# Retrieving Results for Ceuso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ceuso
# Retrieving Results for Ceuso.
# used region as search
# Retrieving Results for Domaine Laporte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Laporte
# Retrieving Results for Dona Maria-Júlio Bastos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dona+Maria-J%C3%BAlio+Bastos
# Retrieving Results for Dona Maria-Júlio Bastos.
# used region as search
# Retrieving Results for Dr. Nägler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+N%C3%A4gler
# Retrieving Results for Draga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Draga
# Retrieving Results for Eola Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Eola+Hills
# Retrieving Results for Fantinel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fantinel
# Retrieving Results for Ferruccio Sgubin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ferruccio+Sgubin
# Retrieving Results for Fess Parker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fess+Parker
# Retrieving Results for Firestone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Firestone
# Retrieving Results for Fullerton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fullerton
# Retrieving Results for Girlan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Girlan
# Retrieving Results for Gradis'ciutta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gradis%27ciutta
# Retrieving Results for Viña Altamar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Altamar
# Retrieving Results for Viña Altamar.
# used region as search
# Retrieving Results for Weinhof Kobler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Weinhof+Kobler
# Retrieving Results for Weinhof Kobler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Weinhof+Kobler
# Retrieving Results for Tramin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tramin
# Retrieving Results for Treos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Treos
# Retrieving Results for Moser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Moser
# Retrieving Results for Peter Jakob Kühn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Peter+Jakob+K%C3%BChn
# Retrieving Results for Peter Zemmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Peter+Zemmer
# Retrieving Results for Pinord.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pinord
# Retrieving Results for Plaisance Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Plaisance+Ranch
# Retrieving Results for Primosic.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Primosic
# Retrieving Results for Quinta da Lapa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+da+Lapa
# Retrieving Results for Quinta da Lapa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+da+Lapa
# Retrieving Results for Quinta de Sant'Ana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+de+Sant%27Ana
# Retrieving Results for Alexander Valley Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alexander+Valley+Vineyards
# Retrieving Results for Willow Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Willow+Crest
# Retrieving Results for Cinco Sentidos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cinco+Sentidos
# Retrieving Results for Columbia Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Columbia+Crest
# Retrieving Results for Coquelicot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Coquelicot
# Retrieving Results for Douglas Green.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Douglas+Green
# Retrieving Results for Fabiano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fabiano
# Retrieving Results for Finca Decero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Decero
# Retrieving Results for Hauck.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hauck
# Retrieving Results for Bonotto delle Tezze.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bonotto+delle+Tezze
# Retrieving Results for Bosio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bosio
# Retrieving Results for Casa de la Cruz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Casa+de+la+Cruz
# Retrieving Results for Château Suau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Suau
# Retrieving Results for Pfendler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pfendler
# Retrieving Results for Stift Klosterneuburg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Stift+Klosterneuburg
# Retrieving Results for TerraNoble.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=TerraNoble
# Retrieving Results for TerraNoble.
# used region as search
# Retrieving Results for Thelema.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Thelema
# Retrieving Results for Thelema.
# used region as search
# Retrieving Results for Yorba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Yorba
# Retrieving Results for Le Vigne di Domenico.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Vigne+di+Domenico
# Retrieving Results for Martin Ray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Martin+Ray
# Retrieving Results for Michel Torino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Michel+Torino
# ...
# Retrieving Results for Segura Viudas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Segura+Viudas
# Retrieving Results for Langtry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Langtry
# Retrieving Results for Col Vetoraz Spumanti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Col+Vetoraz+Spumanti
# Retrieving Results for Falcor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Falcor
# Retrieving Results for Herdade do Esporão.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Herdade+do+Espor%C3%A3o
# Retrieving Results for Toffoli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Toffoli
# Retrieving Results for Mad Dogs & Englishmen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mad+Dogs+%26+Englishmen
# Retrieving Results for Les Clos de Paulilles.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Les+Clos+de+Paulilles
# Retrieving Results for Marquis de la Tour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marquis+de+la+Tour
# Retrieving Results for Quinta do Carmo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+do+Carmo
# Retrieving Results for Toffoli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Toffoli
# Retrieving Results for Juslyn Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Juslyn+Vineyards
# Retrieving Results for Karl Erbes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Karl+Erbes
# Retrieving Results for Vallformosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vallformosa
# Retrieving Results for Cono Sur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cono+Sur
# Retrieving Results for Domaine de la Prébende.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+de+la+Pr%C3%A9bende
# Retrieving Results for Domaine de la Prébende.
# used region as search
# Retrieving Results for Dr. Konstantin Frank.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dr.+Konstantin+Frank
# Retrieving Results for Finn Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finn+Hill
# Retrieving Results for Garces Silva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Garces+Silva
# Retrieving Results for Gen5.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gen5
# Retrieving Results for Ironstone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ironstone
# Retrieving Results for JCR.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=JCR
# Retrieving Results for L. Tramier & Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=L.+Tramier+%26+Fils
# Retrieving Results for L. Tramier & Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=L.+Tramier+%26+Fils
# Retrieving Results for La Spinetta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Spinetta
# Retrieving Results for Lorgeril.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lorgeril
# Retrieving Results for Lorgeril.
# used region as search
# Retrieving Results for Lorgeril.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lorgeril
# Retrieving Results for Lorgeril.
# used region as search
# Retrieving Results for Naggiar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Naggiar
# Retrieving Results for Portal del Montsant.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Portal+del+Montsant
# Retrieving Results for Tamber Bey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tamber+Bey
# Retrieving Results for Araldica.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Araldica
# Retrieving Results for Araldica.
# used region as search
# Retrieving Results for Bodegas Vegalfaro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Vegalfaro
# Retrieving Results for Bonair.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bonair
# Retrieving Results for Calmel & Joseph.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Calmel+%26+Joseph
# Retrieving Results for Canoe Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Canoe+Ridge
# Retrieving Results for Cave des Grands Crus Blancs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cave+des+Grands+Crus+Blancs
# Retrieving Results for Château de Pizay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+de+Pizay
# Retrieving Results for Château du Carrubier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+du+Carrubier
# Retrieving Results for Clos Pons.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Clos+Pons
# Retrieving Results for Dante Robere.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dante+Robere
# Retrieving Results for Domaine des Deux Roches.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+des+Deux+Roches
# Retrieving Results for Porta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Porta
# Retrieving Results for Benjamin de Rothschild & Vega Sicilia SA.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Benjamin+de+Rothschild+%26+Vega+Sicilia+SA
# Retrieving Results for Benjamin de Rothschild & Vega Sicilia SA.
# used region as search
# Retrieving Results for Cairdeas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cairdeas
# Retrieving Results for Cameron Hughes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cameron+Hughes
# Retrieving Results for Château Gaudin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Gaudin
# Retrieving Results for Chateau Margene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chateau+Margene
# Retrieving Results for Ciabot Berton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ciabot+Berton
# Retrieving Results for DeLille.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=DeLille
# Retrieving Results for Destro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Destro
# Retrieving Results for Destro.
# used region as search
# Retrieving Results for Domaine de Nalys.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+de+Nalys
# Retrieving Results for Dusted Valley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dusted+Valley
# Retrieving Results for Dusted Valley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dusted+Valley
# Retrieving Results for Efeste.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Efeste
# Retrieving Results for Ernest & Julio Gallo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ernest+%26+Julio+Gallo
# Retrieving Results for Trinitas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trinitas
# Retrieving Results for Waters.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Waters
# Retrieving Results for Château Élan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+%C3%89lan
# Retrieving Results for Alidis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alidis
# Retrieving Results for Archimedes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Archimedes
# Retrieving Results for Archimedes.
# used region as search
# Retrieving Results for Baer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Baer
# Retrieving Results for Baer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Baer
# Retrieving Results for Bunchgrass.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bunchgrass
# Retrieving Results for Bunchgrass.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bunchgrass
# Retrieving Results for Hersly.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hersly
# Retrieving Results for Hersly.
# used region as search
# Retrieving Results for Höpler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=H%C3%B6pler
# Retrieving Results for Château Beauséjour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Beaus%C3%A9jour
# Retrieving Results for Château Bel-Air Ortet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Bel-Air+Ortet
# Retrieving Results for Château Bel-Air Ortet.
# used region as search
# Retrieving Results for Château Bourseau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Bourseau
# Retrieving Results for Château Riotor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Riotor
# Retrieving Results for Château Riotor.
# Missing field/result... skipping.
# Retrieving Results for Damiani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Damiani
# Retrieving Results for Diwald.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Diwald
# Retrieving Results for Casas del Bosque.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Casas+del+Bosque
# Retrieving Results for Celli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Celli
# Retrieving Results for Château Bois Pertuis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Bois+Pertuis
# Retrieving Results for Château Bois Pertuis.
# used region as search
# Retrieving Results for Château Briot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Briot
# Retrieving Results for Château Briot.
# Missing field/result... skipping.
# Retrieving Results for Château de Beauregard-Ducourt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+de+Beauregard-Ducourt
# Retrieving Results for Château Rousset-Caillau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Rousset-Caillau
# Retrieving Results for Château Saint-Pierre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Saint-Pierre
# Retrieving Results for Daou.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Daou
# Retrieving Results for Derby.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Derby
# Retrieving Results for Galizeus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Galizeus
# Retrieving Results for Galizeus.
# used region as search
# Retrieving Results for Haraszthy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Haraszthy
# Retrieving Results for Viña Bujanda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Bujanda
# Retrieving Results for Viña Bujanda.
# used region as search
# Retrieving Results for Vini Iovine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vini+Iovine
# Retrieving Results for Muri-Gries.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Muri-Gries
# Retrieving Results for Oliver Conti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Oliver+Conti
# Retrieving Results for One.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=One
# Retrieving Results for Palacio de Bornos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Palacio+de+Bornos
# Retrieving Results for Tabarrini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tabarrini
# Retrieving Results for Agustí Torelló Mata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Agust%C3%AD+Torell%C3%B3+Mata
# Retrieving Results for Wood Family Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wood+Family+Vineyards
# Retrieving Results for Zero One Vintners.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zero+One+Vintners
# Retrieving Results for Zero One Vintners.
# used region as search
# Retrieving Results for J. Lohr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+Lohr
# Retrieving Results for Johanneshof Reinisch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Johanneshof+Reinisch
# Retrieving Results for La Tosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Tosa
# Retrieving Results for Rosemont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rosemont

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('5coord.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1       country  \
# 0       48392         52055           52055  South Africa
# 1       48393         52056           52056            US
# 2       48394         52057           52057            US
# 3       48395         52058           52058            US
# 4       48396         52059           52059            US
#
#                                          description           designation  \
# 0  Notes of caramel sauce and balsamic reduction ...            Mocha Java
# 1  It's big and brawny, with a very deep color, s...  Estate Grown Reserve
# 2  Dried peach and apple flavors peek out timidly...          Late Harvest
# 3  Broad and easy in texture, this is tempting to...                   NaN
# 4  The color of this wine has a touch of brown at...   Upper Russian River
#
#    points  price        province      region_1          region_2  \
# 0      85   13.0  Coastal Region           NaN               NaN
# 1      85   24.0      California     Fair Play  Sierra Foothills
# 2      85   15.0        New York  Finger Lakes      Finger Lakes
# 3      85    9.0      California    California  California Other
# 4      85   30.0      California     Mendocino               NaN
#
#           taster_name taster_twitter_handle  \
# 0       Lauren Buzzeo             @laurbuzz
# 1          Jim Gordon      @gordone_cellars
# 2  Anna Lee C. Iijima                   NaN
# 3          Jim Gordon      @gordone_cellars
# 4          Jim Gordon      @gordone_cellars
#
#                                                title     variety  \
# 0  Bellingham 2013 Mocha Java Merlot (Coastal Reg...      Merlot
# 1  Charles B. Mitchell 2012 Estate Grown Reserve ...      Merlot
# 2  Chateau Lafayette Reneau 2012 Late Harvest Rie...    Riesling
# 3              Happy Camper 2012 Merlot (California)      Merlot
# 4  Jeriko 2012 Upper Russian River Pinot Noir (Me...  Pinot Noir
#
#                      winery        Lat         Lng  heat weights
# 0                Bellingham  48.751911 -122.478685             5
# 1       Charles B. Mitchell  38.587658 -120.652308             5
# 2  Chateau Lafayette Reneau  42.479423  -76.870882             5
# 3              Happy Camper  41.904280  -87.634313             5
# 4                    Jeriko  38.986557 -123.122521             5

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
