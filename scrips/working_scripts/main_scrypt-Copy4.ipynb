# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys_Copy2 import g_key

# %%
file = '7.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    country  \
# 0       72587         78082           78082      Spain
# 1       72588         78083           78083      Spain
# 2       72589         78084           78084  Australia
# 3       72590         78085           78085         US
# 4       72591         78086           78086      Spain
#
#                                          description           designation  \
# 0  Dry melon and papaya aromas are common and pro...             Brut Jove
# 1  The only sweetness on offer is on the nose. Af...  Montesierra Oak Aged
# 2  Young Hunter Valley Sémillon is one of the mos...               Reserve
# 3  This New Mexico Cab offers exotic spice and to...                   NaN
# 4  Cloudy in appearance but fairly clear on the n...                Vertus
#
#    points  price         province       region_1 region_2        taster_name  \
# 0      84   13.0        Catalonia           Cava      NaN  Michael Schachner
# 1      83    9.0   Northern Spain      Somontano      NaN  Michael Schachner
# 2      83   17.0  New South Wales  Hunter Valley      NaN     Joe Czerwinski
# 3      83   10.0       New Mexico     New Mexico      NaN    Susan Kostrzewa
# 4      83   13.0          Levante  Utiel-Requena      NaN  Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0           @wineschach      Família Oliveda NV Brut Jove Sparkling (Cava)
# 1           @wineschach  Bodegas Pirineos 2003 Montesierra Oak Aged Tem...
# 2                @JoeCz  Pepper Tree 2006 Reserve Semillon (Hunter Valley)
# 3         @suskostrzewa     Blue Teal 2005 Cabernet Sauvignon (New Mexico)
# 4           @wineschach  Bodegas Iranzo 2006 Vertus Tempranillo (Utiel-...
#
#               variety            winery
# 0     Sparkling Blend   Família Oliveda
# 1         Tempranillo  Bodegas Pirineos
# 2            Sémillon       Pepper Tree
# 3  Cabernet Sauvignon         Blue Teal
# 4         Tempranillo    Bodegas Iranzo

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Família Oliveda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fam%C3%ADlia+Oliveda
# Retrieving Results for Família Oliveda.
# used region as search
# Retrieving Results for Bodegas Pirineos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Pirineos
# Retrieving Results for Pepper Tree.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pepper+Tree
# Retrieving Results for Blue Teal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Blue+Teal
# Retrieving Results for Bodegas Iranzo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Iranzo
# Retrieving Results for Chateau Morrisette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chateau+Morrisette
# Retrieving Results for Château Vessière.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Vessi%C3%A8re
# Retrieving Results for Estraié.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Estrai%C3%A9
# Retrieving Results for Estraié.
# used region as search
# Retrieving Results for Winzer Krems.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Winzer+Krems
# Retrieving Results for Woodward Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Woodward+Canyon
# Retrieving Results for Nittnaus Hans und Christine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Nittnaus+Hans+und+Christine
# Retrieving Results for Nittnaus Hans und Christine.
# used region as search
# Retrieving Results for Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ridge
# Retrieving Results for Shafer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Shafer
# Retrieving Results for Carpineto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Carpineto
# Retrieving Results for Clif Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Clif+Family
# Retrieving Results for Forefathers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Forefathers
# Retrieving Results for García Figuero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Garc%C3%ADa+Figuero
# Retrieving Results for J. Dumangin Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J.+Dumangin+Fils
# Retrieving Results for Kaiken.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kaiken
# Retrieving Results for Kaiken.
# used region as search
# Retrieving Results for Laetitia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Laetitia
# Retrieving Results for Louis Roederer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Louis+Roederer
# Retrieving Results for Kynsi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kynsi
# Retrieving Results for Moone-Tsai.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Moone-Tsai
# Retrieving Results for Sequel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sequel
# Retrieving Results for Trapiche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Trapiche
# Retrieving Results for Twomey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Twomey
# Retrieving Results for Bodega Norton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodega+Norton
# Retrieving Results for Can Blau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Can+Blau
# Retrieving Results for Charles Smith.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Charles+Smith
# Retrieving Results for Doyenne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Doyenne
# Retrieving Results for Finca Torremilanos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Finca+Torremilanos
# Retrieving Results for Francis Ford Coppola.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Francis+Ford+Coppola
# Retrieving Results for Gainey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gainey
# Retrieving Results for Whitehall Lane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Whitehall+Lane
# Retrieving Results for Nefarious.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Nefarious
# Retrieving Results for Ram's Gate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ram%27s+Gate
# Retrieving Results for Cartuxa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cartuxa
# Retrieving Results for Sogrape.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sogrape
# Retrieving Results for Sogrape.
# used region as search
# Retrieving Results for The Vineyard House.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=The+Vineyard+House
# Retrieving Results for Herdade dos Grous.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Herdade+dos+Grous
# Retrieving Results for J. Christopher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J.+Christopher
# Retrieving Results for Justin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Justin
# Retrieving Results for Wittmann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wittmann
# Retrieving Results for Nicholson Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Nicholson+Ranch
# Retrieving Results for Quinta de Chocapalha.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+de+Chocapalha
# Retrieving Results for Quinta de Chocapalha.
# used region as search
# Retrieving Results for Quinta do Crasto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Crasto
# Retrieving Results for Quinta do Passadouro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Passadouro
# Retrieving Results for La Voix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Voix
# Retrieving Results for Roco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Roco
# Retrieving Results for Sinor-LaVallee.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sinor-LaVallee
# Retrieving Results for Sojourn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sojourn
# Retrieving Results for Baxter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Baxter
# Retrieving Results for Big Basin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Big+Basin
# Retrieving Results for Château Lagrézette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Lagr%C3%A9zette
# Retrieving Results for Foxen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Foxen
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gary+Farrell
# Retrieving Results for Casa Ferreirinha.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casa+Ferreirinha
# Retrieving Results for Casa Ferreirinha.
# used region as search
# Retrieving Results for Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hall
# Retrieving Results for La Voix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Voix
# Retrieving Results for Le Cadeau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Le+Cadeau
# Retrieving Results for Leeuwin Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Leeuwin+Estate
# Retrieving Results for Merry Edwards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Merry+Edwards
# Retrieving Results for Quinta do Crasto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Crasto
# Retrieving Results for Wine & Soul.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wine+%26+Soul
# Retrieving Results for Wittmann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wittmann
# Retrieving Results for Dr. H. Thanisch (Erben Thanisch).
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dr.+H.+Thanisch+%28Erben+Thanisch%29
# Retrieving Results for Unum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Unum
# Retrieving Results for Dierberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dierberg
# Retrieving Results for Dinastía Vivanco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dinast%C3%ADa+Vivanco
# Retrieving Results for Domaine Patrice Moreux.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Patrice+Moreux
# Retrieving Results for Francis Ford Coppola.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Francis+Ford+Coppola
# Retrieving Results for Giacomo Grimaldi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Giacomo+Grimaldi
# Retrieving Results for Greenhill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Greenhill
# Retrieving Results for Jefferson Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Jefferson+Vineyards
# Retrieving Results for Josh Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Josh+Cellars
# Retrieving Results for King Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=King+Family
# Retrieving Results for Mario Gagliasso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mario+Gagliasso
# Retrieving Results for Mario Gagliasso.
# used region as search
# Retrieving Results for Benziger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Benziger
# Retrieving Results for Benziger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Benziger
# Retrieving Results for Ca' del Baio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ca%27+del+Baio
# Retrieving Results for Happy Canyon Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Happy+Canyon+Vineyard
# Retrieving Results for Château Goumin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Goumin
# Retrieving Results for Château Goumin.
# Missing field/result... skipping.
# Retrieving Results for Closerie du Bailli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Closerie+du+Bailli
# Retrieving Results for Closerie du Bailli.
# used region as search
# Retrieving Results for Domaine Jean Teiller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Jean+Teiller
# Retrieving Results for Fabbioli Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fabbioli+Cellars
# Retrieving Results for Faunus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Faunus
# Retrieving Results for Monte Clavijo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Monte+Clavijo
# Retrieving Results for Monte Clavijo.
# used region as search
# Retrieving Results for Renato Ratti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Renato+Ratti
# Retrieving Results for Stinson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stinson
# Retrieving Results for Testarossa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Testarossa
# Retrieving Results for Sanguis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sanguis
# Retrieving Results for Estate Biblia Chora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Estate+Biblia+Chora
# Retrieving Results for Domaine Costa Lazaridi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Costa+Lazaridi
# Retrieving Results for Cave du Marmandais.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cave+du+Marmandais
# Retrieving Results for Chassenay d'Arce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chassenay+d%27Arce
# Retrieving Results for Château du Cèdre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+du+C%C3%A8dre
# Retrieving Results for Duckhorn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Duckhorn
# Retrieving Results for Duckhorn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Duckhorn
# Retrieving Results for Casa del Valle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casa+del+Valle
# Retrieving Results for Peterson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Peterson
# Retrieving Results for Martha's Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Martha%27s+Wines
# Retrieving Results for Martin Ray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Martin+Ray
# Retrieving Results for Martin Ray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Martin+Ray
# Retrieving Results for Messias.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Messias
# Retrieving Results for Pelvillain Frères.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pelvillain+Fr%C3%A8res
# Retrieving Results for Pflüger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pfl%C3%BCger
# Retrieving Results for Prager.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Prager
# Retrieving Results for Presqu'ile.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Presqu%27ile
# Retrieving Results for Producteurs Plaimont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Producteurs+Plaimont
# Retrieving Results for Puntí Ferrer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Punt%C3%AD+Ferrer
# Retrieving Results for Joyce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joyce
# Retrieving Results for Kendric.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kendric
# Retrieving Results for La Rioja Alta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Rioja+Alta
# Retrieving Results for Lornano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lornano
# Retrieving Results for Kenefick Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kenefick+Ranch
# Retrieving Results for Together.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Together
# Retrieving Results for W.H. Smith.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=W.H.+Smith
# Retrieving Results for Willful.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Willful
# Retrieving Results for Fort Ross.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fort+Ross
# Retrieving Results for Fort Ross.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fort+Ross
# Retrieving Results for René Muré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ren%C3%A9+Mur%C3%A9
# Retrieving Results for René Muré.
# used region as search
# Retrieving Results for Manfred Tement.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Manfred+Tement
# Retrieving Results for Rieflé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Riefl%C3%A9
# Retrieving Results for Cornerstone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cornerstone
# Retrieving Results for Domaine Ostertag.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Ostertag
# Retrieving Results for Elyse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Elyse
# Retrieving Results for Fort Ross.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fort+Ross
# Retrieving Results for Alta Maria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Alta+Maria
# Retrieving Results for Johanneshof Reinisch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Johanneshof+Reinisch
# Retrieving Results for Kiona.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kiona
# Retrieving Results for Côte Nicault.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=C%C3%B4te+Nicault
# Retrieving Results for Domaine le Galantin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+le+Galantin
# Retrieving Results for Gernot and Heike Heinrich.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gernot+and+Heike+Heinrich
# Retrieving Results for Northstar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Northstar
# Retrieving Results for ONX.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=ONX
# Retrieving Results for Rieflé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Riefl%C3%A9
# Retrieving Results for Rieflé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Riefl%C3%A9
# Retrieving Results for Johanneshof Reinisch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Johanneshof+Reinisch
# Retrieving Results for Joseph Phelps.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Phelps
# Retrieving Results for Lauren Ashton Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lauren+Ashton+Cellars
# Retrieving Results for Alpha Omega.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Alpha+Omega
# Retrieving Results for Bella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bella
# Retrieving Results for Willm.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Willm
# Retrieving Results for Woodward Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Woodward+Canyon
# Retrieving Results for Benton-Lane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Benton-Lane
# Retrieving Results for Burmester.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Burmester
# Retrieving Results for Cataldi Madonna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cataldi+Madonna
# Retrieving Results for Château Moncontour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Moncontour
# Retrieving Results for Wild Horse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wild+Horse
# Retrieving Results for Tenuta Rapitalà.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tenuta+Rapital%C3%A0
# Retrieving Results for Barton & Guestier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Barton+%26+Guestier
# Retrieving Results for Barton & Guestier.
# used region as search
# Retrieving Results for Brookman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brookman
# Retrieving Results for Calatrasi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Calatrasi
# Retrieving Results for Calatrasi.
# used region as search
# Retrieving Results for Cálem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=C%C3%A1lem
# Retrieving Results for Caymus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Caymus
# Retrieving Results for Cherry Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cherry+Hill
# Retrieving Results for Condesa Eylo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Condesa+Eylo
# Retrieving Results for Cusumano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cusumano
# Retrieving Results for Fazio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fazio
# Retrieving Results for Finca Antigua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Finca+Antigua
# Retrieving Results for Penguin Bay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Penguin+Bay
# Retrieving Results for Piedra Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Piedra+Creek
# Retrieving Results for Tablas Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tablas+Creek
# Retrieving Results for Tasca d'Almerita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tasca+d%27Almerita
# Retrieving Results for Tudor Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tudor+Wines
# Retrieving Results for Kunde.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kunde
# Retrieving Results for Lakewood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lakewood
# Retrieving Results for Valle dell'Acate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Valle+dell%27Acate
# Retrieving Results for Vega Sindoa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vega+Sindoa
# Retrieving Results for Vega Sindoa.
# used region as search
# Retrieving Results for W.H. Smith.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=W.H.+Smith
# Retrieving Results for Weinert.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Weinert
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kendall-Jackson
# Retrieving Results for Costa di Bussia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Costa+di+Bussia
# Retrieving Results for Donum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Donum
# Retrieving Results for El Coto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=El+Coto
# Retrieving Results for Villa Oneiro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Villa+Oneiro
# Retrieving Results for W.H. Smith.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=W.H.+Smith
# Retrieving Results for Waits-Mast.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Waits-Mast
# Retrieving Results for Solomon Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Solomon+Hills
# Retrieving Results for Adegas Gran Vinum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Adegas+Gran+Vinum
# Retrieving Results for Bargetto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bargetto
# Retrieving Results for Col Solare.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Col+Solare
# Retrieving Results for Josetta Saffirio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Josetta+Saffirio
# Retrieving Results for Lawrelin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lawrelin
# Retrieving Results for Lawrelin.
# used region as search
# Retrieving Results for Le Macchiole.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Le+Macchiole
# Retrieving Results for Leonetti Cellar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Leonetti+Cellar
# Retrieving Results for Lucie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lucie
# Retrieving Results for Marchesi di Barolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Marchesi+di+Barolo
# Retrieving Results for Marimar Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Marimar+Estate
# Retrieving Results for Fielding Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fielding+Hills
# Retrieving Results for Fratelli Alessandria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fratelli+Alessandria
# Retrieving Results for Adams Bench.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Adams+Bench
# Retrieving Results for Braida di Giacomo Bologna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Braida+di+Giacomo+Bologna
# Retrieving Results for Calera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Calera
# Retrieving Results for Chandon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chandon
# Retrieving Results for Rasa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rasa
# Retrieving Results for Renwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Renwood
# Retrieving Results for Dunham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dunham
# Retrieving Results for Franco M. Martinetti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Franco+M.+Martinetti
# Retrieving Results for García Figuero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Garc%C3%ADa+Figuero
# Retrieving Results for Domaine Schoffit.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Schoffit
# Retrieving Results for Domaine Serene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Serene
# Retrieving Results for Domaine Weinbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Weinbach
# Retrieving Results for Elias Mora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Elias+Mora
# Retrieving Results for Carlisle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Carlisle
# Retrieving Results for J. Portugal Ramos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J.+Portugal+Ramos
# Retrieving Results for Quinta do Noval.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Noval
# Retrieving Results for Kopke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kopke
# Retrieving Results for Luis Duarte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Luis+Duarte
# Retrieving Results for Trimbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Trimbach
# Retrieving Results for Terrazas de Los Andes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Terrazas+de+Los+Andes
# Retrieving Results for Colomé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Colom%C3%A9
# Retrieving Results for Joseph Swan Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Swan+Vineyards
# Retrieving Results for Domaine Ostertag.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Ostertag
# Retrieving Results for Dr. Loosen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dr.+Loosen
# Retrieving Results for Shea.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Shea
# Retrieving Results for Quinta do Vale Meão.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Vale+Me%C3%A3o
# Retrieving Results for Sadie Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sadie+Family
# Retrieving Results for Kopke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kopke
# Retrieving Results for Kopke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kopke
# Retrieving Results for Cálem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=C%C3%A1lem
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Zind-Humbrecht
# Retrieving Results for Ayoub.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ayoub
# Retrieving Results for Ayoub.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ayoub
# Retrieving Results for Laetitia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Laetitia
# Retrieving Results for Laetitia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Laetitia
# Retrieving Results for Martin Schaetzel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Martin+Schaetzel
# Retrieving Results for Domaine Barmès-Buecher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Barm%C3%A8s-Buecher
# Retrieving Results for Domaine Serene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Serene
# Retrieving Results for Domaine Serene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Serene
# Retrieving Results for Rancho Sisquoc.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rancho+Sisquoc
# Retrieving Results for Robert Mondavi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Robert+Mondavi
# Retrieving Results for Rutherford Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rutherford+Grove
# Retrieving Results for Schulz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Schulz
# Retrieving Results for Scilio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Scilio
# Retrieving Results for Stanton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stanton
# Retrieving Results for Stephen Ross.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stephen+Ross
# Retrieving Results for TerraNoble.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=TerraNoble
# Retrieving Results for TerraNoble.
# used region as search
# Retrieving Results for Three Rivers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Three+Rivers
# Retrieving Results for Ippolito 1845.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ippolito+1845
# Retrieving Results for Ippolito 1845.
# Missing field/result... skipping.
# Retrieving Results for Masi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Masi
# Retrieving Results for Magistrate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Magistrate
# Retrieving Results for Masseria Altemura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Masseria+Altemura
# Retrieving Results for Masseria Altemura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Masseria+Altemura
# Retrieving Results for Paradise Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Paradise+Ridge
# Retrieving Results for Chasing Venus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chasing+Venus
# Retrieving Results for Gorgo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gorgo
# Retrieving Results for San Giuseppe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=San+Giuseppe
# Retrieving Results for Tommaso Bussola.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tommaso+Bussola
# Retrieving Results for Château l'Avocat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+l%27Avocat
# Retrieving Results for Château l'Avocat.
# used region as search
# Retrieving Results for Familia Schroeder.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Familia+Schroeder
# Retrieving Results for Familia Schroeder.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Familia+Schroeder
# Retrieving Results for A-Mano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=A-Mano
# Retrieving Results for Indian Rock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Indian+Rock
# Retrieving Results for J. de Telmont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J.+de+Telmont
# Retrieving Results for Kunde.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kunde
# Retrieving Results for Beauregard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Beauregard
# Retrieving Results for Bevela.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bevela
# Retrieving Results for Black Stallion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Black+Stallion
# Retrieving Results for Byington.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Byington
# Retrieving Results for Cambiata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cambiata
# Retrieving Results for Cambiata.
# used region as search
# Retrieving Results for Chanson Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chanson+P%C3%A8re+et+Fils
# Retrieving Results for Chanson Père et Fils.
# used region as search
# Retrieving Results for Chanson Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chanson+P%C3%A8re+et+Fils
# Retrieving Results for Chanson Père et Fils.
# used region as search
# Retrieving Results for Domaine Bott-Geyl.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Bott-Geyl
# Retrieving Results for Domaine Jacques Prieur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Jacques+Prieur
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Zind-Humbrecht
# Retrieving Results for Eberle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Eberle
# Retrieving Results for Feudi di San Gregorio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Feudi+di+San+Gregorio
# Retrieving Results for Flora Springs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Flora+Springs
# Retrieving Results for Frankland Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Frankland+Estate
# Retrieving Results for Freemark Abbey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Freemark+Abbey
# Retrieving Results for Tornatore.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tornatore
# Retrieving Results for V. Sattui.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=V.+Sattui
# Retrieving Results for Villa Raiano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Villa+Raiano
# Retrieving Results for Viña Tarapacá.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vi%C3%B1a+Tarapac%C3%A1
# Retrieving Results for Viña Tarapacá.
# used region as search
# Retrieving Results for Baron De Ley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Baron+De+Ley
# Retrieving Results for Aiken.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Aiken
# Retrieving Results for Albert Bichot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Albert+Bichot
# Retrieving Results for Artesa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Artesa
# Retrieving Results for Black Kite.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Black+Kite
# Retrieving Results for Jansz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Jansz
# Retrieving Results for Grgich Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Grgich+Hills
# Retrieving Results for Hawk Watch Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hawk+Watch+Winery
# Retrieving Results for Hyland.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hyland
# Retrieving Results for Melville.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Melville
# Retrieving Results for Mitolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mitolo
# Retrieving Results for Morambro Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Morambro+Creek
# Retrieving Results for Mulderbosch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mulderbosch
# Retrieving Results for Novy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Novy
# Retrieving Results for Occasio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Occasio
# Retrieving Results for Rubissow.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rubissow
# Retrieving Results for Spice Route.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Spice+Route
# Retrieving Results for Stonegate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stonegate
# Retrieving Results for Tapiz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tapiz
# Retrieving Results for Treveri Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Treveri+Cellars
# Retrieving Results for Ernie Els.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ernie+Els
# Retrieving Results for Yorba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Yorba
# Retrieving Results for Yorba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Yorba
# Retrieving Results for Bibi Graetz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bibi+Graetz
# Retrieving Results for Bonterra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bonterra
# Retrieving Results for Castello Romitorio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Castello+Romitorio
# Retrieving Results for Deep Sea.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Deep+Sea
# Retrieving Results for Ross Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ross+Estate
# Retrieving Results for Salentein.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Salentein
# Retrieving Results for A.A. Badenhorst Family Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=A.A.+Badenhorst+Family+Wines
# Retrieving Results for Agricola Querciabella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Agricola+Querciabella
# Retrieving Results for Jacob Franklin.
# ...
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Russiz+Superiore
# Retrieving Results for Sandro de Bruno.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sandro+de+Bruno
# Retrieving Results for The Rule.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=The+Rule
# Retrieving Results for La Riojana Coop.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Riojana+Coop
# Retrieving Results for Lagar de Cervera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lagar+de+Cervera
# Retrieving Results for Bodegas Valdemar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Valdemar
# Retrieving Results for Trencalòs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Trencal%C3%B2s
# Retrieving Results for Trencalòs.
# Missing field/result... skipping.
# Retrieving Results for Campelo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Campelo
# Retrieving Results for Del Rio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Del+Rio
# Retrieving Results for Callia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Callia
# Retrieving Results for Heartache.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Heartache
# Retrieving Results for Heartache.
# used region as search
# Retrieving Results for Ashokawna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ashokawna
# Retrieving Results for Ashokawna.
# used region as search
# Retrieving Results for Luis Segundo Correas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Luis+Segundo+Correas
# Retrieving Results for Michel Torino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Michel+Torino
# Retrieving Results for Michel Torino.
# Missing field/result... skipping.
# Retrieving Results for Robert Oatley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Robert+Oatley
# Retrieving Results for Hawthorne Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hawthorne+Ridge
# Retrieving Results for Andeluna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Andeluna
# Retrieving Results for Vega de Tera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vega+de+Tera
# Retrieving Results for Mountain Door.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mountain+Door
# Retrieving Results for Joseph Drouhin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Drouhin
# Retrieving Results for Louis Jadot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Louis+Jadot
# Retrieving Results for Louis Jadot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Louis+Jadot
# Retrieving Results for Dobogó.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dobog%C3%B3
# Retrieving Results for Domaine Jean Grivot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Jean+Grivot
# Retrieving Results for Wayfarer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wayfarer
# Retrieving Results for Joseph Drouhin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Drouhin
# Retrieving Results for Roederer Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Roederer+Estate
# Retrieving Results for Thomas Fogarty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Thomas+Fogarty
# Retrieving Results for Dominus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dominus
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gary+Farrell
# Retrieving Results for Robert Biale.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Robert+Biale
# Retrieving Results for Main & Geary.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Main+%26+Geary
# Retrieving Results for Maison Sichel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Maison+Sichel
# Retrieving Results for Bodegas Medina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Medina
# Retrieving Results for Region 1.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Region+1
# Retrieving Results for Château Bellevue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Bellevue
# Retrieving Results for Finca La Anita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Finca+La+Anita
# Retrieving Results for Château Majoureau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Majoureau
# Retrieving Results for Fat Cat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fat+Cat
# Retrieving Results for Calcareous.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Calcareous
# Retrieving Results for Immersion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Immersion
# Retrieving Results for Bodega Carmine Granata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodega+Carmine+Granata
# Retrieving Results for Château Timberlay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Timberlay
# Retrieving Results for Bodegas del Mundo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+del+Mundo
# Retrieving Results for Bodegas Franco-Españolas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Franco-Espa%C3%B1olas
# Retrieving Results for Schramsberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Schramsberg
# Retrieving Results for Failla.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Failla
# Retrieving Results for K Vintners.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=K+Vintners
# Retrieving Results for Joseph Phelps.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Phelps
# Retrieving Results for Dunham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dunham
# Retrieving Results for Tenuta San Guido.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tenuta+San+Guido
# Retrieving Results for The Vineyard House.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=The+Vineyard+House
# Retrieving Results for Goldschmidt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Goldschmidt
# Retrieving Results for Goldschmidt.
# used region as search
# Retrieving Results for Moone-Tsai.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Moone-Tsai
# Retrieving Results for Charles Smith.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Charles+Smith
# Retrieving Results for Amici.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Amici
# Retrieving Results for Dutton-Goldfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dutton-Goldfield
# Retrieving Results for Château Lynch-Bages.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Lynch-Bages
# Retrieving Results for Poet's Leap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Poet%27s+Leap
# Retrieving Results for Williams Selyem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Williams+Selyem
# Retrieving Results for Kazmer & Blaise.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kazmer+%26+Blaise
# Retrieving Results for Sbragia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sbragia
# Retrieving Results for Vina Robles.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vina+Robles
# Retrieving Results for Sequoia Grove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sequoia+Grove
# Retrieving Results for Petaluma.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Petaluma
# Retrieving Results for Tenuta San Leonardo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tenuta+San+Leonardo
# Retrieving Results for Titus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Titus
# Retrieving Results for Frog's Leap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Frog%27s+Leap
# Retrieving Results for Bella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bella
# Retrieving Results for Williams Selyem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Williams+Selyem
# Retrieving Results for Williams Selyem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Williams+Selyem
# Retrieving Results for Etude.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Etude
# Retrieving Results for Brandlin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brandlin
# Retrieving Results for Moccagatta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Moccagatta
# Retrieving Results for Moccagatta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Moccagatta
# Retrieving Results for Arger-Martucci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Arger-Martucci
# Retrieving Results for Arger-Martucci.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Arger-Martucci
# Retrieving Results for Fielding Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fielding+Hills
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gary+Farrell
# Retrieving Results for Gorman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gorman
# Retrieving Results for Lynmar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lynmar
# Retrieving Results for Merry Edwards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Merry+Edwards
# Retrieving Results for La Fenêtre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Fen%C3%AAtre
# Retrieving Results for MacPhail.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=MacPhail
# Retrieving Results for Olson Ogden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Olson+Ogden
# Retrieving Results for Gérard Bertrand.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=G%C3%A9rard+Bertrand
# Retrieving Results for Grans-Fassian.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Grans-Fassian
# Retrieving Results for Hunt Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hunt+Cellars
# Retrieving Results for Le Bonheur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Le+Bonheur
# Retrieving Results for Mocavero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mocavero
# Retrieving Results for Mocavero.
# used region as search
# Retrieving Results for Venteux.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Venteux
# Retrieving Results for Viña Mar de Casablanca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vi%C3%B1a+Mar+de+Casablanca
# Retrieving Results for Wairau River.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wairau+River
# Retrieving Results for Agrinatura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Agrinatura
# Retrieving Results for Agrinatura.
# used region as search
# Retrieving Results for Benito Ferrara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Benito+Ferrara
# Retrieving Results for Blason.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Blason
# Retrieving Results for Bortoluzzi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bortoluzzi
# Retrieving Results for Casas del Bosque.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casas+del+Bosque
# Retrieving Results for Cescon Italo Storia e Vini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cescon+Italo+Storia+e+Vini
# Retrieving Results for Domaines Barons de Rothschild (Lafite).
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaines+Barons+de+Rothschild+%28Lafite%29
# Retrieving Results for Hafner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hafner
# Retrieving Results for Nederburg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Nederburg

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('7coord.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    country  \
# 0       72587         78082           78082      Spain
# 1       72588         78083           78083      Spain
# 2       72589         78084           78084  Australia
# 3       72590         78085           78085         US
# 4       72591         78086           78086      Spain
#
#                                          description           designation  \
# 0  Dry melon and papaya aromas are common and pro...             Brut Jove
# 1  The only sweetness on offer is on the nose. Af...  Montesierra Oak Aged
# 2  Young Hunter Valley Sémillon is one of the mos...               Reserve
# 3  This New Mexico Cab offers exotic spice and to...                   NaN
# 4  Cloudy in appearance but fairly clear on the n...                Vertus
#
#    points  price         province       region_1 region_2        taster_name  \
# 0      84   13.0        Catalonia           Cava      NaN  Michael Schachner
# 1      83    9.0   Northern Spain      Somontano      NaN  Michael Schachner
# 2      83   17.0  New South Wales  Hunter Valley      NaN     Joe Czerwinski
# 3      83   10.0       New Mexico     New Mexico      NaN    Susan Kostrzewa
# 4      83   13.0          Levante  Utiel-Requena      NaN  Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0           @wineschach      Família Oliveda NV Brut Jove Sparkling (Cava)
# 1           @wineschach  Bodegas Pirineos 2003 Montesierra Oak Aged Tem...
# 2                @JoeCz  Pepper Tree 2006 Reserve Semillon (Hunter Valley)
# 3         @suskostrzewa     Blue Teal 2005 Cabernet Sauvignon (New Mexico)
# 4           @wineschach  Bodegas Iranzo 2006 Vertus Tempranillo (Utiel-...
#
#               variety            winery        Lat        Lng  heat weights
# 0     Sparkling Blend   Família Oliveda  40.740842 -73.985510             4
# 1         Tempranillo  Bodegas Pirineos  42.057834   0.092275             3
# 2            Sémillon       Pepper Tree  36.050830 -95.920442             3
# 3  Cabernet Sauvignon         Blue Teal  39.822036 -88.882321             3
# 4         Tempranillo    Bodegas Iranzo  39.558451  -1.277425             3

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
