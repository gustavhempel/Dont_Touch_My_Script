# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key

# %%
file = 'thefile.csv'
df = pd.read_csv(file)
df.nunique()
# Out:
# Unnamed: 0            113402
# country                   42
# description           104675
# points                    21
# price                    384
# region_1                1186
# taster_name               20
# title                 104360
# variety                  677
# winery                 15005
# Lat                    12892
# Lng                    12888
# heat weights              21
# year                      50
# Climate Zone              23
# Climate Zone Desc.        22
# raiting                   21
# dtype: int64

# %%
wineyards = df.groupby(['country'])
wineyards = wineyards['winery'].nunique()
wineyards = wineyards.sort_values(ascending=False).head(10)

# %%
wineyards.head()
# Out:
# country
# US           5160
# France       3089
# Italy        2514
# Spain        1304
# Argentina     506
# Name: winery, dtype: int64

# %%
wineyards.plot(kind='bar')
plt.ylabel('Count of wineries')
plt.title("Wineries by Country")


for x in range(wineyards.shape[0]):
    
    plt.annotate(xy=(x-0.3, wineyards[x] + 100),
                s=wineyards[x])
plt.ylim(0,5700)    
plt.legend()
plt.tight_layout()

plt.savefig("../pics/winery_country.png");

# %%
cz = df.groupby(['Climate Zone'])

czc = cz['winery'].count().sort_values(ascending=False).head(10)
czc
# Out:
# Climate Zone
# Csb    32471
# Cfa    25701
# Cfb    23148
# Csa    12030
# Dfb     6946
# BSk     4143
# Dfa     4081
# BWk     1705
# BSh      758
# Dfc      584
# Name: winery, dtype: int64

# %%
czc.plot(kind='bar')
plt.ylabel('Reviews by Climate Zone')
plt.title("Reviews based on Climate zones")


for x in range(czc.shape[0]):
    
    plt.annotate(xy=(x-0.3, czc[x] +1000),
                s=czc[x])
plt.ylim(0,35000)    
plt.legend()
plt.tight_layout()

plt.savefig("../pics/climatezone.png");

# %%
points = cz['points'].mean()

# %%
points
# Out:
# country
# Argentina                 86.766526
# Armenia                   87.500000
# Australia                 88.583945
# Austria                   90.201531
# Bosnia and Herzegovina    86.500000
# Brazil                    84.378378
# Bulgaria                  87.927007
# Canada                    89.533333
# Chile                     86.504421
# China                     89.000000
# Croatia                   87.323529
# Cyprus                    87.000000
# Czech Republic            87.454545
# England                   91.740741
# France                    88.842741
# Georgia                   87.779221
# Germany                   89.842156
# Greece                    87.334862
# Hungary                   89.257143
# India                     90.222222
# Israel                    88.482255
# Italy                     88.724193
# Lebanon                   87.685714
# Luxembourg                88.666667
# Macedonia                 86.727273
# Mexico                    85.238806
# Moldova                   87.280702
# Morocco                   88.555556
# New Zealand               88.327857
# Peru                      83.562500
# Portugal                  88.346255
# Romania                   86.398305
# Serbia                    87.500000
# Slovakia                  87.000000
# Slovenia                  88.038462
# South Africa              87.856121
# Spain                     87.322133
# Switzerland               88.571429
# Turkey                    88.112360
# US                        88.610902
# Ukraine                   83.800000
# Uruguay                   86.692308
# Name: points, dtype: float64

# %%
price = cz['price'].mean()

# %%
price
rating = cz['raiting'].mean()

# %%
new = pd.DataFrame({'Price':price,'Score':points,'Rating':rating})

# %%
new
# Out:
#                             Price      Score     Rating
# country
# Argentina               24.870042  86.766526  33.832630
# Armenia                 14.500000  87.500000  37.500000
# Australia               35.174312  88.583945  42.919725
# Austria                 30.736152  90.201531  51.007653
# Bosnia and Herzegovina  12.500000  86.500000  32.500000
# Brazil                  23.648649  84.378378  21.891892
# Bulgaria                14.686131  87.927007  39.635036
# Canada                  37.315556  89.533333  47.666667
# Chile                   20.773848  86.504421  32.522103
# China                   18.000000  89.000000  45.000000
# Croatia                 25.117647  87.323529  36.617647
# Cyprus                  16.333333  87.000000  35.000000
# Czech Republic          24.818182  87.454545  37.272727
# England                 51.944444  91.740741  58.703704
# France                  41.627801  88.842741  44.213706
# Georgia                 19.285714  87.779221  38.896104
# Germany                 42.521174  89.842156  49.210780
# Greece                  22.747706  87.334862  36.674312
# Hungary                 41.407143  89.257143  46.285714
# India                   13.333333  90.222222  51.111111
# Israel                  31.768267  88.482255  42.411273
# Italy                   40.784245  88.724193  43.620964
# Lebanon                 30.685714  87.685714  38.428571
# Luxembourg              22.666667  88.666667  43.333333
# Macedonia               15.636364  86.727273  33.636364
# Mexico                  26.895522  85.238806  26.194030
# Moldova                 16.929825  87.280702  36.403509
# Morocco                 19.555556  88.555556  42.777778
# New Zealand             27.112024  88.327857  41.639283
# Peru                    18.062500  83.562500  17.812500
# Portugal                25.285589  88.346255  41.731275
# Romania                 15.194915  86.398305  31.991525
# Serbia                  24.500000  87.500000  37.500000
# Slovakia                16.000000  87.000000  35.000000
# Slovenia                24.525641  88.038462  40.192308
# South Africa            24.776630  87.856121  39.280604
# Spain                   28.727070  87.322133  36.610663
# Switzerland             85.285714  88.571429  42.857143
# Turkey                  24.629213  88.112360  40.561798
# US                      36.916296  88.610902  43.054511
# Ukraine                  8.800000  83.800000  19.000000
# Uruguay                 26.548077  86.692308  33.461538

# %%
cz.count()
# Out:
#               Unnamed: 0  country  description  points  price  region_1  \
# Climate Zone
# Af                    98       98           98      98     98        98
# Am                   557      557          557     557    557       557
# As                    28       28           28      28     28        28
# Aw                    90       90           90      90     90        90
# BSh                  758      758          758     758    758       758
# BSk                 4143     4143         4143    4143   4143      4143
# BWh                  353      353          353     353    353       353
# BWk                 1705     1705         1705    1705   1705      1705
# Cfa                25701    25701        25701   25701  25701     25701
# Cfb                23148    23148        23148   23148  23148     23148
# Cfc                    1        1            1       1      1         1
# Csa                12030    12030        12030   12030  12030     12030
# Csb                32471    32471        32471   32471  32471     32471
# Cwa                   60       60           60      60     60        60
# Cwb                  116      116          116     116    116       116
# Cwc                   17       17           17      17     17        17
# Dfa                 4081     4081         4081    4081   4081      4081
# Dfb                 6946     6946         6946    6946   6946      6946
# Dfc                  584      584          584     584    584       584
# Dsb                  312      312          312     312    312       312
# Dsc                   21       21           21      21     21        21
# ET                   174      174          174     174    174       174
# not avail              8        8            8       8      8         8
#
#               taster_name  title  variety  winery    Lat    Lng  heat weights  \
# Climate Zone
# Af                     98     98       98      98     98     98            98
# Am                    557    557      557     557    557    557           557
# As                     28     28       28      28     28     28            28
# Aw                     90     90       90      90     90     90            90
# BSh                   758    758      758     758    758    758           758
# BSk                  4143   4143     4143    4143   4143   4143          4143
# BWh                   353    353      353     353    353    353           353
# BWk                  1705   1705     1705    1705   1705   1705          1705
# Cfa                 25701  25701    25701   25701  25701  25701         25701
# Cfb                 23148  23148    23148   23148  23148  23148         23148
# Cfc                     1      1        1       1      1      1             1
# Csa                 12030  12030    12030   12030  12030  12030         12030
# Csb                 32471  32471    32471   32471  32471  32471         32471
# Cwa                    60     60       60      60     60     60            60
# Cwb                   116    116      116     116    116    116           116
# Cwc                    17     17       17      17     17     17            17
# Dfa                  4081   4081     4081    4081   4081   4081          4081
# Dfb                  6946   6946     6946    6946   6946   6946          6946
# Dfc                   584    584      584     584    584    584           584
# Dsb                   312    312      312     312    312    312           312
# Dsc                    21     21       21      21     21     21            21
# ET                    174    174      174     174    174    174           174
# not avail               8      8        8       8      8      8             8
#
#                year  Climate Zone Desc.  raiting
# Climate Zone
# Af               98                  98       98
# Am              557                 557      557
# As               28                  28       28
# Aw               90                  90       90
# BSh             758                 758      758
# BSk            4143                4143     4143
# BWh             353                 353      353
# BWk            1705                1705     1705
# Cfa           25701               25701    25701
# Cfb           23148               23148    23148
# Cfc               1                   1        1
# Csa           12030               12030    12030
# Csb           32471               32471    32471
# Cwa              60                  60       60
# Cwb             116                 116      116
# Cwc              17                  17       17
# Dfa            4081                4081     4081
# Dfb            6946                6946     6946
# Dfc             584                 584      584
# Dsb             312                 312      312
# Dsc              21                  21       21
# ET              174                 174      174
# not avail         8                   8        8
