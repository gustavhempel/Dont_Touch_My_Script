# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key
file = 'clean_wine_data.csv'

# %%
df = pd.read_csv(file)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'country', 'description', 'designation',
#        'points', 'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
#df["variety2"] = df["variety"].map(lambda x:x.split("-"))
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   country  \
# 0           1             1  Portugal
# 1           2             2        US
# 2           3             3        US
# 3           4             4        US
# 4           5             5     Spain
#
#                                          description  \
# 0  This is ripe and fruity, a wine that is smooth...
# 1  Tart and snappy, the flavors of lime flesh and...
# 2  Pineapple rind, lemon pith and orange blossom ...
# 3  Much like the regular bottling from 2012, this...
# 4  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# ...

# %%
df.shape
# Out:
# (120975, 15)

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# Unnamed: 0.1               int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df.dropna().shape
# Out:
# (22387, 15)

# %%
dflist =  np.array_split(df, 10)

# %%
dflist[0].to_csv('1.csv')
dflist[1].to_csv('2.csv')
dflist[2].to_csv('3.csv')
dflist[3].to_csv('4.csv')
dflist[4].to_csv('5.csv')
dflist[5].to_csv('6.csv')
dflist[6].to_csv('7.csv')
dflist[7].to_csv('8.csv')
dflist[8].to_csv('9.csv')
dflist[9].to_csv('10.csv')
