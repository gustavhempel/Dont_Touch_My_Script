# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys_Copy1 import g_key

# %%
file = '6.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    country  \
# 0       60490         65147           65147   Portugal
# 1       60491         65148           65148     France
# 2       60492         65149           65149   Portugal
# 3       60493         65150           65150  Argentina
# 4       60494         65151           65151  Argentina
#
#                                          description  \
# 0  There is plenty of acidity here, giving a fres...
# 1  This open, fruity wine is ready to drink. It o...
# 2  With both soft and red fruits, this is a gentl...
# 3  Jammy, stewy berry aromas are accented by bric...
# 4  Earthy aromas of plum, leather and corn tortil...
#
#                   designation  points  price          province       region_1  \
# 0            Imperial Reserve      85   18.0              Port            NaN
# 1                         NaN      85   30.0          Burgundy    Saint-Véran
# 2  Dona Antónia Reserva Tawny      85   20.0              Port            NaN
# 3                         NaN      85   19.0  Mendoza Province        Mendoza
# 4                         NaN      85   13.0  Mendoza Province  Luján de Cuyo
#
#   region_2        taster_name taster_twitter_handle  \
# 0      NaN         Roger Voss            @vossroger
# 1      NaN         Roger Voss            @vossroger
# 2      NaN         Roger Voss            @vossroger
# 3      NaN  Michael Schachner           @wineschach
# 4      NaN  Michael Schachner           @wineschach
#
#                                             title     variety  \
# 0            Sandeman NV Imperial Reserve  (Port)        Port
# 1         Château de Beauregard 2014  Saint-Véran  Chardonnay
# 2  Ferreira NV Dona Antónia Reserva Tawny  (Port)        Port
# 3                       Mas 2015 Malbec (Mendoza)      Malbec
# 4    Nieto Senetiner 2014 Bonarda (Luján de Cuyo)     Bonarda
#
#                   winery
# 0               Sandeman
# 1  Château de Beauregard
# 2               Ferreira
# 3                    Mas
# 4        Nieto Senetiner

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Sandeman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sandeman
# Retrieving Results for Château de Beauregard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+de+Beauregard
# Retrieving Results for Ferreira.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ferreira
# Retrieving Results for Mas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mas
# Retrieving Results for Nieto Senetiner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Nieto+Senetiner
# Retrieving Results for Kiwi Cuvée.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kiwi+Cuv%C3%A9e
# Retrieving Results for Kiwi Cuvée.
# used region as search
# Retrieving Results for Kopke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kopke
# Retrieving Results for Llano Estacado.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Llano+Estacado
# Retrieving Results for Louis de Camponac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Louis+de+Camponac
# Retrieving Results for Louis de Camponac.
# used region as search
# Retrieving Results for Luca Bosio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Luca+Bosio
# Retrieving Results for Luca Bosio.
# used region as search
# Retrieving Results for Turasan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Turasan
# Retrieving Results for Viniverde.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Viniverde
# Retrieving Results for Viniverde.
# used region as search
# Retrieving Results for Herdade da Comporta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Herdade+da+Comporta
# Retrieving Results for J. Portugal Ramos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+Portugal+Ramos
# Retrieving Results for Georges Duboeuf.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Georges+Duboeuf
# Retrieving Results for Adega Cooperativa de Borba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Adega+Cooperativa+de+Borba
# Retrieving Results for Adega Cooperativa do Cartaxo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Adega+Cooperativa+do+Cartaxo
# Retrieving Results for Quinta da Lapa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+da+Lapa
# Retrieving Results for Ricardo Santos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ricardo+Santos
# Retrieving Results for Spicewood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Spicewood
# Retrieving Results for Taliano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Taliano
# Retrieving Results for D'Arenberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=D%27Arenberg
# Retrieving Results for Andeluna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Andeluna
# Retrieving Results for Antucura.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antucura
# Retrieving Results for Bodini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodini
# Retrieving Results for Château Robin des Moines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Robin+des+Moines
# Retrieving Results for Château Roques Mauriac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Roques+Mauriac
# Retrieving Results for Château Toudenac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Toudenac
# Retrieving Results for Château Toudenac.
# Missing field/result... skipping.
# Retrieving Results for Château Vieux Cardinal Lafaurie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Vieux+Cardinal+Lafaurie
# Retrieving Results for Château Vieux Cardinal Lafaurie.
# used region as search
# Retrieving Results for Cooper-Garrod.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cooper-Garrod
# Retrieving Results for Domaine du Père Caboche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+du+P%C3%A8re+Caboche
# Retrieving Results for Rodney Strong.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rodney+Strong
# Retrieving Results for Solminer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Solminer
# Retrieving Results for Sparkman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sparkman
# Retrieving Results for Sparkman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sparkman
# Retrieving Results for Sterling.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sterling
# Retrieving Results for Sylla Sebaste.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sylla+Sebaste
# Retrieving Results for Talbott.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Talbott
# Retrieving Results for Vignobles Jeanjean.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vignobles+Jeanjean
# Retrieving Results for Vite Colte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vite+Colte
# Retrieving Results for WesMar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=WesMar
# Retrieving Results for WindRacer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=WindRacer
# Retrieving Results for WindRacer.
# used region as search
# Retrieving Results for Calmel & Joseph.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Calmel+%26+Joseph
# Retrieving Results for Karah Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Karah+Estate
# Retrieving Results for Kempe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kempe
# Retrieving Results for Kiona.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kiona
# Retrieving Results for Kiona.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kiona
# Retrieving Results for Kontos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kontos
# Retrieving Results for Lava Cap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lava+Cap
# Retrieving Results for Licia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Licia
# Retrieving Results for Licia.
# used region as search
# Retrieving Results for Luke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Luke
# Retrieving Results for M. Chapoutier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=M.+Chapoutier
# Retrieving Results for Marchesi di Barolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marchesi+di+Barolo
# Retrieving Results for Markowitsch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Markowitsch
# Retrieving Results for Mercy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mercy
# Retrieving Results for La Rasina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Rasina
# Retrieving Results for Loacker Corte Pavone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Loacker+Corte+Pavone
# Retrieving Results for Londer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Londer
# Retrieving Results for Tenuta di Sesta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+di+Sesta
# Retrieving Results for Tenuta Vitanza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+Vitanza
# Retrieving Results for Cupano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cupano
# Retrieving Results for Gianni Brunelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gianni+Brunelli
# Retrieving Results for Wild Horse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wild+Horse
# Retrieving Results for PerryMoore.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=PerryMoore
# Retrieving Results for Poggio il Castellare.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poggio+il+Castellare
# Retrieving Results for Protos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Protos
# Retrieving Results for Sesti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sesti
# Retrieving Results for Siro Pacenti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Siro+Pacenti
# Retrieving Results for Bodega Noemía de Patagonia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodega+Noem%C3%ADa+de+Patagonia
# Retrieving Results for Castelgiocondo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Castelgiocondo
# Retrieving Results for Fattoi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fattoi
# Retrieving Results for Fattoria La Lecciaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fattoria+La+Lecciaia
# Retrieving Results for Gary Farrell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gary+Farrell
# Retrieving Results for Glenora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Glenora
# Retrieving Results for Robertson Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Robertson+Winery
# Retrieving Results for Quintay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quintay
# Retrieving Results for Red Newt Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Red+Newt+Cellars
# Retrieving Results for River Road.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=River+Road
# Retrieving Results for Sciandri Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sciandri+Family
# Retrieving Results for Sciandri Family.
# used region as search
# Retrieving Results for Silver Horse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Silver+Horse
# Retrieving Results for Sipp Mack.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sipp+Mack
# Retrieving Results for Thelema.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Thelema
# Retrieving Results for Thelema.
# used region as search
# Retrieving Results for Three Rivers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Three+Rivers
# Retrieving Results for Tsantali.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tsantali
# Retrieving Results for Tsantali.
# used region as search
# Retrieving Results for Tsantali.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tsantali
# Retrieving Results for Tsantali.
# used region as search
# Retrieving Results for Vicari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vicari
# Retrieving Results for Wunsch & Mann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wunsch+%26+Mann
# Retrieving Results for Highway 253.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Highway+253
# Retrieving Results for Hubert Meyer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hubert+Meyer
# Retrieving Results for Hubert Meyer.
# used region as search
# Retrieving Results for Hullabaloo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hullabaloo
# Retrieving Results for Illuminati Dino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Illuminati+Dino
# Retrieving Results for Illuminati Dino.
# used region as search
# Retrieving Results for Imagery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Imagery
# Retrieving Results for J. Rickards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+Rickards
# Retrieving Results for Kelly Fleming.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kelly+Fleming
# Retrieving Results for Larner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Larner
# Retrieving Results for Le Caniette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Caniette
# Retrieving Results for MacRostie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=MacRostie
# Retrieving Results for Larner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Larner
# Retrieving Results for Lawer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lawer
# Retrieving Results for Le Caniette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Caniette
# Retrieving Results for Le Caniette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Caniette
# Retrieving Results for Finca Albret.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Albret
# Retrieving Results for Patriarche Père et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Patriarche+P%C3%A8re+et+Fils
# Retrieving Results for Kourtaki.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kourtaki
# Retrieving Results for Kourtaki.
# used region as search
# Retrieving Results for Las Palmeras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Las+Palmeras
# Retrieving Results for Vicente Gandia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vicente+Gandia
# Retrieving Results for Vignerons de Bel Air.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vignerons+de+Bel+Air
# Retrieving Results for Vignobles Jeanjean.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vignobles+Jeanjean
# Retrieving Results for Vignobles Jeanjean.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vignobles+Jeanjean
# Retrieving Results for Wilderotter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wilderotter
# Retrieving Results for Helfrich.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Helfrich
# Retrieving Results for Hosmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hosmer
# Retrieving Results for Indomita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Indomita
# Retrieving Results for Indomita.
# used region as search
# Retrieving Results for J. Portugal Ramos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+Portugal+Ramos
# Retrieving Results for Georges Duboeuf.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Georges+Duboeuf
# Retrieving Results for Antoine Moltès & Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Antoine+Molt%C3%A8s+%26+Fils
# Retrieving Results for Asuncion Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Asuncion+Ridge
# Retrieving Results for Bonacchi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bonacchi
# Retrieving Results for Bonacchi.
# used region as search
# Retrieving Results for Ca' Momi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ca%27+Momi
# Retrieving Results for Casa Batoreu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Casa+Batoreu
# Retrieving Results for Casa Batoreu.
# used region as search
# Retrieving Results for Casa Santos Lima.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Casa+Santos+Lima
# Retrieving Results for Rui Roboredo Madeira.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rui+Roboredo+Madeira
# Retrieving Results for Sagelands.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sagelands
# Retrieving Results for Schramsberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Schramsberg
# Retrieving Results for Scotto Family Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Scotto+Family+Cellars
# Retrieving Results for Sextant.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sextant
# Retrieving Results for Arrogant Frog.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Arrogant+Frog
# Retrieving Results for Bodegas Hidalgo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Hidalgo
# Retrieving Results for Calcu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Calcu
# Retrieving Results for Calcu.
# used region as search
# Retrieving Results for Kopriva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kopriva
# Retrieving Results for Lafken.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lafken
# Retrieving Results for Le Battistelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Le+Battistelle
# Retrieving Results for Leyda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Leyda
# Retrieving Results for Librandi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Librandi
# Retrieving Results for Lumos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lumos
# Retrieving Results for Masut da Rive.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Masut+da+Rive
# Retrieving Results for Paul Anheuser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paul+Anheuser
# Retrieving Results for Ritual.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ritual
# Retrieving Results for Pflüger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pfl%C3%BCger
# Retrieving Results for Quinta de Chocapalha.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quinta+de+Chocapalha
# Retrieving Results for Quinta de Chocapalha.
# used region as search
# Retrieving Results for Ravenswood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ravenswood
# Retrieving Results for Robert Oatley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Robert+Oatley
# Retrieving Results for Scala Dei.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Scala+Dei
# Retrieving Results for Tenuta Peter Sölva & Söhne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tenuta+Peter+S%C3%B6lva+%26+S%C3%B6hne
# Retrieving Results for Torii Mor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Torii+Mor
# Retrieving Results for Tramin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Tramin
# Retrieving Results for Villa Canestrari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Villa+Canestrari
# Retrieving Results for Vista Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vista+Hills
# Retrieving Results for Wines & Winemakers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wines+%26+Winemakers
# Retrieving Results for Adega Mãe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Adega+M%C3%A3e
# Retrieving Results for Alta Luna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alta+Luna
# Retrieving Results for Barrymore.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barrymore
# Retrieving Results for Beltane Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Beltane+Ranch
# Retrieving Results for Feudi di San Gregorio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Feudi+di+San+Gregorio
# Retrieving Results for Franz Keller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Franz+Keller
# Retrieving Results for Glenwood Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Glenwood+Cellars
# Retrieving Results for Graziano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Graziano
# Retrieving Results for Cellers Grifoll Declara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cellers+Grifoll+Declara
# Retrieving Results for Finca Hispana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Hispana
# Retrieving Results for Finca Hispana.
# used region as search
# Retrieving Results for Petaluma.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Petaluma
# Retrieving Results for Buty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Buty
# Retrieving Results for Hagafen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hagafen
# Retrieving Results for Hanna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hanna
# Retrieving Results for Covey Run.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Covey+Run
# Retrieving Results for Woodward Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Woodward+Canyon
# Retrieving Results for Deerfield Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Deerfield+Ranch
# Retrieving Results for Granite Springs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Granite+Springs
# Retrieving Results for Fritz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fritz
# Retrieving Results for Kestrel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kestrel
# Retrieving Results for Hanna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hanna
# Retrieving Results for M. Cosentino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=M.+Cosentino
# Retrieving Results for Marques de Griñon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marques+de+Gri%C3%B1on
# Retrieving Results for Marques de Griñon.
# used region as search
# Retrieving Results for Ste. Chapelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ste.+Chapelle
# Retrieving Results for McCrea.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=McCrea
# Retrieving Results for Three Rivers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Three+Rivers
# Retrieving Results for Peachy Canyon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Peachy+Canyon
# Retrieving Results for Willow Crest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Willow+Crest
# Retrieving Results for Campo Viejo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Campo+Viejo
# Retrieving Results for Midnight.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Midnight
# Retrieving Results for Penfolds.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Penfolds
# Retrieving Results for Russell Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Russell+Creek
# Retrieving Results for Repolusk.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Repolusk
# Retrieving Results for Ste. Chapelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ste.+Chapelle
# Retrieving Results for Warrabilla.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Warrabilla
# Retrieving Results for L'Ecole No. 41.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=L%27Ecole+No.+41
# Retrieving Results for Marqués de Alella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marqu%C3%A9s+de+Alella
# Retrieving Results for McIlroy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=McIlroy
# Retrieving Results for McIlroy.
# used region as search
# Retrieving Results for Koves-Newlan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Koves-Newlan
# Retrieving Results for Koves-Newlan.
# used region as search
# Retrieving Results for Kendall-Jackson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kendall-Jackson
# Retrieving Results for Millésimé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mill%C3%A9sim%C3%A9
# Retrieving Results for Dante.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dante
# Retrieving Results for Domaine Jean Bousquet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Jean+Bousquet
# Retrieving Results for Domaine Jean Bousquet.
# used region as search
# Retrieving Results for Millésimé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mill%C3%A9sim%C3%A9
# Retrieving Results for Honora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Honora
# Retrieving Results for Château Pétrus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+P%C3%A9trus
# Retrieving Results for Laird.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Laird
# Retrieving Results for Von Strasser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Von+Strasser
# Retrieving Results for Marimar Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marimar+Estate
# Retrieving Results for Roche de Bellene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Roche+de+Bellene
# Retrieving Results for Roche de Bellene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Roche+de+Bellene
# Retrieving Results for Failla.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Failla
# Retrieving Results for Roche de Bellene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Roche+de+Bellene
# Retrieving Results for Luis Duarte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Luis+Duarte
# Retrieving Results for Château du Cèdre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+du+C%C3%A8dre
# Retrieving Results for Pieropan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pieropan
# Retrieving Results for Taittinger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Taittinger
# Retrieving Results for Roche de Bellene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Roche+de+Bellene
# Retrieving Results for Cantina Produttori San Michele Appiano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cantina+Produttori+San+Michele+Appiano
# Retrieving Results for Kunde.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kunde
# Retrieving Results for Marques de la Musa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marques+de+la+Musa
# Retrieving Results for Marques de la Musa.
# used region as search
# Retrieving Results for Marshall Family Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Marshall+Family+Wines
# Retrieving Results for Monogamy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Monogamy
# Retrieving Results for Monogamy.
# used region as search
# Retrieving Results for Barra of Mendocino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barra+of+Mendocino
# Retrieving Results for Bogle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bogle
# Retrieving Results for Boxwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Boxwood
# Retrieving Results for Buccia Nera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Buccia+Nera
# Retrieving Results for Carmenet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Carmenet
# Retrieving Results for Conspire.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Conspire
# Retrieving Results for De Loach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=De+Loach
# Retrieving Results for Andrew Murray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Andrew+Murray
# Retrieving Results for Barra of Mendocino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barra+of+Mendocino
# Retrieving Results for Château Anniche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Anniche
# Retrieving Results for Château Grand Maréchaud.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Grand+Mar%C3%A9chaud
# Retrieving Results for Château Grand Maréchaud.
# Missing field/result... skipping.
# Retrieving Results for Lo Nuevo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lo+Nuevo
# Retrieving Results for Gray Ghost.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gray+Ghost
# Retrieving Results for Sagelands.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sagelands
# Retrieving Results for Bodegas Valdemar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Valdemar
# Retrieving Results for Santa Julia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Santa+Julia
# Retrieving Results for Trapiche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trapiche
# Retrieving Results for Finca Sophenia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Finca+Sophenia
# Retrieving Results for Muruve.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Muruve
# Retrieving Results for Francesc Sanchez Bas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Francesc+Sanchez+Bas
# Retrieving Results for Francesc Sanchez Bas.
# used region as search
# Retrieving Results for Mommessin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mommessin
# Retrieving Results for Mommessin.
# used region as search
# Retrieving Results for Nova Vita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Nova+Vita
# Retrieving Results for Recoletas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Recoletas
# Retrieving Results for Richard Rottiers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Richard+Rottiers
# Retrieving Results for Thomas Fogarty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Thomas+Fogarty
# Retrieving Results for V. Sattui.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=V.+Sattui
# Retrieving Results for Vall Llach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vall+Llach
# Retrieving Results for Dürnberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=D%C3%BCrnberg
# Retrieving Results for Elk Cove.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Elk+Cove
# Retrieving Results for Fattoria Nittardi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fattoria+Nittardi
# Retrieving Results for Ferrer Bobet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ferrer+Bobet
# Retrieving Results for Wattle Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wattle+Creek
# Retrieving Results for Capafons-Ossó.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Capafons-Oss%C3%B3
# Retrieving Results for Judd's Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Judd%27s+Hill
# Retrieving Results for La Rochelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Rochelle
# Retrieving Results for Longplay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Longplay
# Retrieving Results for Pittacum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pittacum
# Retrieving Results for Judd's Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Judd%27s+Hill
# Retrieving Results for La Bodega de Pinoso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Bodega+de+Pinoso
# Retrieving Results for Musetta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Musetta
# Retrieving Results for Piegaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Piegaia
# Retrieving Results for Piegaia.
# used region as search
# Retrieving Results for Standing Stone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Standing+Stone
# Retrieving Results for Galil Mountain.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Galil+Mountain
# Retrieving Results for Heron Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Heron+Hill
# Retrieving Results for Ventosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ventosa
# Retrieving Results for Palmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Palmer
# Retrieving Results for Shalestone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Shalestone
# Retrieving Results for Bodegas Pirineos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Pirineos
# Retrieving Results for Convergence Zone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Convergence+Zone
# Retrieving Results for Fleur de California.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fleur+de+California
# Retrieving Results for Merum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Merum
# Retrieving Results for Poderi Morini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poderi+Morini
# Retrieving Results for Binyamina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Binyamina
# Retrieving Results for AntoLin Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=AntoLin+Cellars
# Retrieving Results for Barrister.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Barrister
# Retrieving Results for Cairdeas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Cairdeas
# Retrieving Results for Calcu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Calcu
# Retrieving Results for Calcu.
# used region as search
# Retrieving Results for Caliterra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Caliterra
# Retrieving Results for Wild Horse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wild+Horse
# Retrieving Results for Wild Horse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wild+Horse
# Retrieving Results for Wind Rose.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wind+Rose
# Retrieving Results for Lapostolle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lapostolle
# Retrieving Results for Lapostolle.
# used region as search
# Retrieving Results for Lomas del Valle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lomas+del+Valle
# Retrieving Results for Nickname.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Nickname
# Retrieving Results for Pace.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pace
# Retrieving Results for Paul Dolan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paul+Dolan
# Retrieving Results for Peju.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Peju
# Retrieving Results for Pelter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pelter
# Retrieving Results for Pratsch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pratsch
# Retrieving Results for Pratsch.
# used region as search
# Retrieving Results for Domaine de l'Herré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+de+l%27Herr%C3%A9
# Retrieving Results for Domaine Uby.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Uby
# Retrieving Results for Evans & Tate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Evans+%26+Tate
# Retrieving Results for François Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fran%C3%A7ois+Lurton
# Retrieving Results for François Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Fran%C3%A7ois+Lurton
# Retrieving Results for Strauss.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Strauss
# Retrieving Results for Vistamar.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vistamar
# Retrieving Results for Steininger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Steininger
# Retrieving Results for Steininger.
# used region as search
# Retrieving Results for Vieux Château Gaubert.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vieux+Ch%C3%A2teau+Gaubert
# Retrieving Results for Pieve de' Pitti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pieve+de%27+Pitti
# Retrieving Results for PoderNuovo a Palazzone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=PoderNuovo+a+Palazzone
# Retrieving Results for Poggio Nardone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poggio+Nardone
# Retrieving Results for Poggio Nardone.
# used region as search
# Retrieving Results for Poggio Nardone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Poggio+Nardone
# Retrieving Results for Poggio Nardone.
# used region as search
# Retrieving Results for Pratesi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pratesi
# Retrieving Results for Provenance Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Provenance+Vineyards
# Retrieving Results for Rascioni e Cecconello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rascioni+e+Cecconello
# Retrieving Results for Original House Wine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Original+House+Wine
# Retrieving Results for Portal del Priorat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Portal+del+Priorat
# Retrieving Results for Quercia al Poggio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Quercia+al+Poggio
# Retrieving Results for Spann Vineyards.
# ...
# Retrieving Results for Yealands.
# used region as search
# Retrieving Results for Zahel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Zahel
# Retrieving Results for Zahel.
# used region as search
# Retrieving Results for Joseph Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Joseph+Cellars
# Retrieving Results for Albet I Noya.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Albet+I+Noya
# Retrieving Results for Allram.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Allram
# Retrieving Results for Alta Alella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Alta+Alella
# Retrieving Results for Ampelos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ampelos
# Retrieving Results for Ascencion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ascencion
# Retrieving Results for Baigorri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Baigorri
# Retrieving Results for Grizzly Peak.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Grizzly+Peak
# Retrieving Results for Gunter Triebaumer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Gunter+Triebaumer
# Retrieving Results for Hermann Moser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hermann+Moser
# Retrieving Results for High Valley Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=High+Valley+Vineyard
# Retrieving Results for Höpler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=H%C3%B6pler
# Retrieving Results for Hosmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hosmer
# Retrieving Results for Hunky Dory.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hunky+Dory
# Retrieving Results for Ideology.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ideology
# Retrieving Results for Jäger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J%C3%A4ger
# Retrieving Results for Jäger.
# used region as search
# Retrieving Results for 1000 Stories.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=1000+Stories
# Retrieving Results for Artisan Wines DI Franz Scheider.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Artisan+Wines+DI+Franz+Scheider
# Retrieving Results for Artner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Artner
# Retrieving Results for AuburnJames.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=AuburnJames
# Retrieving Results for Oso Libre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Oso+Libre
# Retrieving Results for Amalie Robert.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Amalie+Robert
# Retrieving Results for Carabella.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Carabella
# Retrieving Results for Casa Dumetz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Casa+Dumetz
# Retrieving Results for Château de Lavernette.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+de+Lavernette
# Retrieving Results for Grgich Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Grgich+Hills
# Retrieving Results for Halter Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Halter+Ranch
# Retrieving Results for Hyland.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hyland
# Retrieving Results for Hyland.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hyland
# Retrieving Results for Jordan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Jordan
# Retrieving Results for Kessler-Haak.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Kessler-Haak
# Retrieving Results for Love & Squalor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Love+%26+Squalor
# Retrieving Results for Domaine Bott-Geyl.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Bott-Geyl
# Retrieving Results for Domaine Divio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Divio
# Retrieving Results for Francis Tannahill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Francis+Tannahill
# Retrieving Results for Francis Tannahill.
# used region as search
# Retrieving Results for Frankland Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Frankland+Estate
# Retrieving Results for Goat Bubbles.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Goat+Bubbles
# Retrieving Results for Graf von Schönborn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Graf+von+Sch%C3%B6nborn
# Retrieving Results for Valle Hermoso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Valle+Hermoso
# Retrieving Results for Vasco Urbano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vasco+Urbano
# Retrieving Results for Wagner-Stempel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wagner-Stempel
# Retrieving Results for Waxwing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Waxwing
# Retrieving Results for Waxwing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Waxwing
# Retrieving Results for Yalumba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Yalumba
# Retrieving Results for Yorkville Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Yorkville+Cellars
# Retrieving Results for Trinchero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Trinchero
# Retrieving Results for Mueller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mueller
# Retrieving Results for Navarro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Navarro
# Retrieving Results for Occhipinti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Occhipinti
# Retrieving Results for Ordaz Family Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ordaz+Family+Wines
# Retrieving Results for Château Rives-Blanques.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Ch%C3%A2teau+Rives-Blanques
# Retrieving Results for City Winery Chicago.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=City+Winery+Chicago
# Retrieving Results for Domaine Bernhard & Reibel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Bernhard+%26+Reibel
# Retrieving Results for Domaine Bott-Geyl.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Bott-Geyl
# Retrieving Results for Domaine Charles Frey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Charles+Frey
# Retrieving Results for Domaine de Leyre-Loup.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+de+Leyre-Loup
# Retrieving Results for Domaine du Clos du Fief.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+du+Clos+du+Fief
# Retrieving Results for Domaine Richard Rottiers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Domaine+Richard+Rottiers
# Retrieving Results for Donkey & Goat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Donkey+%26+Goat
# Retrieving Results for Emile Beyer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Emile+Beyer
# Retrieving Results for Florent Descombe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Florent+Descombe
# Retrieving Results for Vins El Cep.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vins+El+Cep
# Retrieving Results for Merriman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Merriman
# Retrieving Results for Michaud.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Michaud
# Retrieving Results for Millbrook.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Millbrook
# Retrieving Results for North by Northwest.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=North+by+Northwest
# Retrieving Results for Paul Blanck.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Paul+Blanck
# Retrieving Results for Pinhal da Torre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Pinhal+da+Torre
# Retrieving Results for Januik.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Januik
# Retrieving Results for Joseph Drouhin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Joseph+Drouhin
# Retrieving Results for Keller Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Keller+Estate
# Retrieving Results for Lafond.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Lafond
# Retrieving Results for Leyda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Leyda
# Retrieving Results for Leyda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Leyda
# Retrieving Results for Vignobles Brumont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vignobles+Brumont
# Retrieving Results for Waxwing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Waxwing
# Retrieving Results for Wines & Winemakers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Wines+%26+Winemakers
# Retrieving Results for Wölffer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=W%C3%B6lffer
# Retrieving Results for Wölffer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=W%C3%B6lffer
# Retrieving Results for Hugel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hugel
# Retrieving Results for Rock Point.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Rock+Point
# Retrieving Results for Sanford.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sanford
# Retrieving Results for Hilltown.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hilltown
# Retrieving Results for Karly.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Karly
# Retrieving Results for Karly.
# used region as search
# Retrieving Results for Frog's Leap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Frog%27s+Leap
# Retrieving Results for Hess.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Hess
# Retrieving Results for Algairen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Algairen
# Retrieving Results for Anthony Road.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Anthony+Road
# Retrieving Results for Baron De Ley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Baron+De+Ley
# Retrieving Results for Bell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bell
# Retrieving Results for Bodegas Eguren.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Eguren
# Retrieving Results for Bodegas Navarro López.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Navarro+L%C3%B3pez
# Retrieving Results for Bodegas Real.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Bodegas+Real
# Retrieving Results for Chaddsford.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chaddsford
# Retrieving Results for Chozas Carrascal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Chozas+Carrascal
# Retrieving Results for Dos Cabezas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Dos+Cabezas
# Retrieving Results for J. Jacaman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=J.+Jacaman
# Retrieving Results for J. Jacaman.
# used region as search
# Retrieving Results for La Famiglia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=La+Famiglia
# Retrieving Results for Millésimé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Mill%C3%A9sim%C3%A9
# Retrieving Results for Sylvester.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Sylvester
# Retrieving Results for Viña Altaba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyD3b7J6IplH4y5Vor1Vcai4BstHodYU6KY&address=Vi%C3%B1a+Altaba
# Retrieving Results for Viña Altaba.
# used region as search

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('6coord.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1    country  \
# 0       60490         65147           65147   Portugal
# 1       60491         65148           65148     France
# 2       60492         65149           65149   Portugal
# 3       60493         65150           65150  Argentina
# 4       60494         65151           65151  Argentina
#
#                                          description  \
# 0  There is plenty of acidity here, giving a fres...
# 1  This open, fruity wine is ready to drink. It o...
# 2  With both soft and red fruits, this is a gentl...
# 3  Jammy, stewy berry aromas are accented by bric...
# 4  Earthy aromas of plum, leather and corn tortil...
#
#                   designation  points  price          province       region_1  \
# 0            Imperial Reserve      85   18.0              Port            NaN
# 1                         NaN      85   30.0          Burgundy    Saint-Véran
# 2  Dona Antónia Reserva Tawny      85   20.0              Port            NaN
# 3                         NaN      85   19.0  Mendoza Province        Mendoza
# 4                         NaN      85   13.0  Mendoza Province  Luján de Cuyo
#
#   region_2        taster_name taster_twitter_handle  \
# 0      NaN         Roger Voss            @vossroger
# 1      NaN         Roger Voss            @vossroger
# 2      NaN         Roger Voss            @vossroger
# 3      NaN  Michael Schachner           @wineschach
# 4      NaN  Michael Schachner           @wineschach
#
#                                             title     variety  \
# 0            Sandeman NV Imperial Reserve  (Port)        Port
# 1         Château de Beauregard 2014  Saint-Véran  Chardonnay
# 2  Ferreira NV Dona Antónia Reserva Tawny  (Port)        Port
# 3                       Mas 2015 Malbec (Mendoza)      Malbec
# 4    Nieto Senetiner 2014 Bonarda (Luján de Cuyo)     Bonarda
#
#                   winery        Lat        Lng  heat weights
# 0               Sandeman  40.704453 -74.013743             5
# 1  Château de Beauregard  47.535309   1.378625             5
# 2               Ferreira  27.046377 -80.147980             5
# 3                    Mas  40.761362 -73.993025             5
# 4        Nieto Senetiner -33.013786 -68.910012             5

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
