# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys import g_key

# %%
file = 'clean_wine_data.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   country  \
# 0           1             1  Portugal
# 1           2             2        US
# 2           3             3        US
# 3           4             4        US
# 4           5             5     Spain
#
#                                          description  \
# 0  This is ripe and fruity, a wine that is smooth...
# 1  Tart and snappy, the flavors of lime flesh and...
# 2  Pineapple rind, lemon pith and orange blossom ...
# 3  Much like the regular bottling from 2012, this...
# 4  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery
# 0      Portuguese Red  Quinta dos Avidagos
# 1          Pinot Gris            Rainstorm
# 2            Riesling           St. Julian
# 3          Pinot Noir         Sweet Cheeks
# 4  Tempranillo-Merlot               Tandem

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
#keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Quinta dos Avidagos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Quinta+dos+Avidagos
# Retrieving Results for Rainstorm.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Rainstorm
# Retrieving Results for St. Julian.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=St.+Julian
# Retrieving Results for Sweet Cheeks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sweet+Cheeks
# Retrieving Results for Tandem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tandem
# Retrieving Results for Terre di Giurfo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Terre+di+Giurfo
# Retrieving Results for Trimbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trimbach
# Retrieving Results for Heinz Eifel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Heinz+Eifel
# Retrieving Results for Heinz Eifel.
# used region as search
# Retrieving Results for Jean-Baptiste Adam.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jean-Baptiste+Adam
# Retrieving Results for Kirkland Signature.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kirkland+Signature
# Retrieving Results for Kirkland Signature.
# used region as search
# Retrieving Results for Leon Beyer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Leon+Beyer
# Retrieving Results for Louis M. Martini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+M.+Martini
# Retrieving Results for Mirassou.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mirassou
# Retrieving Results for Richard Böcking.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Richard+B%C3%B6cking
# Retrieving Results for Felix Lavaque.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Felix+Lavaque
# Retrieving Results for Felix Lavaque.
# used region as search
# Retrieving Results for Gaucho Andino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Gaucho+Andino
# Retrieving Results for Gaucho Andino.
# used region as search
# Retrieving Results for Pradorey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pradorey
# Retrieving Results for Quiévremont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Qui%C3%A9vremont
# Retrieving Results for Quiévremont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Qui%C3%A9vremont
# Retrieving Results for Acrobat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Acrobat
# Retrieving Results for Baglio di Pianetto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Baglio+di+Pianetto
# Retrieving Results for Bianchi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bianchi
# Retrieving Results for Canicattì.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Canicatt%C3%AC
# Retrieving Results for Castello di Amorosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Castello+di+Amorosa
# Retrieving Results for Stemmari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stemmari
# Retrieving Results for Stemmari.
# used region as search
# Retrieving Results for Stemmari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stemmari
# Retrieving Results for Stemmari.
# used region as search
# Retrieving Results for Terre di Giurfo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Terre+di+Giurfo
# Retrieving Results for Clarksburg Wine Company.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Clarksburg+Wine+Company
# Retrieving Results for Envolve.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Envolve
# Retrieving Results for Envolve.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Envolve
# Retrieving Results for Erath.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Erath
# Retrieving Results for Estampa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Estampa
# Retrieving Results for Feudi del Pisciotto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Feudi+del+Pisciotto
# Retrieving Results for Feudi di San Marzano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Feudi+di+San+Marzano
# Retrieving Results for Feudo di Santa Tresa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Feudo+di+Santa+Tresa
# Retrieving Results for Feudo Montoni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Feudo+Montoni
# Retrieving Results for Hawkins Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hawkins+Cellars
# Retrieving Results for Henry Fessy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henry+Fessy
# Retrieving Results for Robert Hall.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Robert+Hall
# Retrieving Results for Sundance.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sundance
# Retrieving Results for Tarara.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tarara
# Retrieving Results for Tasca d'Almerita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tasca+d%27Almerita
# Retrieving Results for The White Knight.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=The+White+Knight
# Retrieving Results for Trump.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trump
# Retrieving Results for Vignerons de Bel Air.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vignerons+de+Bel+Air
# Retrieving Results for Casa Silva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Casa+Silva
# Retrieving Results for Cantine di Dolianova.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cantine+di+Dolianova
# Retrieving Results for Château de Sours.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+de+Sours
# Retrieving Results for RustRidge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=RustRidge
# Retrieving Results for Souverain.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Souverain
# Retrieving Results for Tasca d'Almerita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tasca+d%27Almerita
# Retrieving Results for Tres Palacios.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tres+Palacios
# Retrieving Results for Mellisoni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mellisoni
# Retrieving Results for Okapi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Okapi
# Retrieving Results for Podere dal Nespoli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Podere+dal+Nespoli
# Retrieving Results for Ram.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ram
# Retrieving Results for Roland Champion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Roland+Champion
# Retrieving Results for Sevtap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sevtap
# Retrieving Results for Simonnet-Febvre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Simonnet-Febvre
# Retrieving Results for Vignerons des Terres Secrètes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vignerons+des+Terres+Secr%C3%A8tes
# Retrieving Results for Basel Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Basel+Cellars
# Retrieving Results for Cocobon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cocobon
# Retrieving Results for Collet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Collet
# Retrieving Results for Drumheller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Drumheller
# Retrieving Results for Eco Terreno.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Eco+Terreno
# Retrieving Results for Grifalco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Grifalco
# Retrieving Results for Hindsight.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hindsight
# Retrieving Results for Hindsight.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hindsight
# Retrieving Results for Mulvane Wine Co..
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mulvane+Wine+Co.
# Retrieving Results for Schmitt Söhne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Schmitt+S%C3%B6hne
# Retrieving Results for Yalumba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Yalumba
# Retrieving Results for Z'IVO.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Z%27IVO
# Retrieving Results for Aresti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Aresti
# Retrieving Results for Spyro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Spyro
# Retrieving Results for Lionel Osmin & Cie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lionel+Osmin+%26+Cie
# Retrieving Results for Mitolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mitolo
# Retrieving Results for Napa Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Napa+Cellars
# Retrieving Results for P.J. Valckenberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=P.J.+Valckenberg
# Retrieving Results for P.J. Valckenberg.
# used region as search
# Retrieving Results for Palencia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Palencia
# Retrieving Results for Passaggio.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Passaggio
# Retrieving Results for Poggio Alloro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Poggio+Alloro
# Retrieving Results for Fattoria Sardi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fattoria+Sardi
# Retrieving Results for Ferrari-Carano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ferrari-Carano
# Retrieving Results for Folie à Deux.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Folie+%C3%A0+Deux
# Retrieving Results for Franciscan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Franciscan
# Retrieving Results for Fuchs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fuchs
# Retrieving Results for Gård.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=G%C3%A5rd
# Retrieving Results for Henry Fessy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henry+Fessy
# Retrieving Results for Henry Fessy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henry+Fessy
# Retrieving Results for Heron Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Heron+Hill
# Retrieving Results for Serpaia di Endrizzi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Serpaia+di+Endrizzi
# Retrieving Results for Serpaia di Endrizzi.
# used region as search
# Retrieving Results for Soquel Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Soquel+Vineyards
# Retrieving Results for Ventosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ventosa
# Retrieving Results for Lamoreaux Landing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lamoreaux+Landing
# Retrieving Results for Lamoreaux Landing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lamoreaux+Landing
# Retrieving Results for Leyda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Leyda
# Retrieving Results for Madonna Alta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Madonna+Alta
# Retrieving Results for Marchesi Antinori.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marchesi+Antinori
# Retrieving Results for Marchesi de' Frescobaldi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marchesi+de%27+Frescobaldi
# Retrieving Results for Marchesi de' Frescobaldi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marchesi+de%27+Frescobaldi
# Retrieving Results for Martin Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Martin+Ranch
# Retrieving Results for Ornellaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ornellaia
# Retrieving Results for Pardon et Fils.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pardon+et+Fils
# Retrieving Results for Piña.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pi%C3%B1a
# Retrieving Results for Podere Ciona.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Podere+Ciona
# Retrieving Results for Poggioventoso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Poggioventoso
# Retrieving Results for Pull.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pull
# Retrieving Results for Pull.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pull
# Retrieving Results for R2.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=R2
# Retrieving Results for Rideau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Rideau
# Retrieving Results for Tenuta Forconi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tenuta+Forconi
# Retrieving Results for Dopff & Irion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dopff+%26+Irion
# Retrieving Results for Ceretto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ceretto
# Retrieving Results for Matrix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Matrix
# Retrieving Results for Mauritson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mauritson
# Retrieving Results for Henry's Drive Vignerons.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henry%27s+Drive+Vignerons
# Retrieving Results for Silverado.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Silverado
# Retrieving Results for Le Riche.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Le+Riche
# Retrieving Results for Pierre Sparr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pierre+Sparr
# Retrieving Results for Pierre Sparr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pierre+Sparr
# Retrieving Results for Kuentz-Bas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kuentz-Bas
# Retrieving Results for Camberley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Camberley
# Retrieving Results for Ceretto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ceretto
# Retrieving Results for Dopff & Irion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dopff+%26+Irion
# Retrieving Results for Delheim.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Delheim
# Retrieving Results for Poderi Luigi Einaudi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Poderi+Luigi+Einaudi
# Retrieving Results for Clark-Clauden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Clark-Clauden
# Retrieving Results for Clark-Clauden.
# used region as search
# Retrieving Results for Giacomo Ascheri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Giacomo+Ascheri
# Retrieving Results for Lassègue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lass%C3%A8gue
# Retrieving Results for Dopff & Irion.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dopff+%26+Irion
# Retrieving Results for Kuentz-Bas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kuentz-Bas
# Retrieving Results for Poderi Colla.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Poderi+Colla
# Retrieving Results for Giacomo Ascheri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Giacomo+Ascheri
# Retrieving Results for Banyan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Banyan
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Zind-Humbrecht
# Retrieving Results for Terra Valentine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Terra+Valentine
# Retrieving Results for Testarossa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Testarossa
# Retrieving Results for Vincent Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vincent+Vineyards
# Retrieving Results for Vincent Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vincent+Vineyards
# Retrieving Results for Weingut Liebfrauenstift.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Weingut+Liebfrauenstift
# Retrieving Results for Wrath.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wrath
# Retrieving Results for Yardstick.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Yardstick
# Retrieving Results for Herdade Grande.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Herdade+Grande
# Retrieving Results for Albatross Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Albatross+Ridge
# Retrieving Results for Alta Colina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Alta+Colina
# Retrieving Results for Marques de Griñon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marques+de+Gri%C3%B1on
# Retrieving Results for Marques de Griñon.
# Missing field/result... skipping.
# Retrieving Results for Big Basin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Big+Basin
# Retrieving Results for Carl Graff.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Carl+Graff
# Retrieving Results for Casa Santa Vitória.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Casa+Santa+Vit%C3%B3ria
# Retrieving Results for Castello di Gabbiano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Castello+di+Gabbiano
# Retrieving Results for Château Vincens.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ch%C3%A2teau+Vincens
# Retrieving Results for Chronic Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Chronic+Cellars
# Retrieving Results for Claiborne & Churchill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Claiborne+%26+Churchill
# Retrieving Results for Conde de Velázquez.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Conde+de+Vel%C3%A1zquez
# Retrieving Results for Cono Sur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cono+Sur
# Retrieving Results for Domaine Berthoumieu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Berthoumieu
# Retrieving Results for Dracaena.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dracaena
# Retrieving Results for Dracaena.
# used region as search
# Retrieving Results for Duckhorn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Duckhorn
# Retrieving Results for Dutton-Goldfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dutton-Goldfield
# Retrieving Results for Fritz Haag.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fritz+Haag
# Retrieving Results for Fritz Haag.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fritz+Haag
# Retrieving Results for G7.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=G7
# Retrieving Results for Le Cadeau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Le+Cadeau
# Retrieving Results for Stoneleigh.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Stoneleigh
# Retrieving Results for Tenuta Peter Sölva & Söhne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tenuta+Peter+S%C3%B6lva+%26+S%C3%B6hne
# Retrieving Results for TerraMater.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=TerraMater
# Retrieving Results for Isole e Olena.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Isole+e+Olena
# Retrieving Results for Kenwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kenwood
# Retrieving Results for La Chablisienne.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=La+Chablisienne
# Retrieving Results for Manzoni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Manzoni
# Retrieving Results for McIntyre Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=McIntyre+Vineyards
# Retrieving Results for Alamos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Alamos
# Retrieving Results for Anaba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Anaba
# Retrieving Results for Apaltagua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Apaltagua
# Retrieving Results for Harrington.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Harrington
# Retrieving Results for Abbazia Santa Anastasia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Abbazia+Santa+Anastasia
# Retrieving Results for Viña Bisquertt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1a+Bisquertt
# Retrieving Results for Emiliana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Emiliana
# Retrieving Results for Fattoria Alois.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Fattoria+Alois
# Retrieving Results for Fattoria Alois.
# used region as search
# Retrieving Results for Henry's Drive Vignerons.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Henry%27s+Drive+Vignerons
# Retrieving Results for Aldegheri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Aldegheri
# Retrieving Results for Bertrand Ambroise.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bertrand+Ambroise
# Retrieving Results for Bertrand Ambroise.
# used region as search
# Retrieving Results for Carpineto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Carpineto
# Retrieving Results for Cesani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cesani
# Retrieving Results for Spier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Spier
# Retrieving Results for Sequum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sequum
# Retrieving Results for Sierra Starr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sierra+Starr
# Retrieving Results for Terlan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Terlan
# Retrieving Results for Yatir.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Yatir
# Retrieving Results for Adega Cooperativa de Borba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Adega+Cooperativa+de+Borba
# Retrieving Results for J. Lohr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=J.+Lohr
# Retrieving Results for J. Lohr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=J.+Lohr
# Retrieving Results for Courtney Benham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Courtney+Benham
# Retrieving Results for Courtney Benham.
# used region as search
# Retrieving Results for Del Carlo Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Del+Carlo+Winery
# Retrieving Results for Delaire Graff.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Delaire+Graff
# Retrieving Results for Domaine St Pierre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+St+Pierre
# Retrieving Results for Eikendal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Eikendal
# Retrieving Results for Famille Perrin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Famille+Perrin
# Retrieving Results for Matarromera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Matarromera
# Retrieving Results for MCV.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=MCV
# Retrieving Results for Mounts.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mounts
# Retrieving Results for Or Haganuz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Or+Haganuz
# Retrieving Results for Podere Scopetone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Podere+Scopetone
# Retrieving Results for Quinta de Foz de Arouce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Quinta+de+Foz+de+Arouce
# Retrieving Results for Robert Mondavi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Robert+Mondavi
# Retrieving Results for Samuel Tinon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Samuel+Tinon
# Retrieving Results for Sixteen by Twenty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sixteen+by+Twenty
# Retrieving Results for St. Pauls.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=St.+Pauls
# Retrieving Results for Mendel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mendel
# Retrieving Results for Oldenburg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Oldenburg
# Retrieving Results for Oldenburg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Oldenburg
# Retrieving Results for Wagner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Wagner
# Retrieving Results for Treleaven.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Treleaven
# Retrieving Results for Benessere.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Benessere
# Retrieving Results for Bloomer Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bloomer+Creek
# Retrieving Results for Andean Sky.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Andean+Sky
# Retrieving Results for Angove's.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Angove%27s
# Retrieving Results for Silvan Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Silvan+Ridge
# Retrieving Results for Talamonti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Talamonti
# Retrieving Results for Testarossa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Testarossa
# Retrieving Results for Meeker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Meeker
# Retrieving Results for Consorzio Vini Tipici di San Marino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Consorzio+Vini+Tipici+di+San+Marino
# Retrieving Results for D'Arenberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=D%27Arenberg
# Retrieving Results for Dogwood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dogwood
# Retrieving Results for Domaine du Tariquet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+du+Tariquet
# Retrieving Results for Falcor.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Falcor
# Retrieving Results for Hayman & Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hayman+%26+Hill
# Retrieving Results for Hermann J. Wiemer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hermann+J.+Wiemer
# Retrieving Results for J. & F. Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=J.+%26+F.+Lurton
# Retrieving Results for J. & F. Lurton.
# Missing field/result... skipping.
# Retrieving Results for Finca Las Moras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Finca+Las+Moras
# Retrieving Results for Long Flat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Long+Flat
# Retrieving Results for Work.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Work
# Retrieving Results for Amity.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Amity
# Retrieving Results for Autumn Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Autumn+Hill
# Retrieving Results for Blue Rock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Blue+Rock
# Retrieving Results for Cherry Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cherry+Hill
# Retrieving Results for Cloud 9.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cloud+9
# Retrieving Results for Cueva de las Manos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cueva+de+las+Manos
# Retrieving Results for David Fulton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=David+Fulton
# Retrieving Results for Esterlina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Esterlina
# Retrieving Results for Esterlina.
# used region as search
# Retrieving Results for Goats do Roam Wine Co..
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Goats+do+Roam+Wine+Co.
# Retrieving Results for Goats do Roam Wine Co..
# used region as search
# Retrieving Results for Graham Beck.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Graham+Beck
# Retrieving Results for Graham Beck.
# used region as search
# Retrieving Results for Hartenberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Hartenberg
# Retrieving Results for Vignobles 46N118.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vignobles+46N118
# Retrieving Results for Vignobles 46N118.
# used region as search
# Retrieving Results for Willamette Valley Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Willamette+Valley+Vineyards
# Retrieving Results for Algodon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Algodon
# Retrieving Results for Beaver Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Beaver+Creek
# Retrieving Results for Byron.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Byron
# Retrieving Results for Jardin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jardin
# Retrieving Results for Jardin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Jardin
# Retrieving Results for Kaiken.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kaiken
# Retrieving Results for Kaiken.
# used region as search
# Retrieving Results for Lungarotti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lungarotti
# Retrieving Results for Marchesi Fumanelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marchesi+Fumanelli
# Retrieving Results for Mariell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mariell
# Retrieving Results for Livio Felluga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Livio+Felluga
# Retrieving Results for My Big Fat Greek Wine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=My+Big+Fat+Greek+Wine
# Retrieving Results for My Big Fat Greek Wine.
# used region as search
# Retrieving Results for Nals Margreid.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Nals+Margreid
# Retrieving Results for O. Fournier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=O.+Fournier
# Retrieving Results for Pico Maccario.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pico+Maccario
# Retrieving Results for Pico Maccario.
# used region as search
# Retrieving Results for Sottano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sottano
# Retrieving Results for St. Francis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=St.+Francis
# Retrieving Results for Trailhead.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Trailhead
# Retrieving Results for Erath.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Erath
# Retrieving Results for Franz Haas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Franz+Haas
# Retrieving Results for Forstreiter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Forstreiter
# Retrieving Results for Cambria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cambria
# Retrieving Results for I Giusti e Zanza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=I+Giusti+e+Zanza
# Retrieving Results for J. Christopher.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=J.+Christopher
# Retrieving Results for Viña Cobos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vi%C3%B1a+Cobos
# Retrieving Results for Talley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Talley
# Retrieving Results for Acústic.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ac%C3%BAstic
# Retrieving Results for Acústic.
# used region as search
# Retrieving Results for Parallel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Parallel
# Retrieving Results for Domaine Daniel Dugois.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Daniel+Dugois
# Retrieving Results for Kilikanoon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kilikanoon
# Retrieving Results for Finca Sophenia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Finca+Sophenia
# Retrieving Results for Treana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Treana
# Retrieving Results for Ventisquero.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ventisquero
# Retrieving Results for Aquinas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Aquinas
# Retrieving Results for Arboleda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Arboleda
# Retrieving Results for Benessere.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Benessere
# Retrieving Results for Buried Cane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Buried+Cane
# Retrieving Results for Buried Cane.
# used region as search
# Retrieving Results for Cascina Adelaide.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cascina+Adelaide
# Retrieving Results for Claudia Springs.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Claudia+Springs
# Retrieving Results for Cramele Recas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Cramele+Recas
# Retrieving Results for Domaine Bertagna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Bertagna
# Retrieving Results for Domaine Sigalas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Domaine+Sigalas
# Retrieving Results for Socré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Socr%C3%A9
# Retrieving Results for Socré.
# used region as search
# Retrieving Results for Boffa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Boffa
# Retrieving Results for Otto's Constant Dream.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Otto%27s+Constant+Dream
# Retrieving Results for Otto's Constant Dream.
# used region as search
# Retrieving Results for Mount Veeder.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mount+Veeder
# Retrieving Results for Robert Mondavi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Robert+Mondavi
# Retrieving Results for Bellussi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bellussi
# Retrieving Results for Aresti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Aresti
# Retrieving Results for Paladin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Paladin
# Retrieving Results for Perlage.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Perlage
# Retrieving Results for Sant Eurosia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sant+Eurosia
# Retrieving Results for Sant Eurosia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Sant+Eurosia
# Retrieving Results for J. & F. Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=J.+%26+F.+Lurton
# Retrieving Results for J. & F. Lurton.
# used region as search
# Retrieving Results for L'Antica Quercia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=L%27Antica+Quercia
# Retrieving Results for Lucas Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Lucas+Vineyards
# Retrieving Results for Marsuret.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Marsuret
# Retrieving Results for De Martino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=De+Martino
# Retrieving Results for Beringer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Beringer
# Retrieving Results for Brutocao.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Brutocao
# Retrieving Results for Clos La Chance.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Clos+La+Chance
# Retrieving Results for Cono Sur.
# ...
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Maison Champy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Maison+Champy
# Retrieving Results for Olivier Rivière.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Olivier+Rivi%C3%A8re
# Retrieving Results for Olivier Rivière.
# used region as search
# Retrieving Results for Schramsberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Schramsberg
# Retrieving Results for Siduri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Siduri
# Retrieving Results for Barbieri.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Barbieri
# Retrieving Results for Bernardus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bernardus
# Retrieving Results for Bernardus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bernardus
# Retrieving Results for Meurgey-Croses.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Meurgey-Croses
# Retrieving Results for Meurgey-Croses.
# used region as search
# Retrieving Results for Meurgey-Croses.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Meurgey-Croses
# Retrieving Results for Meurgey-Croses.
# used region as search
# Retrieving Results for Navarro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Navarro
# Retrieving Results for Shenandoah Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Shenandoah+Vineyards
# Retrieving Results for Smith & Hook.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Smith+%26+Hook
# Retrieving Results for Syncline.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Syncline
# Retrieving Results for Kaleidos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Kaleidos
# Retrieving Results for La Rata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=La+Rata
# Retrieving Results for La Rata.
# used region as search
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Louis Latour.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Louis+Latour
# Retrieving Results for Maison Bleue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Maison+Bleue
# Retrieving Results for Albert Bichot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Albert+Bichot
# Retrieving Results for Aratás.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Arat%C3%A1s
# Retrieving Results for Aratás.
# used region as search
# Retrieving Results for Arnaud Baillot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Arnaud+Baillot
# Retrieving Results for Barrack.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Barrack
# Retrieving Results for Ila.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ila
# Retrieving Results for Tiamo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tiamo
# Retrieving Results for Heron.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Heron
# Retrieving Results for Tercos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Tercos
# Retrieving Results for Tercos.
# used region as search
# Retrieving Results for Turkey Flat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Turkey+Flat
# Retrieving Results for Bottega.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Bottega
# Retrieving Results for Mosby.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Mosby
# Retrieving Results for Santa Alicia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Santa+Alicia
# Retrieving Results for Santa Carolina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Santa+Carolina
# Retrieving Results for Echeverria.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Echeverria
# Retrieving Results for Filus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Filus
# Retrieving Results for Filus.
# used region as search
# Retrieving Results for Alberti 154.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Alberti+154
# Retrieving Results for Andeluna.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Andeluna
# Retrieving Results for Apaltagua.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Apaltagua
# Retrieving Results for Calina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Calina
# Retrieving Results for Caliterra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Caliterra
# Retrieving Results for Ironberry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ironberry
# Retrieving Results for Ironberry.
# used region as search
# Retrieving Results for Puro Uno.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Puro+Uno
# Retrieving Results for Puro Uno.
# used region as search
# Retrieving Results for Simple Math Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Simple+Math+Cellars
# Retrieving Results for Baby Bear.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Baby+Bear
# Retrieving Results for Vasse Felix.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Vasse+Felix
# Retrieving Results for William Church.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=William+Church
# Retrieving Results for Gordon Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Gordon+Estate
# Retrieving Results for Ciabot Berton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Ciabot+Berton
# Retrieving Results for Domäne Wachau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Dom%C3%A4ne+Wachau
# Retrieving Results for Frankland Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Frankland+Estate
# Retrieving Results for Pecchenino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Pecchenino
# Retrieving Results for Obelisco Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Obelisco+Estate
# Retrieving Results for Peju.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Peju
# Retrieving Results for Saracina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBxMFase9yLbhIfvYy3C96J9ukUWadOcOs&address=Saracina
# Retrieving Results for Schild Estate.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3.7\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~\Anaconda3.7\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3.7\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3.7\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3.7\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3.7\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     317             else:
# --> 318                 raise SocketError(str(e))
#     319         except OpenSSL.SSL.ZeroReturnError:
#
# OSError: (10051, 'WSAENETUNREACH')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3.7\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3.7\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# ~\Anaconda3.7\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3.7\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3.7\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~\Anaconda3.7\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3.7\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3.7\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3.7\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3.7\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     317             else:
# --> 318                 raise SocketError(str(e))
#     319         except OpenSSL.SSL.ZeroReturnError:
#
# ProtocolError: ('Connection aborted.', OSError("(10051, 'WSAENETUNREACH')"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-39-f0fb1f2ea650> in <module>
#      13      #assemble url and make API request
#      14     print(f"Retrieving Results for {row['winery']}.")
# ---> 15     response = requests.get(base_url, params=params)
#      16
#      17     print(response.url)
#
# ~\Anaconda3.7\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3.7\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3.7\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3.7\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3.7\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10051, 'WSAENETUNREACH')"))

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   country  \
# 0           1             1  Portugal
# 1           2             2        US
# 2           3             3        US
# 3           4             4        US
# 4           5             5     Spain
#
#                                          description  \
# 0  This is ripe and fruity, a wine that is smooth...
# 1  Tart and snappy, the flavors of lime flesh and...
# 2  Pineapple rind, lemon pith and orange blossom ...
# 3  Much like the regular bottling from 2012, this...
# 4  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery        Lat         Lng
# 0      Portuguese Red  Quinta dos Avidagos  41.387933   -7.276971
# 1          Pinot Gris            Rainstorm  40.089829  -88.248177
# 2            Riesling           St. Julian  43.177727  -85.560201
# 3          Pinot Noir         Sweet Cheeks  42.343889  -71.101111
# 4  Tempranillo-Merlot               Tandem  32.905753 -117.230246

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   country  \
# 0           1             1  Portugal
# 1           2             2        US
# 2           3             3        US
# 3           4             4        US
# 4           5             5     Spain
#
#                                          description  \
# 0  This is ripe and fruity, a wine that is smooth...
# 1  Tart and snappy, the flavors of lime flesh and...
# 2  Pineapple rind, lemon pith and orange blossom ...
# 3  Much like the regular bottling from 2012, this...
# 4  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery        Lat         Lng
# 0      Portuguese Red  Quinta dos Avidagos  41.387933   -7.276971
# 1          Pinot Gris            Rainstorm  40.089829  -88.248177
# 2            Riesling           St. Julian  43.177727  -85.560201
# 3          Pinot Noir         Sweet Cheeks  42.343889  -71.101111
# 4  Tempranillo-Merlot               Tandem  32.905753 -117.230246

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["points"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
