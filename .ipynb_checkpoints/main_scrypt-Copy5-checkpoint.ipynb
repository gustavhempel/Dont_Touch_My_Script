# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from api_keys_Copy2 import g_key

# %%
file = '9.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  country  \
# 0       96781        103963          103963   France
# 1       96782        103964          103964    Chile
# 2       96783        103965          103965   France
# 3       96784        103966          103966   France
# 4       96785        103967          103967  Hungary
#
#                                          description           designation  \
# 0  Crisp and with good acidity, this is a light, ...                   NaN
# 1  This light-colored, almost clear, SB opens wit...  Sibaris Gran Reserva
# 2  Pay attention to the Tutiac winemakers north o...   Carrelet d'Estuaire
# 3  Intense acidity gives this wine character. It ...      Lalande Bellevue
# 4  This Hungarian Blauburger is garnet in color, ...                   NaN
#
#    points  price      province        region_1 region_2        taster_name  \
# 0      87   15.0      Bordeaux  Bordeaux Blanc      NaN         Roger Voss
# 1      87   15.0  Leyda Valley             NaN      NaN  Michael Schachner
# 2      87   16.0      Bordeaux   Bordeaux Rosé      NaN         Roger Voss
# 3      87   16.0      Bordeaux   Bordeaux Rosé      NaN         Roger Voss
# 4      87   17.0          Eger             NaN      NaN       Jeff Jenssen
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger                       Trocard 2016  Bordeaux Blanc
# 1           @wineschach  Undurraga 2016 Sibaris Gran Reserva Sauvignon ...
# 2            @vossroger  Vignerons de Tutiac 2016 Carrelet d'Estuaire R...
# 3            @vossroger  Vignerons de Tutiac 2016 Lalande Bellevue Rosé...
# 4        @worldwineguys                 Vincze Béla 2008 Blauburger (Eger)
#
#                       variety               winery
# 0  Bordeaux-style White Blend              Trocard
# 1             Sauvignon Blanc            Undurraga
# 2                        Rosé  Vignerons de Tutiac
# 3                        Rosé  Vignerons de Tutiac
# 4                  Blauburger          Vincze Béla

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
keyword = 'Sweet Cheeks'

params = {"key": g_key,'address':keyword}
response = requests.get(base_url, params=params)
#print(response.url)
places_data = response.json()
places_data
for index, row in df.iterrows():
    target_coordinates = row['winery']
    params['address'] = target_coordinates
        
     #assemble url and make API request
    print(f"Retrieving Results for {row['winery']}.")
    response = requests.get(base_url, params=params)
    
    print(response.url)
    try:
        places_data = response.json()
        #print(places_data)
        results = places_data['results'][0]
        #print(results)
        location = results['geometry']['location']
        #print(location)
        lat = location['lat']
        #print(lat)
        lng = location['lng']
        #print(lng)
        df.loc[index, 'Lat'] = lat
        df.loc[index, 'Lng'] = lng
        
        
    except:
        
        try:
            target_coordinates = row['region_1']
            params['address'] = target_coordinates
        
             #assemble url and make API request
            print(f"Retrieving Results for {row['winery']}.")
            response = requests.get(base_url, params=params)
            places_data = response.json()
            #print(places_data)
            results = places_data['results'][0]
            #print(results)
            location = results['geometry']['location']
            #print(location)
            lat = location['lat']
            #print(lat)
            lng = location['lng']
            #print(lng)
            df.loc[index, 'Lat'] = lat
            df.loc[index, 'Lng'] = lng
            print('used region as search')
            
        except:
                
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Trocard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Trocard
# Retrieving Results for Undurraga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Undurraga
# Retrieving Results for Vignerons de Tutiac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vignerons+de+Tutiac
# Retrieving Results for Vignerons de Tutiac.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vignerons+de+Tutiac
# Retrieving Results for Vincze Béla.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vincze+B%C3%A9la
# Retrieving Results for Whalebone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Whalebone
# Retrieving Results for Adega Mãe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Adega+M%C3%A3e
# Retrieving Results for Auclair.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Auclair
# Retrieving Results for Ironstone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ironstone
# Retrieving Results for Markham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Markham
# Retrieving Results for Martin Ray.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Martin+Ray
# Retrieving Results for Montes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Montes
# Retrieving Results for Montes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Montes
# Retrieving Results for Nodland.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Nodland
# Retrieving Results for Paraduxx.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Paraduxx
# Retrieving Results for Quinta do Noval.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Noval
# Retrieving Results for Ribafreixo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ribafreixo
# Retrieving Results for Ribbon Cliff.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ribbon+Cliff
# Retrieving Results for Slow Press.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Slow+Press
# Retrieving Results for Slow Press.
# used region as search
# Retrieving Results for Steele.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Steele
# Retrieving Results for Tertulia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tertulia
# Retrieving Results for Three Rivers.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Three+Rivers
# Retrieving Results for Viña Marty.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vi%C3%B1a+Marty
# Retrieving Results for Bodegas Bilbainas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Bilbainas
# Retrieving Results for Brutocao.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brutocao
# Retrieving Results for Fallbrook.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fallbrook
# Retrieving Results for Grgich Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Grgich+Hills
# Retrieving Results for Michael David.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Michael+David
# Retrieving Results for Alfredo Roca.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Alfredo+Roca
# Retrieving Results for Alfredo Roca.
# used region as search
# Retrieving Results for Abraham Perold.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Abraham+Perold
# Retrieving Results for Abraham Perold.
# used region as search
# Retrieving Results for Sineann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sineann
# Retrieving Results for Concha y Toro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Concha+y+Toro
# Retrieving Results for Concha y Toro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Concha+y+Toro
# Retrieving Results for Viu Manent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Viu+Manent
# Retrieving Results for Capaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Capaia
# Retrieving Results for Sineann.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sineann
# Retrieving Results for Tatiarra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tatiarra
# Retrieving Results for WillaKenzie Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=WillaKenzie+Estate
# Retrieving Results for Big Ass.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Big+Ass
# Retrieving Results for De Toren.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=De+Toren
# Retrieving Results for Piera Martellozzo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Piera+Martellozzo
# Retrieving Results for Rock Hollow.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rock+Hollow
# Retrieving Results for Telavi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Telavi
# Retrieving Results for Tommasi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tommasi
# Retrieving Results for Bocelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bocelli
# Retrieving Results for Botter.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Botter
# Retrieving Results for Botter.
# used region as search
# Retrieving Results for Casa do Valle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casa+do+Valle
# Retrieving Results for Casa Silva.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casa+Silva
# Retrieving Results for Casal Paço Padreiro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casal+Pa%C3%A7o+Padreiro
# Retrieving Results for Château Maris.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Maris
# Retrieving Results for Cramele Recas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cramele+Recas
# Retrieving Results for Dillon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dillon
# Retrieving Results for Gérard Bertrand.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=G%C3%A9rard+Bertrand
# Retrieving Results for Gérard Bertrand.
# used region as search
# Retrieving Results for Villaggio Grando.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Villaggio+Grando
# Retrieving Results for William Cole.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=William+Cole
# Retrieving Results for Donelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Donelli
# Retrieving Results for Donelli.
# Missing field/result... skipping.
# Retrieving Results for Montes.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Montes
# Retrieving Results for Oberon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Oberon
# Retrieving Results for oops.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=oops
# Retrieving Results for Pine Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pine+Ridge
# Retrieving Results for Roadhouse Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Roadhouse+Winery
# Retrieving Results for Ruby Red.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ruby+Red
# Retrieving Results for Spann Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Spann+Vineyards
# Retrieving Results for Efeste.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Efeste
# Retrieving Results for Finca la Celia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Finca+la+Celia
# Retrieving Results for Finca la Celia.
# Missing field/result... skipping.
# Retrieving Results for Boheme.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Boheme
# Retrieving Results for Brassfield.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brassfield
# Retrieving Results for Davies.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Davies
# Retrieving Results for Michele Chiarlo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Michele+Chiarlo
# Retrieving Results for Plantagenet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Plantagenet
# Retrieving Results for Riglos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Riglos
# Retrieving Results for Shannon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Shannon
# Retrieving Results for Shannon Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Shannon+Ridge
# Retrieving Results for Sottomarino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sottomarino
# Retrieving Results for Jean Edwards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Jean+Edwards
# Retrieving Results for Johannishof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Johannishof
# Retrieving Results for Vicente Faria Vinhos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vicente+Faria+Vinhos
# Retrieving Results for WillaKenzie Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=WillaKenzie+Estate
# Retrieving Results for Woodinville Wine Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Woodinville+Wine+Cellars
# Retrieving Results for Domaine Terlato & Chapoutier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Terlato+%26+Chapoutier
# Retrieving Results for Dr. Loosen.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dr.+Loosen
# Retrieving Results for Earthquake.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Earthquake
# Retrieving Results for Galerie.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Galerie
# Retrieving Results for Andrew Will.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Andrew+Will
# Retrieving Results for Tyrrell's.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tyrrell%27s
# Retrieving Results for Xanadu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Xanadu
# Retrieving Results for Château de Pez.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+de+Pez
# Retrieving Results for Château Siran.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Siran
# Retrieving Results for Cristom.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cristom
# Retrieving Results for Domaine Serene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Serene
# Retrieving Results for Domaine Pichot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Pichot
# Retrieving Results for Quinta de Soalheiro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+de+Soalheiro
# Retrieving Results for Quinta de Soalheiro.
# used region as search
# Retrieving Results for Rusack.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rusack
# Retrieving Results for Seven Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Seven+Hills
# Retrieving Results for Seven Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Seven+Hills
# Retrieving Results for Starmont.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Starmont
# Retrieving Results for Stewart Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stewart+Cellars
# Retrieving Results for Undurraga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Undurraga
# Retrieving Results for Waxwing.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Waxwing
# Retrieving Results for Whalebone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Whalebone
# Retrieving Results for Joseph Swan Vineyards.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Swan+Vineyards
# Retrieving Results for Klinker Brick.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Klinker+Brick
# Retrieving Results for Kooyong.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kooyong
# Retrieving Results for Margerum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Margerum
# Retrieving Results for Mark Ryan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mark+Ryan
# Retrieving Results for Passing Time.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Passing+Time
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Zind-Humbrecht
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Zind-Humbrecht
# Retrieving Results for Domaine Zind-Humbrecht.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Zind-Humbrecht
# Retrieving Results for Dry Creek Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dry+Creek+Vineyard
# Retrieving Results for François Baur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fran%C3%A7ois+Baur
# Retrieving Results for Fulcrum.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fulcrum
# Retrieving Results for Guarachi Family.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Guarachi+Family
# Retrieving Results for Gustave Lorentz.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gustave+Lorentz
# Retrieving Results for Hoi Polloi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hoi+Polloi
# Retrieving Results for Hunnicutt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hunnicutt
# Retrieving Results for Work.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Work
# Retrieving Results for Jaxon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Jaxon
# Retrieving Results for Rutherford Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rutherford+Ranch
# Retrieving Results for Tertulia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tertulia
# Retrieving Results for Tertulia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tertulia
# Retrieving Results for Thomas Carteron.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Thomas+Carteron
# Retrieving Results for Thomas Carteron.
# Missing field/result... skipping.
# Retrieving Results for Ponga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ponga
# Retrieving Results for Brooklyn West.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brooklyn+West
# Retrieving Results for Lemelson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lemelson
# Retrieving Results for Airfield Estates.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Airfield+Estates
# Retrieving Results for Bridlewood.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bridlewood
# Retrieving Results for Trivento.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Trivento
# Retrieving Results for Vionta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vionta
# Retrieving Results for Wilson.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Wilson
# Retrieving Results for Winzerkeller Andau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Winzerkeller+Andau
# Retrieving Results for Highland Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Highland+Cellars
# Retrieving Results for Highland Cellars.
# used region as search
# Retrieving Results for Hightower.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hightower
# Retrieving Results for Burnside Road.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Burnside+Road
# Retrieving Results for CàMaiol.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=C%C3%A0Maiol
# Retrieving Results for CàMaiol.
# Missing field/result... skipping.
# Retrieving Results for Cantina di Monteforte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cantina+di+Monteforte
# Retrieving Results for Cantine Grasso.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cantine+Grasso
# Retrieving Results for Cass.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cass
# Retrieving Results for Castello di Spessa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Castello+di+Spessa
# Retrieving Results for Cedar River Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cedar+River+Cellars
# Retrieving Results for Château Carpe Diem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Carpe+Diem
# Retrieving Results for Château d'Astros.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+d%27Astros
# Retrieving Results for Château la Calisse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+la+Calisse
# Retrieving Results for Château Roubine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Roubine
# Retrieving Results for Compagnie Viticole de Provence.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Compagnie+Viticole+de+Provence
# Retrieving Results for Ecker.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ecker
# Retrieving Results for Fontana Candida.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fontana+Candida
# Retrieving Results for Hahn.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hahn
# Retrieving Results for Capestrano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Capestrano
# Retrieving Results for Cas'Almare.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cas%27Almare
# Retrieving Results for Chain Gang.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chain+Gang
# Retrieving Results for Cortenova.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cortenova
# Retrieving Results for Domaine Costa Lazaridi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Costa+Lazaridi
# Retrieving Results for Farnese.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Farnese
# Retrieving Results for François Lurton.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fran%C3%A7ois+Lurton
# Retrieving Results for Hensley.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hensley
# Retrieving Results for Kouros.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kouros
# Retrieving Results for Kouros.
# used region as search
# Retrieving Results for Kumbaya.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kumbaya
# Retrieving Results for Kumbaya.
# used region as search
# Retrieving Results for La di Motte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+di+Motte
# Retrieving Results for Laurier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Laurier
# Retrieving Results for Maipe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Maipe
# Retrieving Results for McFadden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=McFadden
# Retrieving Results for Lava Cap.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lava+Cap
# Retrieving Results for San Simeon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=San+Simeon
# Retrieving Results for Santa Sofia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Santa+Sofia
# Retrieving Results for Alysian.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Alysian
# Retrieving Results for Donovan-Parke.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Donovan-Parke
# Retrieving Results for Donovan-Parke.
# used region as search
# Retrieving Results for Kirkland Signature.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kirkland+Signature
# Retrieving Results for Kirkland Signature.
# used region as search
# Retrieving Results for Ksana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ksana
# Retrieving Results for Malibu Rocky Oaks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Malibu+Rocky+Oaks
# Retrieving Results for Morgenhof.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Morgenhof
# Retrieving Results for Napa Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Napa+Creek
# Retrieving Results for Gravity Hills.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gravity+Hills
# Retrieving Results for Pianetta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pianetta
# Retrieving Results for Makulu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Makulu
# Retrieving Results for Pianetta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pianetta
# Retrieving Results for flipflop.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=flipflop
# Retrieving Results for Barton & Guestier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Barton+%26+Guestier
# Retrieving Results for Barton & Guestier.
# Missing field/result... skipping.
# Retrieving Results for Calcu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Calcu
# Retrieving Results for Calcu.
# used region as search
# Retrieving Results for Little Stone Vineyard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Little+Stone+Vineyard
# Retrieving Results for Cantora.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cantora
# Retrieving Results for Cantora.
# used region as search
# Retrieving Results for Releaf.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Releaf
# Retrieving Results for Barton & Guestier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Barton+%26+Guestier
# Retrieving Results for Barton & Guestier.
# Missing field/result... skipping.
# Retrieving Results for Chilensis.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chilensis
# Retrieving Results for Chilensis.
# used region as search
# Retrieving Results for Mazzocco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mazzocco
# Retrieving Results for Sorrentino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sorrentino
# Retrieving Results for Chilcas.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chilcas
# Retrieving Results for Viu Manent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Viu+Manent
# Retrieving Results for Red Pony Ranch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Red+Pony+Ranch
# Retrieving Results for Miguel Torres.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Miguel+Torres
# Retrieving Results for Castillo Clavijo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Castillo+Clavijo
# Retrieving Results for Cellars 33.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cellars+33
# Retrieving Results for Del Carlo Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Del+Carlo+Winery
# Retrieving Results for Joseph Mellot.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Mellot
# Retrieving Results for Markham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Markham
# Retrieving Results for Melini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Melini
# Retrieving Results for Novy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Novy
# Retrieving Results for Poças.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Po%C3%A7as
# Retrieving Results for Principe Corsini Fattoria Le Corti.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Principe+Corsini+Fattoria+Le+Corti
# Retrieving Results for René Sparr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ren%C3%A9+Sparr
# Retrieving Results for René Sparr.
# used region as search
# Retrieving Results for Barone Ricasoli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Barone+Ricasoli
# Retrieving Results for Barone Ricasoli.
# used region as search
# Retrieving Results for Casale di Daviddi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casale+di+Daviddi
# Retrieving Results for Casalvento Radda.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casalvento+Radda
# Retrieving Results for Castello di Meleto.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Castello+di+Meleto
# Retrieving Results for Castra Rubra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Castra+Rubra
# Retrieving Results for Cave de Ribeauvillé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cave+de+Ribeauvill%C3%A9
# Retrieving Results for Cecchi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cecchi
# Retrieving Results for Ribafreixo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ribafreixo
# Retrieving Results for Sebastiani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sebastiani
# Retrieving Results for Stoller.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stoller
# Retrieving Results for Tenuta di Lilliano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tenuta+di+Lilliano
# Retrieving Results for Domaine Weinbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Weinbach
# Retrieving Results for Caldwell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Caldwell
# Retrieving Results for Gramercy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gramercy
# Retrieving Results for Joseph Phelps.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Joseph+Phelps
# Retrieving Results for Domäne Wachau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dom%C3%A4ne+Wachau
# Retrieving Results for Southard.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Southard
# Retrieving Results for Trimbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Trimbach
# Retrieving Results for Domaine Weinbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Weinbach
# Retrieving Results for Domaines Schlumberger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaines+Schlumberger
# Retrieving Results for Stone The Crows.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stone+The+Crows
# Retrieving Results for Hunnicutt.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hunnicutt
# Retrieving Results for Lauren Ashton Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lauren+Ashton+Cellars
# Retrieving Results for René Muré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ren%C3%A9+Mur%C3%A9
# Retrieving Results for René Muré.
# used region as search
# Retrieving Results for Signorello.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Signorello
# Retrieving Results for Domaines Schlumberger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaines+Schlumberger
# Retrieving Results for Dunham.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dunham
# Retrieving Results for Maison Bleue.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Maison+Bleue
# Retrieving Results for Blue Rock.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Blue+Rock
# Retrieving Results for Domaine de la Bégude.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+de+la+B%C3%A9gude
# Retrieving Results for Domaine Weinbach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Weinbach
# Retrieving Results for Gramercy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gramercy
# Retrieving Results for Lauren Ashton Cellars.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lauren+Ashton+Cellars
# Retrieving Results for Domaine Sorin.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Sorin
# Retrieving Results for Domaine Tempier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Tempier
# Retrieving Results for Domaines Schlumberger.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaines+Schlumberger
# Retrieving Results for Domäne Wachau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dom%C3%A4ne+Wachau
# Retrieving Results for René Muré.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ren%C3%A9+Mur%C3%A9
# Retrieving Results for René Muré.
# used region as search
# Retrieving Results for Sante Arcangeli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sante+Arcangeli
# Retrieving Results for Owen Roe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Owen+Roe
# Retrieving Results for Armida.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Armida
# Retrieving Results for Brooks.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brooks
# Retrieving Results for Viñedos de Paganos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vi%C3%B1edos+de+Paganos
# Retrieving Results for Von Strasser.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Von+Strasser
# Retrieving Results for Yalumba.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Yalumba
# Retrieving Results for Tenuta di Capraia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tenuta+di+Capraia
# Retrieving Results for Hugel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hugel
# Retrieving Results for I Veroni.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=I+Veroni
# Retrieving Results for J Vineyards & Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J+Vineyards+%26+Winery
# Retrieving Results for Otazu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Otazu
# Retrieving Results for Otazu.
# used region as search
# Retrieving Results for Príncipe de Viana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Pr%C3%ADncipe+de+Viana
# Retrieving Results for Jim Barry.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Jim+Barry
# Retrieving Results for Katnook Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Katnook+Estate
# Retrieving Results for Tournon by Michel Chapoutier.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tournon+by+Michel+Chapoutier
# Retrieving Results for Comenge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Comenge
# Retrieving Results for CVNE.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=CVNE
# Retrieving Results for CVNE.
# used region as search
# Retrieving Results for Bleasdale.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bleasdale
# Retrieving Results for Friedeman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Friedeman
# Retrieving Results for Acacia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Acacia
# Retrieving Results for Allimant-Laugner.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Allimant-Laugner
# Retrieving Results for Alma Rosa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Alma+Rosa
# Retrieving Results for Ampelos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ampelos
# Retrieving Results for Argentiera.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Argentiera
# Retrieving Results for Avancia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Avancia
# Retrieving Results for Avignonesi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Avignonesi
# Retrieving Results for Boeckel.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Boeckel
# Retrieving Results for Bonterra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bonterra
# Retrieving Results for Brunelli Martoccia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brunelli+Martoccia
# Retrieving Results for Brutocao.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brutocao
# Retrieving Results for Camigliano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Camigliano
# Retrieving Results for Piocho.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Piocho
# Retrieving Results for Proidl.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Proidl
# Retrieving Results for Ramey.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ramey
# Retrieving Results for Small Vines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Small+Vines
# Retrieving Results for Tenuta di Sesta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tenuta+di+Sesta
# Retrieving Results for Johanneshof Reinisch.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Johanneshof+Reinisch
# Retrieving Results for Kokomo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kokomo
# Retrieving Results for Loimer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Loimer
# Retrieving Results for Malat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Malat
# Retrieving Results for Marchesi de' Frescobaldi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Marchesi+de%27+Frescobaldi
# Retrieving Results for Zoetic Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Zoetic+Wines
# Retrieving Results for Zoetic Wines.
# used region as search
# Retrieving Results for Mazzei.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mazzei
# Retrieving Results for Allram.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Allram
# Retrieving Results for Allram.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Allram
# Retrieving Results for Anton Bauer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Anton+Bauer
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Br%C3%BCndlmayer
# Retrieving Results for Schramsberg.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Schramsberg
# Retrieving Results for Te Mata.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Te+Mata
# Retrieving Results for J. Lohr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J.+Lohr
# Retrieving Results for J. Lohr.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=J.+Lohr
# Retrieving Results for Bacio Divino.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bacio+Divino
# Retrieving Results for Bacio Divino.
# used region as search
# Retrieving Results for Baileyana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Baileyana
# Retrieving Results for Brophy Clark.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brophy+Clark
# Retrieving Results for Bründlmayer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Br%C3%BCndlmayer
# Retrieving Results for Domaine Baron de l'Ecluse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+Baron+de+l%27Ecluse
# Retrieving Results for Domaine du Vissoux.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Domaine+du+Vissoux
# Retrieving Results for Ebner-Ebenauer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ebner-Ebenauer
# Retrieving Results for Fontodi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fontodi
# Retrieving Results for Rubino Estates Winery.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Rubino+Estates+Winery
# Retrieving Results for Sierra Norte.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sierra+Norte
# Retrieving Results for Spell.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Spell
# Retrieving Results for Talisman.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Talisman
# Retrieving Results for Quinta do Arrobe.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Quinta+do+Arrobe
# Retrieving Results for Real Companhia Velha.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Real+Companhia+Velha
# Retrieving Results for Le Marchesine.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Le+Marchesine
# Retrieving Results for Lexington.
# ...
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Junta
# Retrieving Results for Terre di Talamo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Terre+di+Talamo
# Retrieving Results for Terre di Talamo.
# used region as search
# Retrieving Results for Tolaini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Tolaini
# Retrieving Results for Valentini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Valentini
# Retrieving Results for 240 Days.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=240+Days
# Retrieving Results for 240 Days.
# used region as search
# Retrieving Results for Boomtown.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Boomtown
# Retrieving Results for Fattoria di Ruppiano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fattoria+di+Ruppiano
# Retrieving Results for Fornacelle.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fornacelle
# Retrieving Results for Henry Fessy.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Henry+Fessy
# Retrieving Results for Bertani.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bertani
# Retrieving Results for MacPhail.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=MacPhail
# Retrieving Results for Olson Ogden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Olson+Ogden
# Retrieving Results for Olson Ogden.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Olson+Ogden
# Retrieving Results for Stonestreet.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Stonestreet
# Retrieving Results for La Fenêtre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Fen%C3%AAtre
# Retrieving Results for Weinrieder.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Weinrieder
# Retrieving Results for Gloria Ferrer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Gloria+Ferrer
# Retrieving Results for Think Tank.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Think+Tank
# Retrieving Results for Titus.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Titus
# Retrieving Results for Vina Robles.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vina+Robles
# Retrieving Results for Waterbrook.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Waterbrook
# Retrieving Results for Hanaiali'i.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hanaiali%27i
# Retrieving Results for Hanaiali'i.
# used region as search
# Retrieving Results for Bodegas Berceo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Berceo
# Retrieving Results for Galatea Effect.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Galatea+Effect
# Retrieving Results for Lagana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lagana
# Retrieving Results for Lagana.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Lagana
# Retrieving Results for Loft.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Loft
# Retrieving Results for Matsu.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Matsu
# Retrieving Results for Nadler.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Nadler
# Retrieving Results for :Nota Bene.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=%3ANota+Bene
# Retrieving Results for Oyster Bay.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Oyster+Bay
# Retrieving Results for Hosmer.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Hosmer
# Retrieving Results for Ignacio Marín.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ignacio+Mar%C3%ADn
# Retrieving Results for La Cignozza.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Cignozza
# Retrieving Results for La Querce.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=La+Querce
# Retrieving Results for Les Hauts de Lagarde.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Les+Hauts+de+Lagarde
# Retrieving Results for Les Hauts de Lagarde.
# Missing field/result... skipping.
# Retrieving Results for 60 North.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=60+North
# Retrieving Results for Bota Box.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bota+Box
# Retrieving Results for Brancaia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Brancaia
# Retrieving Results for Buried Cane.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Buried+Cane
# Retrieving Results for Buried Cane.
# used region as search
# Retrieving Results for Château Andron.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Andron
# Retrieving Results for Château Au Grand Paris.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Au+Grand+Paris
# Retrieving Results for Château Grand Jean.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Grand+Jean
# Retrieving Results for Château Haut-Sorillon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Haut-Sorillon
# Retrieving Results for Château Haut-Sorillon.
# Missing field/result... skipping.
# Retrieving Results for Château Vircoulon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Vircoulon
# Retrieving Results for Dark Horse.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dark+Horse
# Retrieving Results for Fattoria Petriolo.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fattoria+Petriolo
# Retrieving Results for Goose Ridge.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Goose+Ridge
# Retrieving Results for Les Vignerons de la Méditerranée.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Les+Vignerons+de+la+M%C3%A9diterran%C3%A9e
# Retrieving Results for Mil Piedras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Mil+Piedras
# Retrieving Results for Mil Piedras.
# used region as search
# Retrieving Results for Porta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Porta
# Retrieving Results for Raphael.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Raphael
# Retrieving Results for Alpataco.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Alpataco
# Retrieving Results for Alpataco.
# used region as search
# Retrieving Results for Bocelli.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bocelli
# Retrieving Results for Casa Larga.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casa+Larga
# Retrieving Results for Concha y Toro.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Concha+y+Toro
# Retrieving Results for Cave de Ribeauvillé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Cave+de+Ribeauvill%C3%A9
# Retrieving Results for Macari.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Macari
# Retrieving Results for Murphy-Goode.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Murphy-Goode
# Retrieving Results for Murphy-Goode.
# used region as search
# Retrieving Results for Muscardini.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Muscardini
# Retrieving Results for Santa Carolina.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Santa+Carolina
# Retrieving Results for Santa Rita.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Santa+Rita
# Retrieving Results for Chapel Hill.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chapel+Hill
# Retrieving Results for De Loach.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=De+Loach
# Retrieving Results for Dutch Bill Creek.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Dutch+Bill+Creek
# Retrieving Results for Giordano.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Giordano
# Retrieving Results for Kawarau Estate.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Kawarau+Estate
# Retrieving Results for Château La Prade.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+La+Prade
# Retrieving Results for Château La Prade.
# Missing field/result... skipping.
# Retrieving Results for Château Lajarre.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Lajarre
# Retrieving Results for Château les Arromans.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+les+Arromans
# Retrieving Results for Château Malbat.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Malbat
# Retrieving Results for Château Roc de Ségur.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Roc+de+S%C3%A9gur
# Retrieving Results for Château Roc de Ségur.
# used region as search
# Retrieving Results for Château Suau.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Suau
# Retrieving Results for Chehalem.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Chehalem
# Retrieving Results for City Winery Chicago.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=City+Winery+Chicago
# Retrieving Results for Conde de Subirats.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Conde+de+Subirats
# Retrieving Results for Consejo de la Alta.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Consejo+de+la+Alta
# Retrieving Results for Contadi Castaldi.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Contadi+Castaldi
# Retrieving Results for EOS.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=EOS
# Retrieving Results for Fount.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Fount
# Retrieving Results for Sanguinhal.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Sanguinhal
# Retrieving Results for Vignobles Carreau Selection.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Vignobles+Carreau+Selection
# Retrieving Results for 786 Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=786+Wines
# Retrieving Results for 786 Wines.
# used region as search
# Retrieving Results for Bodegas Cerrosol.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Cerrosol
# Retrieving Results for Bodegas Ondalan.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Bodegas+Ondalan
# Retrieving Results for Casa Nuestra.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Casa+Nuestra
# Retrieving Results for Casa Nuestra.
# used region as search
# Retrieving Results for Ioppa.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ioppa
# Retrieving Results for Ironstone.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ironstone
# Retrieving Results for Jean Laurent.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Jean+Laurent
# Retrieving Results for DFJ Vinhos.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=DFJ+Vinhos
# Retrieving Results for Global Wines.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Global+Wines
# Retrieving Results for Château Barbé.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Barb%C3%A9
# Retrieving Results for Château Feret Lambert.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Feret+Lambert
# Retrieving Results for Château Gigault.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Gigault
# Retrieving Results for Château Haut Peyrefaure.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Haut+Peyrefaure
# Retrieving Results for Château Haut Peyrefaure.
# Missing field/result... skipping.
# Retrieving Results for Château Jeanguillon.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Ch%C3%A2teau+Jeanguillon
# Retrieving Results for Château Jeanguillon.
# used region as search
# Retrieving Results for Santa Alicia.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Santa+Alicia
# Retrieving Results for Skouras.
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBVCSTQFux_PH6nd9vUwRQBFAZUkegM82c&address=Skouras
# Retrieving Results for Thirteen Appellations.

# %%
df.head()
df['heat weights'] = df['points']-80

# %%
#Don't drop, just take the rows where EPS is not NA:

df = df[df['Lat'].notna()]
df = df[df['Lng'].notna()]
df.to_csv('9coord.csv')
df.head()

# %%
import gmaps
gmaps.configure(api_key=g_key)
locations = df[["Lat", "Lng"]].astype(float)
humidity = df["heat weights"].astype(float)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=20,
                                 point_radius = 0.2)

fig.add_layer(heat_layer)
fig
